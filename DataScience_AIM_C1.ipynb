# %% [markdown]
# # **Cuestión 1**
#  **Elaboración de un modelo predictivo de machine learning con el objetivo de predecir si un determinado verraco será o no será productivo.**
#
# **Descripción del tutor de la empresa:**
#
# > *Algunos puntos que me parece interesante que puedas llegar a establecer relaciones son:
# FECHA DE RECOGIDA, CENTRO, CONCENTRACIÓN, DOSIS, RAZA, GENÉTICA,
# MOTILIDAD4, CALIDAD_MOVIMIENTO4, supervivencia del verraco en el centro (FECHA_SALIDA – FECHA LLEGADA), PROCEDENCIA, CAUSA_BAJA, LINEA_GEN ... Sería interesante buscar relaciones entre las variables que se te ocurran y poder obtener una ventaja competitiva con dicha información extraida*

# %% [markdown]
# # **Modelo Predictivo - Machine Learning:**
#
# **Modelo predictivo en busca de conocer si un verraco será productivo o no es función a su raza, procedencia, linea genética, centro y dosis reales en cada una de las extracciones realizadas en él**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

df = pd.read_excel('EYACULADOS.xlsx')
verracos = pd.read_excel('VERRACOS.xlsx')

# %% [markdown]
# ## **Estudio inicial de los datos**

# %% [markdown]
# **Las dos bases de datos a utilizar son la perteneicente al archivo denominado EYACULADOS.xlsx (almacenada en la cariable "df") y Verracos.xlsx (almacenada en la variable "verracos")**

# %%
df.head(5)
# Out:
#    CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 0  140901 2020-01-03         2095  620ND06    CAL          68          56
# 1  140902 2020-01-03         1872  520ND19    CAL          68          55
# 2  140903 2020-01-03         2094  620ND05    CAL          68          83
# 3  140904 2020-01-03         2086  620ND96    CAL          68          78
# 4  140905 2020-01-03         2470  807DP42    CAL          68          83
#
#    VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 0      317             76          9                   7               10
# 1      357             61          9                   7                9
# 2      511            156          9                   7               36
# 3      497            134          9                   8               30
# 4      572            116          9                   7               30
#
#    DOSIS_REAL  DOSIS_A_DILUIR  DILUYENTE  SEMEN_ANADIR  CONCENTRACION_REAL  \
# 0          10             0.0      513.0           317                2409
# 1           9             0.0      390.0           357                2420
# 2          36             0.0     2477.0           511                2214
# 3          30             0.0     1993.0           497                2220
# 4          30             0.0     1918.0           572                2212
#
#   VALIDO MOTIVO_DESECHO MOTIVO_DIFERENCIA HETEROSPERMIA CODIGO_HETEROSPERMIA  \
# 0   True             OK                OK          True          N07DDA10101
# 1   True             OK                OK          True          N07DDA10101
# 2   True             OK                OK          True          N07DDA10101
# 3   True             OK                OK          True          N07DDA10101
# 4   True             OK                OK          True          N07DPA10101
#
#    ENVASADAS  DILUIDO  BOLASER_BLANCO  BOLASER_MA  ID_DILUYENTE  ML_DILUYENTE  \
# 0    98.3125     True         30995.0         0.0        2730.0         513.0
# 1     0.0000     True         30995.0         0.0        2730.0         390.0
# 2     0.0000     True         30995.0         0.0        2730.0        2477.0
# 3     0.0000     True         30995.0         0.0        2730.0        1993.0
# 4    82.0000     True         30995.0         0.0        2730.0        1918.0
#
#       RAZA  DOSIS DILUIDAS  TEMP_DILUYENTE  CONDUCTIVIDAD
# 0  DANBRED              10       20.299999           10.6
# 1  DANBRED               9       20.299999           10.4
# 2  DANBRED              36       20.299999           10.5
# 3  DANBRED              30       20.299999           10.6
# 4    DUPIC              30       20.400000            9.6

# %%
df['AÑO'] = df['FECHA_REC'].dt.year
df['MES'] = df['FECHA_REC'].dt.month
df.head(5)
# Out:
#    CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 0  140901 2020-01-03         2095  620ND06    CAL          68          56
# 1  140902 2020-01-03         1872  520ND19    CAL          68          55
# 2  140903 2020-01-03         2094  620ND05    CAL          68          83
# 3  140904 2020-01-03         2086  620ND96    CAL          68          78
# 4  140905 2020-01-03         2470  807DP42    CAL          68          83
#
#    VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 0      317             76          9                   7               10
# 1      357             61          9                   7                9
# 2      511            156          9                   7               36
# 3      497            134          9                   8               30
# 4      572            116          9                   7               30
#
#    DOSIS_REAL  DOSIS_A_DILUIR  DILUYENTE  SEMEN_ANADIR  CONCENTRACION_REAL  \
# 0          10             0.0      513.0           317                2409
# 1           9             0.0      390.0           357                2420
# 2          36             0.0     2477.0           511                2214
# 3          30             0.0     1993.0           497                2220
# 4          30             0.0     1918.0           572                2212
#
#   VALIDO MOTIVO_DESECHO MOTIVO_DIFERENCIA HETEROSPERMIA CODIGO_HETEROSPERMIA  \
# 0   True             OK                OK          True          N07DDA10101
# 1   True             OK                OK          True          N07DDA10101
# 2   True             OK                OK          True          N07DDA10101
# 3   True             OK                OK          True          N07DDA10101
# 4   True             OK                OK          True          N07DPA10101
#
#    ENVASADAS  DILUIDO  BOLASER_BLANCO  BOLASER_MA  ID_DILUYENTE  ML_DILUYENTE  \
# 0    98.3125     True         30995.0         0.0        2730.0         513.0
# 1     0.0000     True         30995.0         0.0        2730.0         390.0
# 2     0.0000     True         30995.0         0.0        2730.0        2477.0
# 3     0.0000     True         30995.0         0.0        2730.0        1993.0
# 4    82.0000     True         30995.0         0.0        2730.0        1918.0
#
#       RAZA  DOSIS DILUIDAS  TEMP_DILUYENTE  CONDUCTIVIDAD   AÑO  MES
# 0  DANBRED              10       20.299999           10.6  2020    1
# 1  DANBRED               9       20.299999           10.4  2020    1
# 2  DANBRED              36       20.299999           10.5  2020    1
# 3  DANBRED              30       20.299999           10.6  2020    1
# 4    DUPIC              30       20.400000            9.6  2020    1

# %%
print(df['AÑO'].value_counts())
print(df['MES'].value_counts())
# Out:
# 2015    23414
# 2017    21919
# 2020    20761
# 2016    20234
# 2018    20094
# 2019    19847
# 2014    14042
# 2013    12638
# 2012      628
# 2021      122
# Name: AÑO, dtype: int64
# 9     13848
# 8     13764
# 10    13711
# 12    13637
# 7     13279
# 6     12834
# 3     12752
# 5     12555
# 4     12553
# 11    12288
# 1     11266
# 2     11212
# Name: MES, dtype: int64

# %%
df['CENTRO'].value_counts()
# Out:
# CAL      100158
# PEÑAS     48924
# TOL        4617
# Name: CENTRO, dtype: int64

# %%
df['RAZA'].value_counts()
# Out:
# 0             50148
# DANBRED       24808
# AND           10479
# PIETUPBJJ      7736
# PIETUPBNN      6542
# PAC            6518
# TDDDD          5352
# DUPIC          5178
# PIETUPB        3967
# AGSG           3900
# TEEEE          3597
# DNA            2050
# PIETAXIOM      1990
# DURGENES       1761
# ADN            1679
# TLLLL          1635
# TUUUUIBE       1247
# TVVVV          1183
# DCAXIOM        1085
# LDAX           1075
# TPPNP          1028
# TPPPPTOP        975
# BLUEACMC        846
# DCADN           699
# TDDPP           698
# LWAX            631
# LDADN           603
# TUUUU           506
# PIETUPBFR       492
# PI ALEM NP      467
# TIIII           456
# IBERICO         396
# TPPPPELI        276
# LWACMC          263
# TZZZZGGP        263
# LWADN           261
# MAXSEG          230
# TAAAAGGP        228
# DURGENMJJ       223
# DURGENG         222
# ADNREK          221
# DURGENM         205
# DURGENESM       165
# TUUUUEFI        158
# TUUUUCAL        149
# L65P+           142
# TZZZZ           128
# PACCAR          100
# PIETSERGAL       87
# TUUUUGGP         30
# TPPNN            22
# TDDDDTOP         10
# PIETGEN          10
# TAAAA             3
# DAN-INGA          1
# -                 1
# Name: RAZA, dtype: int64

# %%
verracos.head()
# Out:
#    CODIGO  CLASE VERRACO TATUAJE CENTRO FECHA_NACTO FECHA_LLEGADA  \
# 0     828  TUUUU     406   A4V7Z    CAL         NaT    2008-01-22
# 1     829  TUUUU     407   A2V7W    CAL  2007-03-04    2008-03-06
# 2     830  TUUUU     408   A8V2P    CAL  2007-12-21    2008-03-06
# 3     831  TUUUU     409   S7N8F    CAL  2007-03-06    2008-03-06
# 4     832  TUUUU     410   S8N7D    CAL  2007-05-11    2008-03-06
#
#   FECHA_SALIDA  ACTIVO STRESS PROCEDENCIA            DESTINO CAUSA_BAJA  \
# 0   2008-09-03   False    NaN         NaN                NaN         29
# 1   2008-09-03   False    NaN         NaN                NaN         29
# 2   2009-01-08   False    NaN         NaN  CARNICAS CIEZANAS         15
# 3   2008-09-03   False    NaN         NaN                NaN         29
# 4   2008-12-11   False    NaN         NaN                NaN         29
#
#   LINEA_GEN INICIO_AMORT  COSTE_AMORT  MESES_AMORT  COD_ANT  \
# 0       NaN   2008-01-22         2500           18      828
# 1       NaN   2008-03-06         2500           18      829
# 2       NaN   2008-03-06         2500           18      830
# 3       NaN   2008-03-06         2500           18      831
# 4       NaN   2008-03-06         2500           18      832
#
#    PROPIEDAD_CLIENTE COD_CLIENTE ULTIMA_AMORTIZACION  IMP_PTE_AMORTIZAR  \
# 0              False         NaN                 NaT                NaN
# 1              False         NaN                 NaT                NaN
# 2              False         NaN                 NaT                NaN
# 3              False         NaN                 NaT                NaN
# 4              False         NaN                 NaT                NaN
#
#   NUM_ACTIVO_FIJO  RECLAMADO CUARENTENA GENETICA RAZA2 FECHA_ENTRADA_PROD
# 0             NaN      False        NaN      NaN   NaN                NaT
# 1             NaN      False        NaN      NaN   NaN                NaT
# 2             NaN      False        NaN      NaN   NaN                NaT
# 3             NaN      False        NaN      NaN   NaN                NaT
# 4             NaN      False        NaN      NaN   NaN                NaT

# %%
verracos['LINEA_GEN'].value_counts()
# Out:
# PIETUPB      214
# DANBRED      197
# PAC          106
# TDDDD         70
# AND           65
# DURGEN        38
# DUPIC         35
# TUUUU         34
# PTAXIOM       34
# TEEEE         33
# TAAAA         33
# TVVVV         28
# TZZZZ         27
# TPPPP         27
# BLUEACMC      21
# TLLLL         20
# DNA           18
# LDAX          18
# AGSG          17
# TDDPP         16
# PTADN         13
# DURAXIOM      12
# TIIII         12
# LWAX          10
# LWACMC        10
# PTSER          9
# LDADN          8
# TPPNP          8
# TNNNN          8
# PTALE          7
# DURADN         7
# LWADN          5
# MAXSEG         5
# PIETRAIN       5
# ADNREK         4
# TBBBB          4
# L65            4
# PIETUPBFR      4
# TPPNN          3
# IBERICO        3
# PTAUSBAR       1
# PIETGEN        1
# Name: LINEA_GEN, dtype: int64

# %%
verracos['PROCEDENCIA'].value_counts()
# Out:
# PEÑAS DE SAN PEDRO                                    159
# MEJORADA                                              102
# ANTONIO LOPEZ                                          83
# BURUTAIN                                               53
# ESCORIAL                                               50
# PEÑAS                                                  48
# QUALITAT ESPERMATICA                                   44
# AIM LEON                                               42
# TAFALLA                                                37
# SINOVAS                                                34
# GANADOS PERALTA S.L                                    24
# ACOMPOR                                                24
# ALMENAR                                                23
# ZAHARA                                                 22
# GENESUS INC OAKVILLE MB ID NO 5326121                  18
# LA COMETA                                              17
# CAN JAUMO                                              17
# EXPLOTACIONES CUFA                                     17
# DESCONOCIDA                                            16
# HASTRUPGARD, HASTRUPGARDSVEJ 7000 FREDERICIA DENMA     16
# AIM SINOVAS                                            15
# PEUT VAN DE V.O.F.                                     14
# SORIA                                                  14
# PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE HOL     13
# ALBAGES                                                12
# BUJARALOZ                                              12
# UPB GENETIC                                            12
# LA MASIA                                               12
# MAS GALLAT                                             11
# AIM SORIA                                              11
# LEON                                                   11
# REPUBLICA CHECA                                        11
# JOSSE PASCAL LE POURCAUD AUGAN FRANCE                  10
# ROHWER TIMO LOOPER WEG 19 24589 SCHULP ALEMANIA        10
# GRUPO ALTOPASO A CORUÑA                                10
# ELTZABURU                                               9
# USA                                                     9
# NAVARRA                                                 9
# HASTRUPGARD HASTRUPGARDSVEJ 8 7000 FREDERICIA DK        9
# NAVALAGAMELLA                                           9
# AIM ANDALUCIA                                           8
# KERNEIS KERINOU LE CONQUET 29217 FRANCIA                8
# QUALITAT                                                8
# FINA MARKUS AM LAUBENBUCH 2 ALEMANIA                    8
# AIM CENTRO                                              8
# GRANJA ZAHARA TOLEDO ESPAÑA                             8
# SCWARZ WOLFGANG BACHSTR 14 SALCHING ALEMANIA            8
# ROHWER JURGEN BOKELER STR 5 24793 BRAMMER ALEMANIA      7
# GUMPP HERMANN KIRCHPLATZ 1, 89420 DEISENFOFEN ALEM      7
# TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA           7
# SOSA                                                    7
# DESCONOCIDO                                             7
# EL ESCORIAL                                             7
# COMETA                                                  7
# VOLSGAARDI DAMSTRUPVEJ ORNHOJ DENMARK                   7
# GRANJA ZAHARA                                           7
# MELGAR                                                  6
# FINA MARKUS WEIBENBURG GERMANY                          6
# FINA MARKUS AM LAUBENBUCH WEIBENBURG ALEMANIA           6
# SCHWARZ WOLFGANG BACHT STR 14 ALEMANIA                  6
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN ALEMANIA                6
# VAN DE PEUT B.V.                                        6
# TRAINING TOPIGS                                         6
# GRANJA ALTOPASO  A CORUÑA SPAIN                         6
# LA GARENNE 37310 AZAY-SUR-INDRE FRANCIA                 6
# CIA MEJORADA                                            6
# MAALING AVL OG OPFORMERING SKELDEMARG 10 DENMARK        6
# GRANJA ALTOPASO SOBRADO DE LOS MONJES A CORUÑA          5
# ARENILLAS                                               5
# NAVALCAN                                                5
# ARANDA DE DUERO                                         5
# KUGEL GEORG MAUERNER STR 23A ALEMANIA                   5
# TOM RATHJE COLUMBUS NEBRASKA USA                        5
# NEHER STEPHAN DORFSTR 16 ALEMANIA                       5
# ARRI-TURRI                                              5
# AIM ANDALUCÍA                                           4
# PETERSEN HANS DETLEF SUEDER  VOLSEMENHUSEN ALEMANI      4
# BEUNZA                                                  4
# INTEGRACIONES PERALTA                                   4
# LYKKENSGAARD AVLSCENTER ELLEDEVEJ 95 DENMARK            4
# ODARPI (GENETICA VILLADIEGO)                            4
# AIM PEÑAS                                               4
# ECKARDT BERND GBR HOHNWEG 14 ALEMANIA                   4
# LA ALMOLDA                                              4
# LIPPERT NORBERT AURAER STR 1 ALEMANIA                   4
# FUGLSANG DENMARK 4160 HERLUFMAGLE                       4
# HEMELUMER HOEVE BV                                      4
# SANTENIS NAVALCAN TOLEDO SPAIN                          4
# ALMUDEVAR                                               4
# GRANJA ZAHARA CERVERA TOLEDO ESPAÑA                     4
# HOLANDA                                                 4
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ  DENMARK          4
# ARRI TURRI                                              4
# ATEZ                                                    4
# AGER                                                    4
# UPB GENETIC WORLD                                       4
# EXPLOTACIONES CUFA SL                                   4
# MUNKBRO II MUNKBROVEJ 7 7500 HOLSTEBRO DENMARK          4
# TOJAPIGS SARL DROMBAS DROMBAS FRANCE                    3
# GRUPO ALTOPASO A CORUÑA ES150800089301                  3
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN GERMANY                 3
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ DENMARK           3
# SCHWARZ WOLFGANG SALCHING GERMANY                       3
# GRANJA ZAHARA (TOLEDO) ESPAÑA                           3
# AVLSCENTRET HOLMEGARD A/S, FALDSLEDVEJ FABORG DK        3
# SANTIBAÑEZ                                              3
# LIPPERT NORBERT EUERDORF GERMANY                        3
# MAS EL CROS                                             3
# ELEVAGE DE BIZY OUZOUERLE MARCHE FRANCE                 3
# KUGEL GEORG PFORRING GERMANY                            3
# FINA MARKUS AM LAUBNBUCH 2                              3
# AIM NAVARRA                                             3
# ES5010370130002-00864                                   2
# ELEVAGE DE BIZY OUZOUER LE MARCHE FRANCE                2
# KERNEIS KERINOU LE CONQUET FRANCE                       2
# ODARPI GENETICA VILLADIEGO                              2
# KERDANET                                                2
# ERTL JOHANNES FRAUNBERG GERMANY                         2
# ODARPI VILLUSTO ESPAÑA                                  2
# HORIZON CERAN LE FROMENTEAU CERANS FOULLETOURTE FR      2
# TOPIGS NORSVIN ESPAÑA                                   2
# BIURRUN                                                 2
# ELEVAGE DE BIZY OUZOUER LE MARCHE 41240 FRANCIA         2
# SANTENIS - C. CARRASCONES 12-2A - 45610 NAVALCAN T      2
# TOPIGS IBERICA                                          2
# GUMPP HERMANN DEISENHOFEN GERMANY                       2
# SAN RAFAEL                                              2
# SCHWARZ WOLFGANG BACHSTR SALCHING GERMANY               2
# CHANTELOUP                                              2
# KÜGEL GEORG MAUERNER STR PFÖRRING ALEMANIA              2
# SCHAAF-SCHELD GBR ARNSHAINER WEG 5 WAHLEN ALEMANIA      2
# ZAHARA CERVERA TOLEDO ESPAÑA                            2
# ESKEGAARD A/S MOLLEGYDE HADERSLEV DENMARK               2
# ERTL JOHANNES GROSSHUNDLBACH 12 ALEMANIA                2
# PEUT BV, VAN DE - BAARLOSEWEG 18 -  MARKNESS NETHE      2
# EARL FERME DE LA VALLE 650 RUE DU PIRE ALLER FRANC      2
# VAN DE PEUT B.V                                         1
# TOJAPIGS SARL DOMBRAS - 1, RUE NAPOLEON - -FRANCE       1
# ECKARDT BERND SONNEFELD GERMANY                         1
# LE BARON CHRISTIAN PEN LAN KERDAVID LE MOUSTOIR FR      1
# EARL ARMANE LE BOIS CLAIR EVAILLE 72120 FRANCIA         1
# KERBELAY (MARZAN)                                       1
# BURUATIN                                                1
# VAN DE PEUT B.B.                                        1
# ARRI TURRI, SL                                          1
# BERGSHOLM VIDAR N-3160 STOKKE NORUEGA                   1
# EXPLTACIONES CUFA                                       1
# UPB GENETICA                                            1
# BARCELONA                                               1
# SCEA PINIER-JOSSO KERBELAY MARZAN 56130 FRANCIA         1
# ECKARDT BERND HOHNWEG 14 SONNFELD GERMANY               1
# QUALITA ESPERMATICA                                     1
# SAS ADN (MAIGRIS)                                       1
# FINA MARKUS AM LAUBENBUCH 2 WEIBENBURG ALEMANIA         1
# QIALITAT ESPERMATICA                                    1
# LL. TANKEDAL DENMARK 6580 VANDRUP                       1
# GANADERA MONEGRO                                        1
# PEÑAS DE SAN PÈDRO                                      1
# GRANJA ZAHARA TOLEDO SPAIN                              1
# AGUILAFUENTE                                            1
# ES250020011665                                          1
# TRANING TOPIGS                                          1
# EARL DARTOIS BEAUCHENE GUITE FRANCE                     1
# VITORIA                                                 1
# JULE TOR HENRIK - - - - 7710 SPARBU - - NORWAY          1
# GUMPP HERMANN KIRCHPLATZ 1 DEISENHOFEN GERMANY          1
# QUALITAT ESPERMÁTICA                                    1
# TOPIGS IBERICA SL                                       1
# EARL FERME DE LA VALLEE HERBINGHEM FRANCE               1
# CASETA SANTASUSANA SAN MATEU DE BAGES                   1
# ATEZ (NAVARRA)                                          1
# FINA MARKUS AM LAUBENBUCH WEIBENBURG GERMANY            1
# INGA FOOD SA ALMENDRALEJO BADAJOZ                       1
# SCHAAF-SCHELD ARNSHAINER KIRTORF-WAHLEN GERMANY         1
# CUARENTENA SOSA                                         1
# CUARENTENA UPB                                          1
# BERGSHOLM VIDAR N 3160 STOKKE NORUEGA                   1
# FRANCIA                                                 1
# TRAINING MEJORADA                                       1
# TRAINING TOPINS                                         1
# GAEC DES PORCS SAINS LA FOURBERIE GUIGNEN 35580         1
# DECONOCIDO                                              1
# CAN CARRERAS                                            1
# SANCHEZ ROMERO CARVAJAL JABUGO S.A.                     1
# QUALITAT ESPERMATICA SL                                 1
# GANADERA MOBEGRO                                        1
# ALMOLDA                                                 1
# MAALING III SLEVADVEJ 3 6560 SOMMERSTED DENMARK         1
# ECKARDT BEECKARDT BERND SONNEFELD GERMANY               1
# INGLATERRA                                              1
# Name: PROCEDENCIA, dtype: int64

# %% [markdown]
# **Para saber si un verraco es productivo o no es necesario establecer un mínimo de dosis reales producidas en un año**

# %%
group_1 = df.groupby(['COD_VERRACO', 'AÑO'])['DOSIS_REAL'].count()
group_1 = pd.DataFrame(group_1)
group_1 = group_1.reset_index()
group_1.head()
# Out:
#    COD_VERRACO   AÑO  DOSIS_REAL
# 0          770  2013           1
# 1         1048  2012           3
# 2         1048  2013          18
# 3         1049  2012           3
# 4         1049  2013          12

# %%
group_1.shape
# Out:
# (3146, 3)

# %%
merged = pd.merge(df, group_1, on=['COD_VERRACO', 'AÑO'])

# %%
merged.head(10)
# Out:
#    CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 0  140901 2020-01-03         2095  620ND06    CAL          68          56
# 1  141423 2020-01-13         2095  620ND06    CAL          68          55
# 2  141683 2020-01-17         2095  620ND06    CAL          68          78
# 3  141838 2020-01-20         2095  620ND06    CAL          68          55
# 4  142047 2020-01-24         2095  620ND06    CAL          68          83
# 5  142252 2020-01-27         2095  620ND06    CAL          68          83
# 6  142651 2020-02-03         2095  620ND06    CAL          68          55
# 7  142857 2020-02-07         2095  620ND06    CAL          68          55
# 8  143016 2020-02-10         2095  620ND06    CAL          68          83
# 9  142449 2020-01-29         2095  620ND06    CAL          68          78
#
#    VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 0      317             76          9                   7               10
# 1      562             87          8                   7               22
# 2      639            166          9                   7               48
# 3      272             96          9                   8               11
# 4      500             76          9                   8               17
# 5      433             92          9                   7               18
# 6      643            111          9                   8               32
# 7      354             66          9                   7               10
# 8      458             72          9                   7               14
# 9      380             56          8                   7                9
#
#    DOSIS_REAL_x  DOSIS_A_DILUIR  DILUYENTE  SEMEN_ANADIR  CONCENTRACION_REAL  \
# 0            10             0.0      513.0           317                2409
# 1            22             0.0     1264.0           562                2222
# 2            48             0.0     3345.0           639                2210
# 3            11             0.0      641.0           272                2374
# 4            17             0.0      911.0           500                2235
# 5            18             0.0     1061.0           433                2213
# 6            32             0.0     2013.0           643                2230
# 7            10             0.0      476.0           354                2336
# 8            14             0.0      704.0           458                2355
# 9             0             0.0        0.0            32                   0
#
#   VALIDO MOTIVO_DESECHO MOTIVO_DIFERENCIA HETEROSPERMIA CODIGO_HETEROSPERMIA  \
# 0   True             OK                OK          True          N07DDA10101
# 1   True             OK                OK          True          N07DDA10303
# 2   True             OK                OK          True          N07DDA10310
# 3   True             OK                OK          True          N07DDA10403
# 4   True             OK                OK          True          N07DDA10406
# 5   True             OK                OK          True          N07DDA10502
# 6   True             OK                OK          True          N07DDA10602
# 7   True             OK                OK          True          N07DDA10606
# 8   True             OK                OK          True          N07DDA10703
# 9  False              F                OK         False                  NaN
#
#    ENVASADAS  DILUIDO  BOLASER_BLANCO  BOLASER_MA  ID_DILUYENTE  ML_DILUYENTE  \
# 0    98.3125     True         30995.0         0.0        2730.0         513.0
# 1    68.6250     True         31483.0         0.0        2749.0        1264.0
# 2     0.0000     True         31475.0         0.0        2760.0        3345.0
# 3     0.0000     True         31343.0         0.0        2765.0         641.0
# 4     0.0000     True         30832.0         0.0        2774.0         911.0
# 5     0.0000     True         30999.0         0.0        2780.0        1061.0
# 6     0.0000     True         30976.0         0.0        2795.0        2013.0
# 7     0.0000     True         31049.0         0.0        2806.0         476.0
# 8     0.0000     True         31177.0         0.0        2812.0         704.0
# 9     0.0000    False         30983.0         0.0           0.0           0.0
#
#       RAZA  DOSIS DILUIDAS  TEMP_DILUYENTE  CONDUCTIVIDAD   AÑO  MES  \
# 0  DANBRED              10       20.299999           10.6  2020    1
# 1  DANBRED              22       20.500000           10.7  2020    1
# 2  DANBRED              48       20.299999           10.4  2020    1
# 3  DANBRED              11       20.500000           10.5  2020    1
# 4  DANBRED              17       20.200001           10.4  2020    1
# 5  DANBRED              18       20.799999           10.8  2020    1
# 6  DANBRED              32       20.900000           10.6  2020    2
# 7  DANBRED              10       21.100000           10.5  2020    2
# 8  DANBRED              14       20.799999           10.4  2020    2
# 9  DANBRED               0             NaN            NaN  2020    1
#
#    DOSIS_REAL_y
# 0            18
# 1            18
# 2            18
# 3            18
# 4            18
# 5            18
# 6            18
# 7            18
# 8            18
# 9            18

# %% [markdown]
# **DOSIS_REAL_y es el valor de la producción de dosis anual en el año de la fecha de recogida. En base a este dato y suponiendo que, para ser considerado productivo, un verraco ha de producir más de 80 dosis al año, creo la nueva columna 'PRODUCTIVO' con valores 1 si es productivo, 0 si no.**
#
# **Este valor que marca la productividad o no de un semental es proporcionado por la empresa, el cual es el más frecuente según la distribución normal realizada más adelante**

# %%
merged['DOSIS_REAL_y'].unique()
# Out:
# array([ 18,  11,  45,  17,  81,   2,  73,  37,  62,  56,  36,  80,  84,
#         70,  86,  58,  65,  28, 120,  44,   9, 128, 101,  51,  64,  61,
#         48,  33,  53,  82, 130,  60,  46,  77,  92,  76,  47,  72,  31,
#         79,  71,  90,  95,  26,  19, 138,  94, 139, 141, 135, 134, 133,
#        126, 147, 131, 136,  30, 123,  24,  40,  21,  29,  27,  39,   4,
#         89,   1,  42,  14,  32,  59, 140,  10, 143, 116,  22, 145, 100,
#         63,  88,  15,  85,  54,  35,  74,  83,  20,  69,  52,  41,   7,
#        109,  99,  50,  55,  13,  23,  49, 121, 103,  87,  43,  75,  34,
#         68,  91, 125,  16, 127,  78,   5,  67,  66,  57,  12,  25,   3,
#          8,   6, 104,  97, 106,  96, 144, 107, 114, 115, 118, 108, 112,
#         98, 166, 119, 105, 132, 102, 113, 152, 165, 156, 111,  93,  38,
#        122, 117, 124, 110, 129, 137, 142, 148, 154, 151])

# %%
plt.hist(merged['DOSIS_REAL_y'])
# Out:
# (array([ 6034., 10354., 17325., 19186., 28184., 25956., 25327., 12883.,
#          7506.,   944.]),
#  array([  1. ,  17.5,  34. ,  50.5,  67. ,  83.5, 100. , 116.5, 133. ,
#         149.5, 166. ]),
#  <a list of 10 Patch objects>)

# %%
merged['PRODUCTIVO'] = 0

# %%
merged['PRODUCTIVO'] = np.where(merged['DOSIS_REAL_y'] >= 80, 1, 0)

# %%
merged.head()
# Out:
#    CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 0  140901 2020-01-03         2095  620ND06    CAL          68          56
# 1  141423 2020-01-13         2095  620ND06    CAL          68          55
# 2  141683 2020-01-17         2095  620ND06    CAL          68          78
# 3  141838 2020-01-20         2095  620ND06    CAL          68          55
# 4  142047 2020-01-24         2095  620ND06    CAL          68          83
#
#    VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 0      317             76          9                   7               10
# 1      562             87          8                   7               22
# 2      639            166          9                   7               48
# 3      272             96          9                   8               11
# 4      500             76          9                   8               17
#
#    DOSIS_REAL_x  DOSIS_A_DILUIR  DILUYENTE  SEMEN_ANADIR  CONCENTRACION_REAL  \
# 0            10             0.0      513.0           317                2409
# 1            22             0.0     1264.0           562                2222
# 2            48             0.0     3345.0           639                2210
# 3            11             0.0      641.0           272                2374
# 4            17             0.0      911.0           500                2235
#
#   VALIDO MOTIVO_DESECHO MOTIVO_DIFERENCIA HETEROSPERMIA CODIGO_HETEROSPERMIA  \
# 0   True             OK                OK          True          N07DDA10101
# 1   True             OK                OK          True          N07DDA10303
# 2   True             OK                OK          True          N07DDA10310
# 3   True             OK                OK          True          N07DDA10403
# 4   True             OK                OK          True          N07DDA10406
#
#    ENVASADAS  DILUIDO  BOLASER_BLANCO  BOLASER_MA  ID_DILUYENTE  ML_DILUYENTE  \
# 0    98.3125     True         30995.0         0.0        2730.0         513.0
# 1    68.6250     True         31483.0         0.0        2749.0        1264.0
# 2     0.0000     True         31475.0         0.0        2760.0        3345.0
# 3     0.0000     True         31343.0         0.0        2765.0         641.0
# 4     0.0000     True         30832.0         0.0        2774.0         911.0
#
#       RAZA  DOSIS DILUIDAS  TEMP_DILUYENTE  CONDUCTIVIDAD   AÑO  MES  \
# 0  DANBRED              10       20.299999           10.6  2020    1
# 1  DANBRED              22       20.500000           10.7  2020    1
# 2  DANBRED              48       20.299999           10.4  2020    1
# 3  DANBRED              11       20.500000           10.5  2020    1
# 4  DANBRED              17       20.200001           10.4  2020    1
#
#    DOSIS_REAL_y  PRODUCTIVO
# 0            18           0
# 1            18           0
# 2            18           0
# 3            18           0
# 4            18           0

# %%
merged['PRODUCTIVO'].value_counts()
# Out:
# 1    78700
# 0    74999
# Name: PRODUCTIVO, dtype: int64

# %% [markdown]
# **Del data frame de VERRACOS no nos interesa toda la información existente. Me creo un dataframe que posteriormente uniremos a "datos_modelo", base de datos que será la fuente de información para el modelo. Así mismo, del dataframe de EYACULADOS no nos interesa toda la información**

# %%
small_verracos = verracos.loc[:, ['LINEA_GEN', 'CODIGO', 'PROCEDENCIA']]
small_eyaculados = merged.loc[:, ['COD_VERRACO', 'CENTRO', 'DOSIS_REAL_x', 'RAZA', 'AÑO', 'DOSIS_REAL_y', 'PRODUCTIVO']]

# %%
datos_modelo = pd.merge(small_eyaculados, small_verracos, left_on='COD_VERRACO', right_on='CODIGO', how='outer')

# %%
datos_modelo.head()
# Out:
#    COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 0       2095.0    CAL          10.0  DANBRED  2020.0          18.0
# 1       2095.0    CAL          22.0  DANBRED  2020.0          18.0
# 2       2095.0    CAL          48.0  DANBRED  2020.0          18.0
# 3       2095.0    CAL          11.0  DANBRED  2020.0          18.0
# 4       2095.0    CAL          17.0  DANBRED  2020.0          18.0
#
#    PRODUCTIVO LINEA_GEN  CODIGO                        PROCEDENCIA
# 0         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 1         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 2         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 3         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 4         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE

# %%
datos_modelo.shape
# Out:
# (154216, 10)

# %% [markdown]
# ## PREPROCESAMIENTO - ANÁLISI Y LIMPIEZA

# %% [markdown]
# **Una vez seleccionado y calculado los datos necesarios para el correcto funcionamiento del modelo, procedo a hacer la correspondiente limpieza de datos en busca de valores NaN, NaT o valores carentes de sentido**

# %%
datos_modelo.shape
# Out:
# (154216, 10)

# %%
print(datos_modelo.isnull().sum().sum())
# Out:
# 45218

# %% [markdown]
# **Existe un total de 45.218 valores NaN, voy a localizar dónde están exactamente:**

# %%
datos_modelo.isnull().sum()
# Out:
# COD_VERRACO       517
# CENTRO            517
# DOSIS_REAL_x      517
# RAZA             1091
# AÑO               517
# DOSIS_REAL_y      517
# PRODUCTIVO        517
# LINEA_GEN       20952
# CODIGO            214
# PROCEDENCIA     19859
# dtype: int64

# %% [markdown]
# **Como tanto en CODIGO como en COD_VERRACO existen valores nulos siendo estos verracos sin código asignado, los elimino directamente. Son verracos a los que no se les puede realizar un seguimiento.**

# %%
datos_modelo = datos_modelo.dropna(subset=["COD_VERRACO"])
datos_modelo = datos_modelo.dropna(subset=["CODIGO"])

# %%
datos_modelo.isnull().sum()
# Out:
# COD_VERRACO         0
# CENTRO              0
# DOSIS_REAL_x        0
# RAZA              574
# AÑO                 0
# DOSIS_REAL_y        0
# PRODUCTIVO          0
# LINEA_GEN       20246
# CODIGO              0
# PROCEDENCIA     19391
# dtype: int64

# %% [markdown]
# **Al ser variables categóricas (y no poder asignar la media de los valores de los verracos semejantes, por ejemplo) he decidido eliminar los NaN restantes**

# %%
datos_modelo = datos_modelo.dropna(subset=["LINEA_GEN"])
datos_modelo = datos_modelo.dropna(subset=["PROCEDENCIA"])
datos_modelo = datos_modelo.dropna(subset=["RAZA"])

# %%
datos_modelo.isnull().sum()
# Out:
# COD_VERRACO     0
# CENTRO          0
# DOSIS_REAL_x    0
# RAZA            0
# AÑO             0
# DOSIS_REAL_y    0
# PRODUCTIVO      0
# LINEA_GEN       0
# CODIGO          0
# PROCEDENCIA     0
# dtype: int64

# %%
print(datos_modelo.shape)
print(datos_modelo.isnull().sum().sum())
# Out:
# (115101, 10)
# 0

# %%
datos_modelo.head()
# Out:
#    COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 0       2095.0    CAL          10.0  DANBRED  2020.0          18.0
# 1       2095.0    CAL          22.0  DANBRED  2020.0          18.0
# 2       2095.0    CAL          48.0  DANBRED  2020.0          18.0
# 3       2095.0    CAL          11.0  DANBRED  2020.0          18.0
# 4       2095.0    CAL          17.0  DANBRED  2020.0          18.0
#
#    PRODUCTIVO LINEA_GEN  CODIGO                        PROCEDENCIA
# 0         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 1         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 2         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 3         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 4         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE

# %% [markdown]
# **Una vez eliminados los NaN, se analizan particularidades**

# %%
datos_modelo['CENTRO'].value_counts()
# Out:
# CAL      75155
# PEÑAS    36165
# TOL       3781
# Name: CENTRO, dtype: int64

# %% [markdown]
# **Nada mal en CENTRO**

# %%
datos_modelo['RAZA'].value_counts()
# Out:
# 0             23941
# DANBRED       21051
# AND            8513
# PIETUPBNN      6542
# PIETUPBJJ      6423
# PAC            5417
# TDDDD          5349
# DUPIC          5152
# PIETUPB        3967
# TEEEE          3595
# DNA            2050
# PIETAXIOM      1989
# DURGENES       1759
# AGSG           1725
# TLLLL          1635
# ADN            1583
# TUUUUIBE       1247
# TVVVV          1173
# DCAXIOM         999
# LDAX            989
# TPPNP           875
# TPPPPTOP        871
# BLUEACMC        779
# TDDPP           698
# LWAX            631
# LDADN           548
# PIETUPBFR       492
# PI ALEM NP      464
# TIIII           451
# DCADN           428
# IBERICO         396
# TUUUU           294
# TPPPPELI        276
# LWADN           261
# TZZZZGGP        236
# MAXSEG          230
# DURGENMJJ       223
# DURGENG         222
# ADNREK          221
# DURGENM         205
# TAAAAGGP        199
# DURGENESM       165
# L65P+           142
# LWACMC          127
# TUUUUEFI        116
# TZZZZ           111
# PACCAR          100
# PIETSERGAL       87
# TUUUUCAL         87
# TUUUUGGP         30
# TPPNN            22
# TDDDDTOP         10
# TAAAA             3
# -                 1
# DAN-INGA          1
# Name: RAZA, dtype: int64

# %% [markdown]
# **Hay una RAZA denominada '-' y otra con nombre '0'. Elimino ambas**

# %%
datos_modelo[datos_modelo['RAZA'] == '-']
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x RAZA     AÑO  DOSIS_REAL_y  \
# 35099       2484.0    TOL          13.0    -  2019.0          88.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO    PROCEDENCIA
# 35099         1.0     TDDPP  2484.0  GRANJA ZAHARA

# %%
datos_modelo[datos_modelo['RAZA'] == 0].head()
# Out:
#      COD_VERRACO CENTRO  DOSIS_REAL_x RAZA     AÑO  DOSIS_REAL_y  PRODUCTIVO  \
# 906       1872.0  PEÑAS          18.0    0  2015.0          61.0         0.0
# 907       1872.0  PEÑAS          24.0    0  2015.0          61.0         0.0
# 908       1872.0  PEÑAS          38.0    0  2015.0          61.0         0.0
# 909       1872.0  PEÑAS          31.0    0  2015.0          61.0         0.0
# 910       1872.0  PEÑAS          10.0    0  2015.0          61.0         0.0
#
#     LINEA_GEN  CODIGO  PROCEDENCIA
# 906   DANBRED  1872.0  DESCONOCIDA
# 907   DANBRED  1872.0  DESCONOCIDA
# 908   DANBRED  1872.0  DESCONOCIDA
# 909   DANBRED  1872.0  DESCONOCIDA
# 910   DANBRED  1872.0  DESCONOCIDA

# %%
datos_modelo = datos_modelo.drop(datos_modelo[datos_modelo['RAZA'] == '-'].index, axis=0)
datos_modelo = datos_modelo.drop(datos_modelo[datos_modelo['RAZA'] == 0].index, axis=0)

# %%
datos_modelo['RAZA'].value_counts()
# Out:
# DANBRED       21051
# AND            8513
# PIETUPBNN      6542
# PIETUPBJJ      6423
# PAC            5417
# TDDDD          5349
# DUPIC          5152
# PIETUPB        3967
# TEEEE          3595
# DNA            2050
# PIETAXIOM      1989
# DURGENES       1759
# AGSG           1725
# TLLLL          1635
# ADN            1583
# TUUUUIBE       1247
# TVVVV          1173
# DCAXIOM         999
# LDAX            989
# TPPNP           875
# TPPPPTOP        871
# BLUEACMC        779
# TDDPP           698
# LWAX            631
# LDADN           548
# PIETUPBFR       492
# PI ALEM NP      464
# TIIII           451
# DCADN           428
# IBERICO         396
# TUUUU           294
# TPPPPELI        276
# LWADN           261
# TZZZZGGP        236
# MAXSEG          230
# DURGENMJJ       223
# DURGENG         222
# ADNREK          221
# DURGENM         205
# TAAAAGGP        199
# DURGENESM       165
# L65P+           142
# LWACMC          127
# TUUUUEFI        116
# TZZZZ           111
# PACCAR          100
# TUUUUCAL         87
# PIETSERGAL       87
# TUUUUGGP         30
# TPPNN            22
# TDDDDTOP         10
# TAAAA             3
# DAN-INGA          1
# Name: RAZA, dtype: int64

# %%
datos_modelo.shape
# Out:
# (91159, 10)

# %% [markdown]
# **Eliminados los valores extraños en RAZA**

# %%
print(datos_modelo['DOSIS_REAL_x'].min())
print(datos_modelo['DOSIS_REAL_x'].max())
# Out:
# 0.0
# 122.0

# %%
datos_modelo['DOSIS_REAL_x'].unique()
# Out:
# array([ 10.,  22.,  48.,  11.,  17.,  18.,  32.,  14.,   0.,  25.,  23.,
#         21.,  33.,  58.,  15.,  43.,  12.,  13.,  70.,  24.,  28.,  36.,
#         41.,  57.,  38.,  26.,  16.,  51.,  37.,   6.,  39.,  20.,   8.,
#          9.,  19.,   5.,  34.,  47.,  31.,  27.,  29.,  42.,  52.,  30.,
#         44.,  40.,  66.,  50.,  71.,  55.,  45.,  68.,  35.,   4.,  74.,
#         59.,  53.,   3.,  67.,  80.,  61.,  64.,  54.,  63.,  90.,  62.,
#         60.,  65.,  88.,  49.,  46.,   7.,   2.,  56.,  69.,  76.,  75.,
#         84.,  85.,  82.,  72.,  73.,  89.,  87.,  86.,  96.,  79.,  98.,
#         77.,  83.,  78.,  91.,  95.,  92.,  94., 111., 101.,  93.,  81.,
#        100., 106., 103.,  97., 110., 107., 102., 109.,  99., 122., 114.,
#          1.])

# %%
datos_modelo['DOSIS_REAL_x'].unique()
# Out:
# array([ 10.,  22.,  48.,  11.,  17.,  18.,  32.,  14.,   0.,  25.,  23.,
#         21.,  33.,  58.,  15.,  43.,  12.,  13.,  70.,  24.,  28.,  36.,
#         41.,  57.,  38.,  26.,  16.,  51.,  37.,   6.,  39.,  20.,   8.,
#          9.,  19.,   5.,  34.,  47.,  31.,  27.,  29.,  42.,  52.,  30.,
#         44.,  40.,  66.,  50.,  71.,  55.,  45.,  68.,  35.,   4.,  74.,
#         59.,  53.,   3.,  67.,  80.,  61.,  64.,  54.,  63.,  90.,  62.,
#         60.,  65.,  88.,  49.,  46.,   7.,   2.,  56.,  69.,  76.,  75.,
#         84.,  85.,  82.,  72.,  73.,  89.,  87.,  86.,  96.,  79.,  98.,
#         77.,  83.,  78.,  91.,  95.,  92.,  94., 111., 101.,  93.,  81.,
#        100., 106., 103.,  97., 110., 107., 102., 109.,  99., 122., 114.,
#          1.])

# %% [markdown]
# **Todo bien en DOSIS_REAL_x**

# %%
print(datos_modelo['AÑO'].min())
print(datos_modelo['AÑO'].max())
# Out:
# 2016.0
# 2021.0

# %%
datos_modelo['AÑO'].unique()
# Out:
# array([2020., 2019., 2018., 2017., 2016., 2021.])

# %%
datos_modelo['PRODUCTIVO'].value_counts()
# Out:
# 1.0    46900
# 0.0    44259
# Name: PRODUCTIVO, dtype: int64

# %%
datos_modelo['PRODUCTIVO'].unique()
# Out:
# array([0., 1.])

# %% [markdown]
# **Todo bien en AÑO y PRODUCTIVO**

# %%
datos_modelo['LINEA_GEN'].value_counts()
# Out:
# DANBRED      27043
# PIETUPB      17069
# PAC           5517
# TDDDD         5359
# DUPIC         5152
# TEEEE         3595
# AND           3498
# PTAXIOM       2576
# DURGEN        2574
# DNA           2224
# TPPPP         2044
# TUUUU         1774
# TLLLL         1635
# LDAX          1299
# TVVVV         1173
# DURAXIOM      1045
# PTADN          994
# BLUEACMC       779
# TIIII          738
# TDDPP          698
# LWAX           650
# AGSG           574
# PTALE          464
# DURADN         382
# PIETUPBFR      355
# TZZZZ          347
# LWADN          242
# LDADN          238
# MAXSEG         230
# ADNREK         221
# TAAAA          202
# L65            142
# LWACMC         127
# IBERICO        109
# PTSER           87
# PIETRAIN         3
# Name: LINEA_GEN, dtype: int64

# %% [markdown]
# **Todo bien en cuanto a GENÉTICA**

# %%
datos_modelo['PROCEDENCIA'].value_counts()
# Out:
# QUALITAT ESPERMATICA                                  6601
# BURUTAIN                                              4834
# DESCONOCIDA                                           3549
# TAFALLA                                               3264
# EXPLOTACIONES CUFA                                    2796
# PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE HOL    2558
# GENESUS INC OAKVILLE MB ID NO 5326121                 2338
# GRUPO ALTOPASO A CORUÑA                               2112
# CAN JAUMO                                             1883
# ESCORIAL                                              1838
# LA COMETA                                             1747
# AIM LEON                                              1688
# DESCONOCIDO                                           1683
# ZAHARA                                                1669
# FUGLSANG DENMARK 4160 HERLUFMAGLE                     1660
# NAVARRA                                               1525
# MAS GALLAT                                            1519
# USA                                                   1513
# FINA MARKUS AM LAUBENBUCH 2 ALEMANIA                  1416
# LA MASIA                                              1403
# NEHER STEPHAN DORFSTR 16 ALEMANIA                     1268
# HASTRUPGARD HASTRUPGARDSVEJ 8 7000 FREDERICIA DK      1262
# LIPPERT NORBERT AURAER STR 1 ALEMANIA                 1188
# PEÑAS DE SAN PEDRO                                    1180
# UPB GENETIC                                           1148
# QUALITAT                                              1026
# SCHWARZ WOLFGANG BACHT STR 14 ALEMANIA                1024
# GRUPO ALTOPASO A CORUÑA ES150800089301                 971
# EL ESCORIAL                                            951
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ  DENMARK         939
# BUJARALOZ                                              931
# MAALING AVL OG OPFORMERING SKELDEMARG 10 DENMARK       879
# COMETA                                                 879
# KERNEIS KERINOU LE CONQUET 29217 FRANCIA               818
# ELTZABURU                                              779
# ACOMPOR                                                748
# KUGEL GEORG MAUERNER STR 23A ALEMANIA                  740
# GRANJA ZAHARA                                          734
# MUNKBRO II MUNKBROVEJ 7 7500 HOLSTEBRO DENMARK         716
# ECKARDT BERND GBR HOHNWEG 14 ALEMANIA                  702
# HASTRUPGARD, HASTRUPGARDSVEJ 7000 FREDERICIA DENMA     691
# TOJAPIGS SARL DROMBAS DROMBAS FRANCE                   683
# AVLSCENTRET HOLMEGARD A/S, FALDSLEDVEJ FABORG DK       677
# AIM ANDALUCIA                                          673
# ROHWER TIMO LOOPER WEG 19 24589 SCHULP ALEMANIA        653
# AIM PEÑAS                                              605
# NAVALAGAMELLA                                          600
# VAN DE PEUT B.V.                                       592
# LYKKENSGAARD AVLSCENTER ELLEDEVEJ 95 DENMARK           571
# GRANJA ZAHARA TOLEDO ESPAÑA                            540
# ROHWER JURGEN BOKELER STR 5 24793 BRAMMER ALEMANIA     540
# SCWARZ WOLFGANG BACHSTR 14 SALCHING ALEMANIA           539
# TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA          537
# TOM RATHJE COLUMBUS NEBRASKA USA                       501
# ELEVAGE DE BIZY OUZOUER LE MARCHE 41240 FRANCIA        500
# SINOVAS                                                492
# ALBAGES                                                475
# AIM ANDALUCÍA                                          470
# EXPLOTACIONES CUFA SL                                  420
# LEON                                                   418
# GRANJA ALTOPASO SOBRADO DE LOS MONJES A CORUÑA         384
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ DENMARK          377
# LA ALMOLDA                                             364
# GUMPP HERMANN KIRCHPLATZ 1, 89420 DEISENFOFEN ALEM     362
# UPB GENETIC WORLD                                      355
# LL. TANKEDAL DENMARK 6580 VANDRUP                      353
# ODARPI GENETICA VILLADIEGO                             342
# BEUNZA                                                 336
# JOSSE PASCAL LE POURCAUD AUGAN FRANCE                  334
# AIM SINOVAS                                            321
# GANADOS PERALTA S.L                                    313
# HORIZON CERAN LE FROMENTEAU CERANS FOULLETOURTE FR     309
# ALMUDEVAR                                              288
# ERTL JOHANNES GROSSHUNDLBACH 12 ALEMANIA               286
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN ALEMANIA               285
# AIM CENTRO                                             281
# GRANJA ALTOPASO  A CORUÑA SPAIN                        277
# UPB GENETICA                                           276
# ATEZ                                                   253
# EXPLTACIONES CUFA                                      250
# PETERSEN HANS DETLEF SUEDER  VOLSEMENHUSEN ALEMANI     233
# VAN DE PEUT B.V                                        208
# INTEGRACIONES PERALTA                                  208
# AGER                                                   207
# DECONOCIDO                                             204
# VOLSGAARDI DAMSTRUPVEJ ORNHOJ DENMARK                  203
# KERDANET                                               202
# QIALITAT ESPERMATICA                                   196
# LE BARON CHRISTIAN PEN LAN KERDAVID LE MOUSTOIR FR     191
# BERGSHOLM VIDAR N-3160 STOKKE NORUEGA                  189
# LA GARENNE 37310 AZAY-SUR-INDRE FRANCIA                174
# GRANJA ZAHARA (TOLEDO) ESPAÑA                          171
# FINA MARKUS AM LAUBNBUCH 2                             166
# GRANJA ZAHARA CERVERA TOLEDO ESPAÑA                    164
# ARANDA DE DUERO                                        164
# AIM SORIA                                              163
# FINA MARKUS AM LAUBENBUCH WEIBENBURG ALEMANIA          160
# EARL FERME DE LA VALLE 650 RUE DU PIRE ALLER FRANC     159
# ELEVAGE DE BIZY OUZOUERLE MARCHE FRANCE                154
# SANTENIS - C. CARRASCONES 12-2A - 45610 NAVALCAN T     151
# MAS EL CROS                                            147
# GAEC DES PORCS SAINS LA FOURBERIE GUIGNEN 35580        142
# SCHAAF-SCHELD GBR ARNSHAINER WEG 5 WAHLEN ALEMANIA     142
# MAALING III SLEVADVEJ 3 6560 SOMMERSTED DENMARK        134
# PEUT BV, VAN DE - BAARLOSEWEG 18 -  MARKNESS NETHE     134
# FINA MARKUS WEIBENBURG GERMANY                         131
# ODARPI VILLUSTO ESPAÑA                                 120
# ZAHARA CERVERA TOLEDO ESPAÑA                           107
# ATEZ (NAVARRA)                                         101
# SCEA PINIER-JOSSO KERBELAY MARZAN 56130 FRANCIA         98
# GANADERA MONEGRO                                        97
# ESKEGAARD A/S MOLLEGYDE HADERSLEV DENMARK               95
# EARL ARMANE LE BOIS CLAIR EVAILLE 72120 FRANCIA         95
# QUALITA ESPERMATICA                                     92
# CHANTELOUP                                              91
# ES5010370130002-00864                                   89
# VAN DE PEUT B.B.                                        87
# CASETA SANTASUSANA SAN MATEU DE BAGES                   85
# CAN CARRERAS                                            84
# ELEVAGE DE BIZY OUZOUER LE MARCHE FRANCE                84
# LIPPERT NORBERT EUERDORF GERMANY                        79
# PEÑAS DE SAN PÈDRO                                      78
# JULE TOR HENRIK - - - - 7710 SPARBU - - NORWAY          78
# QUALITAT ESPERMÁTICA                                    75
# KERBELAY (MARZAN)                                       75
# FINA MARKUS AM LAUBENBUCH 2 WEIBENBURG ALEMANIA         72
# SANTIBAÑEZ                                              70
# BIURRUN                                                 70
# KERNEIS KERINOU LE CONQUET FRANCE                       69
# KÜGEL GEORG MAUERNER STR PFÖRRING ALEMANIA              68
# TOJAPIGS SARL DOMBRAS - 1, RUE NAPOLEON - -FRANCE       63
# GRANJA ZAHARA TOLEDO SPAIN                              61
# TOPIGS NORSVIN ESPAÑA                                   61
# BERGSHOLM VIDAR N 3160 STOKKE NORUEGA                   46
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN GERMANY                 39
# EARL FERME DE LA VALLEE HERBINGHEM FRANCE               37
# SCHWARZ WOLFGANG SALCHING GERMANY                       35
# KUGEL GEORG PFORRING GERMANY                            34
# ALMOLDA                                                 31
# ERTL JOHANNES FRAUNBERG GERMANY                         28
# ECKARDT BEECKARDT BERND SONNEFELD GERMANY               21
# SCHWARZ WOLFGANG BACHSTR SALCHING GERMANY               19
# GUMPP HERMANN DEISENHOFEN GERMANY                       19
# EARL DARTOIS BEAUCHENE GUITE FRANCE                     17
# INGA FOOD SA ALMENDRALEJO BADAJOZ                       16
# SAS ADN (MAIGRIS)                                       14
# SCHAAF-SCHELD ARNSHAINER KIRTORF-WAHLEN GERMANY         12
# SANTENIS NAVALCAN TOLEDO SPAIN                          11
# GUMPP HERMANN KIRCHPLATZ 1 DEISENHOFEN GERMANY          10
# BARCELONA                                                9
# ECKARDT BERND HOHNWEG 14 SONNFELD GERMANY                8
# FINA MARKUS AM LAUBENBUCH WEIBENBURG GERMANY             6
# ECKARDT BERND SONNEFELD GERMANY                          4
# Name: PROCEDENCIA, dtype: int64

# %% [markdown]
# **Se puede apreciar tres PROCEDENCIAS iguales con distinto nombre: DESCONOCIDO, DESCONOCIDA, DECONOCIDA**

# %%
datos_modelo[datos_modelo['PROCEDENCIA'] == 'DESCONOCIDO'].head()
# Out:
#       COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 4202       2326.0    CAL          26.0  DANBRED  2020.0          58.0
# 4203       2326.0    CAL          16.0  DANBRED  2020.0          58.0
# 4204       2326.0    CAL          20.0  DANBRED  2020.0          58.0
# 4205       2326.0    CAL          27.0  DANBRED  2020.0          58.0
# 4206       2326.0    CAL          28.0  DANBRED  2020.0          58.0
#
#       PRODUCTIVO LINEA_GEN  CODIGO  PROCEDENCIA
# 4202         0.0   DANBRED  2326.0  DESCONOCIDO
# 4203         0.0   DANBRED  2326.0  DESCONOCIDO
# 4204         0.0   DANBRED  2326.0  DESCONOCIDO
# 4205         0.0   DANBRED  2326.0  DESCONOCIDO
# 4206         0.0   DANBRED  2326.0  DESCONOCIDO

# %%
datos_modelo[datos_modelo['PROCEDENCIA'] == 'DESCONOCIDA'].head()
# Out:
#      COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 433       1872.0    CAL           9.0  DANBRED  2020.0          11.0
# 434       1872.0    CAL          31.0  DANBRED  2020.0          11.0
# 435       1872.0    CAL           4.0  DANBRED  2020.0          11.0
# 436       1872.0    CAL          26.0  DANBRED  2020.0          11.0
# 437       1872.0    CAL          19.0  DANBRED  2020.0          11.0
#
#      PRODUCTIVO LINEA_GEN  CODIGO  PROCEDENCIA
# 433         0.0   DANBRED  1872.0  DESCONOCIDA
# 434         0.0   DANBRED  1872.0  DESCONOCIDA
# 435         0.0   DANBRED  1872.0  DESCONOCIDA
# 436         0.0   DANBRED  1872.0  DESCONOCIDA
# 437         0.0   DANBRED  1872.0  DESCONOCIDA

# %%
datos_modelo[datos_modelo['PROCEDENCIA'] == 'DECONOCIDO'].head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 12927       2421.0  PEÑAS          21.0  DANBRED  2020.0          30.0
# 12928       2421.0  PEÑAS          30.0  DANBRED  2020.0          30.0
# 12929       2421.0  PEÑAS          16.0  DANBRED  2020.0          30.0
# 12930       2421.0  PEÑAS          21.0  DANBRED  2020.0          30.0
# 12931       2421.0  PEÑAS          25.0  DANBRED  2020.0          30.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO PROCEDENCIA
# 12927         0.0   DANBRED  2421.0  DECONOCIDO
# 12928         0.0   DANBRED  2421.0  DECONOCIDO
# 12929         0.0   DANBRED  2421.0  DECONOCIDO
# 12930         0.0   DANBRED  2421.0  DECONOCIDO
# 12931         0.0   DANBRED  2421.0  DECONOCIDO

# %% [markdown]
# **Se sustituyen los valores "DESCONOCIDO" y "DECONOCIDO" por el valor "DESCONOCIDA"**

# %%
datos_modelo['PROCEDENCIA'] = np.where(datos_modelo['PROCEDENCIA'] == 'DESCONOCIDO', datos_modelo['PROCEDENCIA'] == 'DESCONOCIDA', datos_modelo['PROCEDENCIA'])
datos_modelo['PROCEDENCIA'] = np.where(datos_modelo['PROCEDENCIA'] == 'DECONOCIDO', datos_modelo['PROCEDENCIA'] == 'DESCONOCIDA', datos_modelo['PROCEDENCIA'])

# %%
datos_modelo['PROCEDENCIA'].value_counts()
# Out:
# QUALITAT ESPERMATICA                                  6601
# BURUTAIN                                              4834
# DESCONOCIDA                                           3549
# TAFALLA                                               3264
# EXPLOTACIONES CUFA                                    2796
# PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE HOL    2558
# GENESUS INC OAKVILLE MB ID NO 5326121                 2338
# GRUPO ALTOPASO A CORUÑA                               2112
# False                                                 1887
# CAN JAUMO                                             1883
# ESCORIAL                                              1838
# LA COMETA                                             1747
# AIM LEON                                              1688
# ZAHARA                                                1669
# FUGLSANG DENMARK 4160 HERLUFMAGLE                     1660
# NAVARRA                                               1525
# MAS GALLAT                                            1519
# USA                                                   1513
# FINA MARKUS AM LAUBENBUCH 2 ALEMANIA                  1416
# LA MASIA                                              1403
# NEHER STEPHAN DORFSTR 16 ALEMANIA                     1268
# HASTRUPGARD HASTRUPGARDSVEJ 8 7000 FREDERICIA DK      1262
# LIPPERT NORBERT AURAER STR 1 ALEMANIA                 1188
# PEÑAS DE SAN PEDRO                                    1180
# UPB GENETIC                                           1148
# QUALITAT                                              1026
# SCHWARZ WOLFGANG BACHT STR 14 ALEMANIA                1024
# GRUPO ALTOPASO A CORUÑA ES150800089301                 971
# EL ESCORIAL                                            951
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ  DENMARK         939
# BUJARALOZ                                              931
# COMETA                                                 879
# MAALING AVL OG OPFORMERING SKELDEMARG 10 DENMARK       879
# KERNEIS KERINOU LE CONQUET 29217 FRANCIA               818
# ELTZABURU                                              779
# ACOMPOR                                                748
# KUGEL GEORG MAUERNER STR 23A ALEMANIA                  740
# GRANJA ZAHARA                                          734
# MUNKBRO II MUNKBROVEJ 7 7500 HOLSTEBRO DENMARK         716
# ECKARDT BERND GBR HOHNWEG 14 ALEMANIA                  702
# HASTRUPGARD, HASTRUPGARDSVEJ 7000 FREDERICIA DENMA     691
# TOJAPIGS SARL DROMBAS DROMBAS FRANCE                   683
# AVLSCENTRET HOLMEGARD A/S, FALDSLEDVEJ FABORG DK       677
# AIM ANDALUCIA                                          673
# ROHWER TIMO LOOPER WEG 19 24589 SCHULP ALEMANIA        653
# AIM PEÑAS                                              605
# NAVALAGAMELLA                                          600
# VAN DE PEUT B.V.                                       592
# LYKKENSGAARD AVLSCENTER ELLEDEVEJ 95 DENMARK           571
# ROHWER JURGEN BOKELER STR 5 24793 BRAMMER ALEMANIA     540
# GRANJA ZAHARA TOLEDO ESPAÑA                            540
# SCWARZ WOLFGANG BACHSTR 14 SALCHING ALEMANIA           539
# TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA          537
# TOM RATHJE COLUMBUS NEBRASKA USA                       501
# ELEVAGE DE BIZY OUZOUER LE MARCHE 41240 FRANCIA        500
# SINOVAS                                                492
# ALBAGES                                                475
# AIM ANDALUCÍA                                          470
# EXPLOTACIONES CUFA SL                                  420
# LEON                                                   418
# GRANJA ALTOPASO SOBRADO DE LOS MONJES A CORUÑA         384
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ DENMARK          377
# LA ALMOLDA                                             364
# GUMPP HERMANN KIRCHPLATZ 1, 89420 DEISENFOFEN ALEM     362
# UPB GENETIC WORLD                                      355
# LL. TANKEDAL DENMARK 6580 VANDRUP                      353
# ODARPI GENETICA VILLADIEGO                             342
# BEUNZA                                                 336
# JOSSE PASCAL LE POURCAUD AUGAN FRANCE                  334
# AIM SINOVAS                                            321
# GANADOS PERALTA S.L                                    313
# HORIZON CERAN LE FROMENTEAU CERANS FOULLETOURTE FR     309
# ALMUDEVAR                                              288
# ERTL JOHANNES GROSSHUNDLBACH 12 ALEMANIA               286
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN ALEMANIA               285
# AIM CENTRO                                             281
# GRANJA ALTOPASO  A CORUÑA SPAIN                        277
# UPB GENETICA                                           276
# ATEZ                                                   253
# EXPLTACIONES CUFA                                      250
# PETERSEN HANS DETLEF SUEDER  VOLSEMENHUSEN ALEMANI     233
# VAN DE PEUT B.V                                        208
# INTEGRACIONES PERALTA                                  208
# AGER                                                   207
# VOLSGAARDI DAMSTRUPVEJ ORNHOJ DENMARK                  203
# KERDANET                                               202
# QIALITAT ESPERMATICA                                   196
# LE BARON CHRISTIAN PEN LAN KERDAVID LE MOUSTOIR FR     191
# BERGSHOLM VIDAR N-3160 STOKKE NORUEGA                  189
# LA GARENNE 37310 AZAY-SUR-INDRE FRANCIA                174
# GRANJA ZAHARA (TOLEDO) ESPAÑA                          171
# FINA MARKUS AM LAUBNBUCH 2                             166
# ARANDA DE DUERO                                        164
# GRANJA ZAHARA CERVERA TOLEDO ESPAÑA                    164
# AIM SORIA                                              163
# FINA MARKUS AM LAUBENBUCH WEIBENBURG ALEMANIA          160
# EARL FERME DE LA VALLE 650 RUE DU PIRE ALLER FRANC     159
# ELEVAGE DE BIZY OUZOUERLE MARCHE FRANCE                154
# SANTENIS - C. CARRASCONES 12-2A - 45610 NAVALCAN T     151
# MAS EL CROS                                            147
# GAEC DES PORCS SAINS LA FOURBERIE GUIGNEN 35580        142
# SCHAAF-SCHELD GBR ARNSHAINER WEG 5 WAHLEN ALEMANIA     142
# PEUT BV, VAN DE - BAARLOSEWEG 18 -  MARKNESS NETHE     134
# MAALING III SLEVADVEJ 3 6560 SOMMERSTED DENMARK        134
# FINA MARKUS WEIBENBURG GERMANY                         131
# ODARPI VILLUSTO ESPAÑA                                 120
# ZAHARA CERVERA TOLEDO ESPAÑA                           107
# ATEZ (NAVARRA)                                         101
# SCEA PINIER-JOSSO KERBELAY MARZAN 56130 FRANCIA         98
# GANADERA MONEGRO                                        97
# EARL ARMANE LE BOIS CLAIR EVAILLE 72120 FRANCIA         95
# ESKEGAARD A/S MOLLEGYDE HADERSLEV DENMARK               95
# QUALITA ESPERMATICA                                     92
# CHANTELOUP                                              91
# ES5010370130002-00864                                   89
# VAN DE PEUT B.B.                                        87
# CASETA SANTASUSANA SAN MATEU DE BAGES                   85
# CAN CARRERAS                                            84
# ELEVAGE DE BIZY OUZOUER LE MARCHE FRANCE                84
# LIPPERT NORBERT EUERDORF GERMANY                        79
# PEÑAS DE SAN PÈDRO                                      78
# JULE TOR HENRIK - - - - 7710 SPARBU - - NORWAY          78
# QUALITAT ESPERMÁTICA                                    75
# KERBELAY (MARZAN)                                       75
# FINA MARKUS AM LAUBENBUCH 2 WEIBENBURG ALEMANIA         72
# BIURRUN                                                 70
# SANTIBAÑEZ                                              70
# KERNEIS KERINOU LE CONQUET FRANCE                       69
# KÜGEL GEORG MAUERNER STR PFÖRRING ALEMANIA              68
# TOJAPIGS SARL DOMBRAS - 1, RUE NAPOLEON - -FRANCE       63
# GRANJA ZAHARA TOLEDO SPAIN                              61
# TOPIGS NORSVIN ESPAÑA                                   61
# BERGSHOLM VIDAR N 3160 STOKKE NORUEGA                   46
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN GERMANY                 39
# EARL FERME DE LA VALLEE HERBINGHEM FRANCE               37
# SCHWARZ WOLFGANG SALCHING GERMANY                       35
# KUGEL GEORG PFORRING GERMANY                            34
# ALMOLDA                                                 31
# ERTL JOHANNES FRAUNBERG GERMANY                         28
# ECKARDT BEECKARDT BERND SONNEFELD GERMANY               21
# SCHWARZ WOLFGANG BACHSTR SALCHING GERMANY               19
# GUMPP HERMANN DEISENHOFEN GERMANY                       19
# EARL DARTOIS BEAUCHENE GUITE FRANCE                     17
# INGA FOOD SA ALMENDRALEJO BADAJOZ                       16
# SAS ADN (MAIGRIS)                                       14
# SCHAAF-SCHELD ARNSHAINER KIRTORF-WAHLEN GERMANY         12
# SANTENIS NAVALCAN TOLEDO SPAIN                          11
# GUMPP HERMANN KIRCHPLATZ 1 DEISENHOFEN GERMANY          10
# BARCELONA                                                9
# ECKARDT BERND HOHNWEG 14 SONNFELD GERMANY                8
# FINA MARKUS AM LAUBENBUCH WEIBENBURG GERMANY             6
# ECKARDT BERND SONNEFELD GERMANY                          4
# Name: PROCEDENCIA, dtype: int64

# %% [markdown]
# # **FEATURE ENGINEERING**

# %%
datos_modelo.head()
# Out:
#    COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 0       2095.0    CAL          10.0  DANBRED  2020.0          18.0
# 1       2095.0    CAL          22.0  DANBRED  2020.0          18.0
# 2       2095.0    CAL          48.0  DANBRED  2020.0          18.0
# 3       2095.0    CAL          11.0  DANBRED  2020.0          18.0
# 4       2095.0    CAL          17.0  DANBRED  2020.0          18.0
#
#    PRODUCTIVO LINEA_GEN  CODIGO                        PROCEDENCIA
# 0         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 1         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 2         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 3         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 4         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE

# %%
datos_modelo.shape
# Out:
# (91159, 10)

# %% [markdown]
# **CENTRO, RAZA, LINEA_GEN y PROCEDENCIA son variables categóricas las cuales han de ser codificadas para poder introducirlas como parámetros al modelo. Para ello, utilizaré la técninca de Target Encoding.**

# %% [markdown]
# **¡Importante! Target Encoding se realiza solo sobre el conjunto de train. El algoritmo tiene que ser capaz de, cuando se le pase una lista de razas, identificarlas, asignarle probabilidades y calcular su influencia en la productividad. Al algoritmo no se le va a introducir las razas ya codificadas, sino una lista con las diferentes razas nuevas existentes. Todo esto es aplicable al resto de variables categóricas**

# %%
train, test = train_test_split(datos_modelo, test_size=0.25)

# %%
train.shape, test.shape
# Out:
# ((68369, 10), (22790, 10))

# %%
datos_modelo['RAZA'].value_counts()
# Out:
# DANBRED       21051
# AND            8513
# PIETUPBNN      6542
# PIETUPBJJ      6423
# PAC            5417
# TDDDD          5349
# DUPIC          5152
# PIETUPB        3967
# TEEEE          3595
# DNA            2050
# PIETAXIOM      1989
# DURGENES       1759
# AGSG           1725
# TLLLL          1635
# ADN            1583
# TUUUUIBE       1247
# TVVVV          1173
# DCAXIOM         999
# LDAX            989
# TPPNP           875
# TPPPPTOP        871
# BLUEACMC        779
# TDDPP           698
# LWAX            631
# LDADN           548
# PIETUPBFR       492
# PI ALEM NP      464
# TIIII           451
# DCADN           428
# IBERICO         396
# TUUUU           294
# TPPPPELI        276
# LWADN           261
# TZZZZGGP        236
# MAXSEG          230
# DURGENMJJ       223
# DURGENG         222
# ADNREK          221
# DURGENM         205
# TAAAAGGP        199
# DURGENESM       165
# L65P+           142
# LWACMC          127
# TUUUUEFI        116
# TZZZZ           111
# PACCAR          100
# TUUUUCAL         87
# PIETSERGAL       87
# TUUUUGGP         30
# TPPNN            22
# TDDDDTOP         10
# TAAAA             3
# DAN-INGA          1
# Name: RAZA, dtype: int64

# %% [markdown]
# **Como se puede apreciar en la lista arriba mostrada, de las razas TAAAA y DAN-INGA solo existen 3 y 1 verracos respectivamente. Las conclusiones que se obtengan en base a la probabilidad de ser productivo en base a esas determinadas razas no van a ser muy fiables**

# %%
razas_encoded = train.groupby('RAZA')['PRODUCTIVO'].agg(['mean', 'count']).sort_values(by='count', ascending=False)
razas_encoded
# Out:
#                 mean  count
# RAZA
# DANBRED     0.712066  15830
# AND         0.720246   6352
# PIETUPBNN   0.336658   4913
# PIETUPBJJ   0.602652   4827
# PAC         0.243364   4031
# TDDDD       0.429643   4001
# DUPIC       0.557752   3896
# PIETUPB     0.524000   3000
# TEEEE       0.386055   2725
# DNA         0.855856   1554
# PIETAXIOM   0.340192   1458
# DURGENES    0.260138   1307
# AGSG        0.579891   1283
# TLLLL       0.660962   1227
# ADN         0.391881   1207
# TUUUUIBE    0.309245    941
# TVVVV       0.299889    897
# LDAX        0.171812    745
# DCAXIOM     0.644809    732
# TPPNP       0.334347    658
# TPPPPTOP    0.334351    655
# BLUEACMC    0.103203    562
# TDDPP       0.372137    524
# LWAX        0.450106    471
# LDADN       0.414508    386
# PIETUPBFR   0.000000    359
# PI ALEM NP  0.000000    352
# TIIII       0.000000    336
# DCADN       0.641026    312
# IBERICO     0.325424    295
# TUUUU       0.630631    222
# TPPPPELI    0.302326    215
# LWADN       0.346939    196
# TZZZZGGP    0.000000    176
# DURGENMJJ   0.119760    167
# MAXSEG      0.757576    165
# DURGENG     0.000000    163
# TAAAAGGP    0.000000    152
# ADNREK      0.000000    151
# DURGENM     0.271523    151
# DURGENESM   0.000000    132
# L65P+       0.000000    112
# LWACMC      0.000000     90
# TUUUUEFI    0.000000     90
# TZZZZ       0.000000     88
# PACCAR      0.000000     80
# TUUUUCAL    0.865672     67
# PIETSERGAL  0.000000     66
# TUUUUGGP    0.000000     23
# TPPNN       0.000000     16
# TDDDDTOP    0.000000      7
# TAAAA       0.000000      3
# DAN-INGA    1.000000      1

# %% [markdown]
# **El procedimiento a seguir para codificar las variables categóricas es el siguiente: se agrupan los datos por la variable categórica en cuestión, y se elabora la media de sus valores PRODUCTIVO. De esta forma, tendremos (en tanto por uno) la probabilidad de ser productivo en función a la variable categórica estudiada en cada caso. Además de la media, se realiza un conteo con el objetivo de analizar qué ocurre con aquellas RAZAS (en este primer caso) que no son muy habituales (poc frecuentes). Si hay las suficientes sería necesario estudiar una posible solución a ello. No ha sido el caso en este proyecto de Data Science**

# %%
razas_encoded = train.groupby('RAZA')['PRODUCTIVO'].mean()
razas_encoded = pd.DataFrame(razas_encoded)
razas_encoded.columns = ['RAZA_ENCODED']
razas_encoded.head()
# Out:
#           RAZA_ENCODED
# RAZA
# ADN           0.391881
# ADNREK        0.000000
# AGSG          0.579891
# AND           0.720246
# BLUEACMC      0.103203

# %%
centros_encoded = train.groupby(['CENTRO'])['PRODUCTIVO'].agg(['mean', 'count']).sort_values(by='count', ascending=False)
centros_encoded
# Out:
#             mean  count
# CENTRO
# CAL     0.419873  41122
# PEÑAS   0.690232  24796
# TOL     0.309262   2451

# %%
centros_encoded = train.groupby(['CENTRO'])['PRODUCTIVO'].mean()
centros_encoded = pd.DataFrame(centros_encoded)
centros_encoded = centros_encoded.rename(columns = {'PRODUCTIVO':'CENTRO_ENCODED'})
centros_encoded
# Out:
#         CENTRO_ENCODED
# CENTRO
# CAL           0.419873
# PEÑAS         0.690232
# TOL           0.309262

# %%
genetica_encoded = train.groupby(['LINEA_GEN'])['PRODUCTIVO'].agg(['mean', 'count']).sort_values(by='count', ascending=False)
genetica_encoded
# Out:
#                mean  count
# LINEA_GEN
# DANBRED    0.718685  20326
# PIETUPB    0.477767  12841
# PAC        0.238628   4111
# TDDDD      0.428892   4008
# DUPIC      0.557752   3896
# TEEEE      0.386055   2725
# AND        0.619490   2586
# DURGEN     0.208854   1920
# PTAXIOM    0.416885   1907
# DNA        0.852401   1687
# TPPPP      0.326425   1544
# TUUUU      0.364110   1343
# TLLLL      0.660962   1227
# LDAX       0.300000    960
# TVVVV      0.299889    897
# DURAXIOM   0.636601    765
# PTADN      0.229855    757
# BLUEACMC   0.103203    562
# TIIII      0.175182    548
# TDDPP      0.372137    524
# LWAX       0.438017    484
# AGSG       0.652381    420
# PTALE      0.000000    352
# DURADN     0.663082    279
# TZZZZ      0.000000    264
# PIETUPBFR  0.000000    258
# LWADN      0.371585    183
# LDADN      0.000000    171
# MAXSEG     0.757576    165
# TAAAA      0.000000    155
# ADNREK     0.000000    151
# L65        0.000000    112
# LWACMC     0.000000     90
# IBERICO    0.000000     83
# PTSER      0.000000     66
# PIETRAIN   0.000000      2

# %%
genetica_encoded = train.groupby(['LINEA_GEN'])['PRODUCTIVO'].mean()
genetica_encoded = pd.DataFrame(genetica_encoded)
genetica_encoded = genetica_encoded.rename(columns = {'PRODUCTIVO':'GENETICA_ENCODED'})
genetica_encoded
# Out:
#            GENETICA_ENCODED
# LINEA_GEN
# ADNREK             0.000000
# AGSG               0.652381
# AND                0.619490
# BLUEACMC           0.103203
# DANBRED            0.718685
# DNA                0.852401
# DUPIC              0.557752
# DURADN             0.663082
# DURAXIOM           0.636601
# DURGEN             0.208854
# IBERICO            0.000000
# L65                0.000000
# LDADN              0.000000
# LDAX               0.300000
# LWACMC             0.000000
# LWADN              0.371585
# LWAX               0.438017
# MAXSEG             0.757576
# PAC                0.238628
# PIETRAIN           0.000000
# PIETUPB            0.477767
# PIETUPBFR          0.000000
# PTADN              0.229855
# PTALE              0.000000
# PTAXIOM            0.416885
# PTSER              0.000000
# TAAAA              0.000000
# TDDDD              0.428892
# TDDPP              0.372137
# TEEEE              0.386055
# TIIII              0.175182
# TLLLL              0.660962
# TPPPP              0.326425
# TUUUU              0.364110
# TVVVV              0.299889
# TZZZZ              0.000000

# %%
procedencia_encoded = train.groupby(['PROCEDENCIA'])['PRODUCTIVO'].agg(['mean', 'count']).sort_values(by='count', ascending=False)
procedencia_encoded
# Out:
#                                                         mean  count
# PROCEDENCIA
# QUALITAT ESPERMATICA                                0.774344   4919
# BURUTAIN                                            0.389197   3610
# DESCONOCIDA                                         0.652893   2662
# TAFALLA                                             0.637444   2441
# EXPLOTACIONES CUFA                                  0.727400   2135
# PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE HOL  0.497401   1924
# GENESUS INC OAKVILLE MB ID NO 5326121               0.230991   1736
# GRUPO ALTOPASO A CORUÑA                             0.717419   1596
# CAN JAUMO                                           0.574278   1454
# False                                               0.743094   1448
# ESCORIAL                                            0.468254   1386
# LA COMETA                                           0.436975   1309
# AIM LEON                                            0.232227   1266
# FUGLSANG DENMARK 4160 HERLUFMAGLE                   0.838247   1255
# ZAHARA                                              0.243222   1254
# USA                                                 0.866957   1150
# NAVARRA                                             0.810811   1147
# MAS GALLAT                                          0.517364   1123
# FINA MARKUS AM LAUBENBUCH 2 ALEMANIA                0.405534   1048
# LA MASIA                                            0.755299   1038
# NEHER STEPHAN DORFSTR 16 ALEMANIA                   0.598326    956
# HASTRUPGARD HASTRUPGARDSVEJ 8 7000 FREDERICIA DK    0.642094    936
# PEÑAS DE SAN PEDRO                                  0.396667    900
# LIPPERT NORBERT AURAER STR 1 ALEMANIA               0.728211    872
# UPB GENETIC                                         0.467279    871
# SCHWARZ WOLFGANG BACHT STR 14 ALEMANIA              0.464968    785
# QUALITAT                                            0.522996    761
# GRUPO ALTOPASO A CORUÑA ES150800089301              0.586436    752
# EL ESCORIAL                                         0.492558    739
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ  DENMARK      0.995781    711
# BUJARALOZ                                           0.527738    703
# COMETA                                              0.468892    659
# MAALING AVL OG OPFORMERING SKELDEMARG 10 DENMARK    0.685446    639
# KERNEIS KERINOU LE CONQUET 29217 FRANCIA            0.738255    596
# ACOMPOR                                             0.333901    587
# ELTZABURU                                           0.103203    562
# GRANJA ZAHARA                                       0.585714    560
# KUGEL GEORG MAUERNER STR 23A ALEMANIA               0.000000    557
# MUNKBRO II MUNKBROVEJ 7 7500 HOLSTEBRO DENMARK      0.891544    544
# TOJAPIGS SARL DROMBAS DROMBAS FRANCE                0.602294    523
# ECKARDT BERND GBR HOHNWEG 14 ALEMANIA               0.641618    519
# AIM ANDALUCIA                                       0.382470    502
# HASTRUPGARD, HASTRUPGARDSVEJ 7000 FREDERICIA DENMA  0.000000    500
# ROHWER TIMO LOOPER WEG 19 24589 SCHULP ALEMANIA     0.366733    499
# AVLSCENTRET HOLMEGARD A/S, FALDSLEDVEJ FABORG DK    0.995859    483
# AIM PEÑAS                                           0.635021    474
# NAVALAGAMELLA                                       0.415418    467
# LYKKENSGAARD AVLSCENTER ELLEDEVEJ 95 DENMARK        0.952830    424
# VAN DE PEUT B.V.                                    0.489362    423
# TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA       0.280098    407
# GRANJA ZAHARA TOLEDO ESPAÑA                         0.146766    402
# ROHWER JURGEN BOKELER STR 5 24793 BRAMMER ALEMANIA  0.483376    391
# SCWARZ WOLFGANG BACHSTR 14 SALCHING ALEMANIA        0.000000    384
# TOM RATHJE COLUMBUS NEBRASKA USA                    0.957560    377
# SINOVAS                                             0.523161    367
# ELEVAGE DE BIZY OUZOUER LE MARCHE 41240 FRANCIA     0.950000    360
# ALBAGES                                             0.411940    335
# AIM ANDALUCÍA                                       0.577508    329
# LEON                                                0.525157    318
# EXPLOTACIONES CUFA SL                               0.000000    315
# GRANJA ALTOPASO SOBRADO DE LOS MONJES A CORUÑA      0.200000    295
# LL. TANKEDAL DENMARK 6580 VANDRUP                   0.669065    278
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ DENMARK       0.850909    275
# GUMPP HERMANN KIRCHPLATZ 1, 89420 DEISENFOFEN ALEM  0.000000    268
# LA ALMOLDA                                          0.253731    268
# UPB GENETIC WORLD                                   0.000000    258
# BEUNZA                                              0.375000    256
# AIM SINOVAS                                         0.000000    250
# ODARPI GENETICA VILLADIEGO                          0.580645    248
# JOSSE PASCAL LE POURCAUD AUGAN FRANCE               0.000000    245
# GANADOS PERALTA S.L                                 0.259414    239
# HORIZON CERAN LE FROMENTEAU CERANS FOULLETOURTE FR  0.000000    234
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN ALEMANIA            0.000000    226
# ALMUDEVAR                                           0.000000    216
# UPB GENETICA                                        0.786047    215
# ERTL JOHANNES GROSSHUNDLBACH 12 ALEMANIA            0.363636    209
# GRANJA ALTOPASO  A CORUÑA SPAIN                     0.000000    208
# AIM CENTRO                                          0.000000    203
# ATEZ                                                0.000000    186
# EXPLTACIONES CUFA                                   0.808743    183
# PETERSEN HANS DETLEF SUEDER  VOLSEMENHUSEN ALEMANI  0.000000    175
# INTEGRACIONES PERALTA                               0.000000    157
# AGER                                                0.420382    157
# KERDANET                                            0.523179    151
# VOLSGAARDI DAMSTRUPVEJ ORNHOJ DENMARK               0.000000    151
# VAN DE PEUT B.V                                     0.463087    149
# QIALITAT ESPERMATICA                                1.000000    147
# BERGSHOLM VIDAR N-3160 STOKKE NORUEGA               0.544776    134
# LE BARON CHRISTIAN PEN LAN KERDAVID LE MOUSTOIR FR  0.000000    134
# GRANJA ZAHARA (TOLEDO) ESPAÑA                       0.500000    132
# LA GARENNE 37310 AZAY-SUR-INDRE FRANCIA             0.000000    128
# AIM SORIA                                           0.000000    128
# ARANDA DE DUERO                                     0.582677    127
# GRANJA ZAHARA CERVERA TOLEDO ESPAÑA                 0.000000    126
# FINA MARKUS AM LAUBENBUCH WEIBENBURG ALEMANIA       0.000000    120
# FINA MARKUS AM LAUBNBUCH 2                          0.000000    120
# SANTENIS - C. CARRASCONES 12-2A - 45610 NAVALCAN T  0.000000    118
# MAS EL CROS                                         0.649573    117
# EARL FERME DE LA VALLE 650 RUE DU PIRE ALLER FRANC  0.478632    117
# ELEVAGE DE BIZY OUZOUERLE MARCHE FRANCE             0.000000    111
# MAALING III SLEVADVEJ 3 6560 SOMMERSTED DENMARK     0.925926    108
# SCHAAF-SCHELD GBR ARNSHAINER WEG 5 WAHLEN ALEMANIA  0.000000    108
# GAEC DES PORCS SAINS LA FOURBERIE GUIGNEN 35580     0.660377    106
# PEUT BV, VAN DE - BAARLOSEWEG 18 -  MARKNESS NETHE  0.000000     98
# FINA MARKUS WEIBENBURG GERMANY                      0.000000     97
# ODARPI VILLUSTO ESPAÑA                              0.000000     84
# ZAHARA CERVERA TOLEDO ESPAÑA                        0.000000     79
# ESKEGAARD A/S MOLLEGYDE HADERSLEV DENMARK           0.000000     76
# SCEA PINIER-JOSSO KERBELAY MARZAN 56130 FRANCIA     0.000000     74
# ATEZ (NAVARRA)                                      0.000000     73
# EARL ARMANE LE BOIS CLAIR EVAILLE 72120 FRANCIA     0.000000     72
# GANADERA MONEGRO                                    0.802817     71
# CASETA SANTASUSANA SAN MATEU DE BAGES               0.000000     69
# CHANTELOUP                                          0.000000     67
# QUALITAT ESPERMÁTICA                                0.000000     67
# ES5010370130002-00864                               0.000000     66
# ELEVAGE DE BIZY OUZOUER LE MARCHE FRANCE            0.000000     65
# QUALITA ESPERMATICA                                 1.000000     65
# CAN CARRERAS                                        0.000000     63
# PEÑAS DE SAN PÈDRO                                  0.000000     60
# LIPPERT NORBERT EUERDORF GERMANY                    0.000000     59
# VAN DE PEUT B.B.                                    0.000000     57
# JULE TOR HENRIK - - - - 7710 SPARBU - - NORWAY      0.000000     56
# KERBELAY (MARZAN)                                   0.000000     55
# FINA MARKUS AM LAUBENBUCH 2 WEIBENBURG ALEMANIA     0.000000     54
# BIURRUN                                             0.000000     54
# SANTIBAÑEZ                                          0.000000     53
# KÜGEL GEORG MAUERNER STR PFÖRRING ALEMANIA          0.000000     52
# KERNEIS KERINOU LE CONQUET FRANCE                   0.000000     51
# TOPIGS NORSVIN ESPAÑA                               0.000000     46
# TOJAPIGS SARL DOMBRAS - 1, RUE NAPOLEON - -FRANCE   0.000000     44
# GRANJA ZAHARA TOLEDO SPAIN                          0.000000     43
# BERGSHOLM VIDAR N 3160 STOKKE NORUEGA               0.000000     36
# SCHWARZ WOLFGANG SALCHING GERMANY                   0.000000     32
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN GERMANY             0.000000     30
# EARL FERME DE LA VALLEE HERBINGHEM FRANCE           0.000000     29
# KUGEL GEORG PFORRING GERMANY                        0.000000     26
# ALMOLDA                                             0.000000     25
# ERTL JOHANNES FRAUNBERG GERMANY                     0.000000     22
# EARL DARTOIS BEAUCHENE GUITE FRANCE                 0.000000     16
# GUMPP HERMANN DEISENHOFEN GERMANY                   0.000000     15
# SCHWARZ WOLFGANG BACHSTR SALCHING GERMANY           0.000000     14
# ECKARDT BEECKARDT BERND SONNEFELD GERMANY           0.000000     14
# INGA FOOD SA ALMENDRALEJO BADAJOZ                   0.000000     12
# SCHAAF-SCHELD ARNSHAINER KIRTORF-WAHLEN GERMANY     0.000000     11
# SANTENIS NAVALCAN TOLEDO SPAIN                      0.000000     10
# SAS ADN (MAIGRIS)                                   0.000000     10
# GUMPP HERMANN KIRCHPLATZ 1 DEISENHOFEN GERMANY      0.000000      8
# ECKARDT BERND HOHNWEG 14 SONNFELD GERMANY           0.000000      6
# BARCELONA                                           0.000000      4
# FINA MARKUS AM LAUBENBUCH WEIBENBURG GERMANY        0.000000      4
# ECKARDT BERND SONNEFELD GERMANY                     0.000000      4

# %%
procedencia_encoded = train.groupby(['PROCEDENCIA'])['PRODUCTIVO'].mean()
procedencia_encoded = pd.DataFrame(procedencia_encoded)
procedencia_encoded = procedencia_encoded.rename(columns = {'PRODUCTIVO':'PROCEDENCIA_ENCODED'})
procedencia_encoded
# Out:
#                                                     PROCEDENCIA_ENCODED
# PROCEDENCIA
# False                                                          0.743094
# ACOMPOR                                                        0.333901
# AGER                                                           0.420382
# AIM ANDALUCIA                                                  0.382470
# AIM ANDALUCÍA                                                  0.577508
# AIM CENTRO                                                     0.000000
# AIM LEON                                                       0.232227
# AIM PEÑAS                                                      0.635021
# AIM SINOVAS                                                    0.000000
# AIM SORIA                                                      0.000000
# ALBAGES                                                        0.411940
# ALMOLDA                                                        0.000000
# ALMUDEVAR                                                      0.000000
# ARANDA DE DUERO                                                0.582677
# ATEZ                                                           0.000000
# ATEZ (NAVARRA)                                                 0.000000
# AVLSCENTRET HOLMEGARD A/S, FALDSLEDVEJ FABORG DK               0.995859
# BARCELONA                                                      0.000000
# BERGSHOLM VIDAR N 3160 STOKKE NORUEGA                          0.000000
# BERGSHOLM VIDAR N-3160 STOKKE NORUEGA                          0.544776
# BEUNZA                                                         0.375000
# BIURRUN                                                        0.000000
# BUJARALOZ                                                      0.527738
# BURUTAIN                                                       0.389197
# CAN CARRERAS                                                   0.000000
# CAN JAUMO                                                      0.574278
# CASETA SANTASUSANA SAN MATEU DE BAGES                          0.000000
# CHANTELOUP                                                     0.000000
# COMETA                                                         0.468892
# DESCONOCIDA                                                    0.652893
# EARL ARMANE LE BOIS CLAIR EVAILLE 72120 FRANCIA                0.000000
# EARL DARTOIS BEAUCHENE GUITE FRANCE                            0.000000
# EARL FERME DE LA VALLE 650 RUE DU PIRE ALLER FRANC             0.478632
# EARL FERME DE LA VALLEE HERBINGHEM FRANCE                      0.000000
# ECKARDT BEECKARDT BERND SONNEFELD GERMANY                      0.000000
# ECKARDT BERND GBR HOHNWEG 14 ALEMANIA                          0.641618
# ECKARDT BERND HOHNWEG 14 SONNFELD GERMANY                      0.000000
# ECKARDT BERND SONNEFELD GERMANY                                0.000000
# EL ESCORIAL                                                    0.492558
# ELEVAGE DE BIZY OUZOUER LE MARCHE 41240 FRANCIA                0.950000
# ELEVAGE DE BIZY OUZOUER LE MARCHE FRANCE                       0.000000
# ELEVAGE DE BIZY OUZOUERLE MARCHE FRANCE                        0.000000
# ELTZABURU                                                      0.103203
# ERTL JOHANNES FRAUNBERG GERMANY                                0.000000
# ERTL JOHANNES GROSSHUNDLBACH 12 ALEMANIA                       0.363636
# ES5010370130002-00864                                          0.000000
# ESCORIAL                                                       0.468254
# ESKEGAARD A/S MOLLEGYDE HADERSLEV DENMARK                      0.000000
# EXPLOTACIONES CUFA                                             0.727400
# EXPLOTACIONES CUFA SL                                          0.000000
# EXPLTACIONES CUFA                                              0.808743
# FINA MARKUS AM LAUBENBUCH 2 ALEMANIA                           0.405534
# FINA MARKUS AM LAUBENBUCH 2 WEIBENBURG ALEMANIA                0.000000
# FINA MARKUS AM LAUBENBUCH WEIBENBURG ALEMANIA                  0.000000
# FINA MARKUS AM LAUBENBUCH WEIBENBURG GERMANY                   0.000000
# FINA MARKUS AM LAUBNBUCH 2                                     0.000000
# FINA MARKUS WEIBENBURG GERMANY                                 0.000000
# FUGLSANG DENMARK 4160 HERLUFMAGLE                              0.838247
# GAEC DES PORCS SAINS LA FOURBERIE GUIGNEN 35580                0.660377
# GANADERA MONEGRO                                               0.802817
# GANADOS PERALTA S.L                                            0.259414
# GENESUS INC OAKVILLE MB ID NO 5326121                          0.230991
# GRANJA ALTOPASO  A CORUÑA SPAIN                                0.000000
# GRANJA ALTOPASO SOBRADO DE LOS MONJES A CORUÑA                 0.200000
# GRANJA ZAHARA                                                  0.585714
# GRANJA ZAHARA (TOLEDO) ESPAÑA                                  0.500000
# GRANJA ZAHARA CERVERA TOLEDO ESPAÑA                            0.000000
# GRANJA ZAHARA TOLEDO ESPAÑA                                    0.146766
# GRANJA ZAHARA TOLEDO SPAIN                                     0.000000
# GRUPO ALTOPASO A CORUÑA                                        0.717419
# GRUPO ALTOPASO A CORUÑA ES150800089301                         0.586436
# GUMPP HERMANN DEISENHOFEN GERMANY                              0.000000
# GUMPP HERMANN KIRCHPLATZ 1 DEISENHOFEN GERMANY                 0.000000
# GUMPP HERMANN KIRCHPLATZ 1, 89420 DEISENFOFEN ALEM             0.000000
# HASTRUPGARD HASTRUPGARDSVEJ 8 7000 FREDERICIA DK               0.642094
# HASTRUPGARD, HASTRUPGARDSVEJ 7000 FREDERICIA DENMA             0.000000
# HORIZON CERAN LE FROMENTEAU CERANS FOULLETOURTE FR             0.000000
# INGA FOOD SA ALMENDRALEJO BADAJOZ                              0.000000
# INTEGRACIONES PERALTA                                          0.000000
# JOSSE PASCAL LE POURCAUD AUGAN FRANCE                          0.000000
# JULE TOR HENRIK - - - - 7710 SPARBU - - NORWAY                 0.000000
# KERBELAY (MARZAN)                                              0.000000
# KERDANET                                                       0.523179
# KERNEIS KERINOU LE CONQUET 29217 FRANCIA                       0.738255
# KERNEIS KERINOU LE CONQUET FRANCE                              0.000000
# KUGEL GEORG MAUERNER STR 23A ALEMANIA                          0.000000
# KUGEL GEORG PFORRING GERMANY                                   0.000000
# KÜGEL GEORG MAUERNER STR PFÖRRING ALEMANIA                     0.000000
# LA ALMOLDA                                                     0.253731
# LA COMETA                                                      0.436975
# LA GARENNE 37310 AZAY-SUR-INDRE FRANCIA                        0.000000
# LA MASIA                                                       0.755299
# LE BARON CHRISTIAN PEN LAN KERDAVID LE MOUSTOIR FR             0.000000
# LEON                                                           0.525157
# LIPPERT NORBERT AURAER STR 1 ALEMANIA                          0.728211
# LIPPERT NORBERT EUERDORF GERMANY                               0.000000
# LL. TANKEDAL DENMARK 6580 VANDRUP                              0.669065
# LYKKENSGAARD AVLSCENTER ELLEDEVEJ 95 DENMARK                   0.952830
# MAALING AVL OG OPFORMERING SKELDEMARG 10 DENMARK               0.685446
# MAALING III SLEVADVEJ 3 6560 SOMMERSTED DENMARK                0.925926
# MAS EL CROS                                                    0.649573
# MAS GALLAT                                                     0.517364
# MUNKBRO II MUNKBROVEJ 7 7500 HOLSTEBRO DENMARK                 0.891544
# NAVALAGAMELLA                                                  0.415418
# NAVARRA                                                        0.810811
# NEHER STEPHAN DORFSTR 16 ALEMANIA                              0.598326
# ODARPI GENETICA VILLADIEGO                                     0.580645
# ODARPI VILLUSTO ESPAÑA                                         0.000000
# PETERSEN HANS DETLEF SUEDER  VOLSEMENHUSEN ALEMANI             0.000000
# PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE HOL             0.497401
# PEUT BV, VAN DE - BAARLOSEWEG 18 -  MARKNESS NETHE             0.000000
# PEÑAS DE SAN PEDRO                                             0.396667
# PEÑAS DE SAN PÈDRO                                             0.000000
# QIALITAT ESPERMATICA                                           1.000000
# QUALITA ESPERMATICA                                            1.000000
# QUALITAT                                                       0.522996
# QUALITAT ESPERMATICA                                           0.774344
# QUALITAT ESPERMÁTICA                                           0.000000
# ROHWER JURGEN BOKELER STR 5 24793 BRAMMER ALEMANIA             0.483376
# ROHWER TIMO LOOPER WEG 19 24589 SCHULP ALEMANIA                0.366733
# SANTENIS - C. CARRASCONES 12-2A - 45610 NAVALCAN T             0.000000
# SANTENIS NAVALCAN TOLEDO SPAIN                                 0.000000
# SANTIBAÑEZ                                                     0.000000
# SAS ADN (MAIGRIS)                                              0.000000
# SCEA PINIER-JOSSO KERBELAY MARZAN 56130 FRANCIA                0.000000
# SCHAAF-SCHELD ARNSHAINER KIRTORF-WAHLEN GERMANY                0.000000
# SCHAAF-SCHELD GBR ARNSHAINER WEG 5 WAHLEN ALEMANIA             0.000000
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN ALEMANIA                       0.000000
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN GERMANY                        0.000000
# SCHWARZ WOLFGANG BACHSTR SALCHING GERMANY                      0.000000
# SCHWARZ WOLFGANG BACHT STR 14 ALEMANIA                         0.464968
# SCHWARZ WOLFGANG SALCHING GERMANY                              0.000000
# SCWARZ WOLFGANG BACHSTR 14 SALCHING ALEMANIA                   0.000000
# SINOVAS                                                        0.523161
# TAFALLA                                                        0.637444
# TOJAPIGS SARL DOMBRAS - 1, RUE NAPOLEON - -FRANCE              0.000000
# TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA                  0.280098
# TOJAPIGS SARL DROMBAS DROMBAS FRANCE                           0.602294
# TOM RATHJE COLUMBUS NEBRASKA USA                               0.957560
# TOPIGS NORSVIN ESPAÑA                                          0.000000
# UPB GENETIC                                                    0.467279
# UPB GENETIC WORLD                                              0.000000
# UPB GENETICA                                                   0.786047
# USA                                                            0.866957
# VAN DE PEUT B.B.                                               0.000000
# VAN DE PEUT B.V                                                0.463087
# VAN DE PEUT B.V.                                               0.489362
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ  DENMARK                 0.995781
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ DENMARK                  0.850909
# VOLSGAARDI DAMSTRUPVEJ ORNHOJ DENMARK                          0.000000
# ZAHARA                                                         0.243222
# ZAHARA CERVERA TOLEDO ESPAÑA                                   0.000000

# %%
train = train.merge(razas_encoded, how='inner', left_on='RAZA', right_index=True)

# %%
train = train.merge(centros_encoded, how='inner', left_on='CENTRO', right_index=True)

# %%
train = train.merge(genetica_encoded, how='inner', left_on='LINEA_GEN', right_index=True)

# %%
train = train.merge(procedencia_encoded, how='inner', left_on='PROCEDENCIA', right_index=True)

# %%
train.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x   RAZA     AÑO  DOSIS_REAL_y  \
# 37177       2613.0    CAL          37.0  TDDDD  2020.0          77.0
# 37182       2613.0    CAL          23.0  TDDDD  2020.0          77.0
# 37125       2612.0    CAL          42.0  TDDDD  2020.0          77.0
# 37132       2612.0    CAL          34.0  TDDDD  2020.0          77.0
# 36966       2610.0    CAL          38.0  TDDDD  2020.0          80.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO  \
# 37177         0.0     TDDDD  2613.0
# 37182         0.0     TDDDD  2613.0
# 37125         0.0     TDDDD  2612.0
# 37132         0.0     TDDDD  2612.0
# 36966         1.0     TDDDD  2610.0
#
#                                          PROCEDENCIA  RAZA_ENCODED  \
# 37177  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA      0.429643
# 37182  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA      0.429643
# 37125  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA      0.429643
# 37132  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA      0.429643
# 36966  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA      0.429643
#
#        CENTRO_ENCODED  GENETICA_ENCODED  PROCEDENCIA_ENCODED
# 37177        0.419873          0.428892             0.280098
# 37182        0.419873          0.428892             0.280098
# 37125        0.419873          0.428892             0.280098
# 37132        0.419873          0.428892             0.280098
# 36966        0.419873          0.428892             0.280098

# %%
train['PROCEDENCIA_ENCODED'].unique()
# Out:
# array([0.28009828, 0.49740125, 0.49255751, 0.23222749, 0.52515723,
#        0.4893617 , 0.60229446, 0.46308725, 0.46825397, 0.        ,
#        0.39666667, 0.52773826, 0.63744367, 0.38919668, 0.6350211 ,
#        0.83824701, 0.77434438, 0.65289256, 0.74309392, 0.66906475,
#        0.80874317, 0.81081081, 0.52299606, 0.72740047, 0.95283019,
#        0.68544601, 0.85090909, 0.99578059, 0.64209402, 0.99585921,
#        0.89154412, 0.92592593, 0.14676617, 0.57427785, 0.73825503,
#        0.47863248, 0.58064516, 0.41541756, 0.52316076, 0.58267717,
#        0.71741855, 0.2       , 0.38247012, 0.58643617, 0.5775076 ,
#        0.48337596, 0.40553435, 0.36673347, 0.43697479, 0.72821101,
#        0.59832636, 0.46496815, 0.36363636, 0.75529865, 0.46727899,
#        0.46889226, 0.78604651, 0.33390119, 0.6416185 , 0.42038217,
#        0.4119403 , 0.375     , 0.8028169 , 0.52317881, 0.95      ,
#        0.5173642 , 0.25941423, 0.23099078, 0.86695652, 0.95755968,
#        0.10320285, 0.64957265, 0.25373134, 0.54477612, 0.66037736,
#        1.        , 0.5       , 0.24322169, 0.58571429])

# %% [markdown]
# # CREACIÓN DEL MODELO

# %%
train.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x   RAZA     AÑO  DOSIS_REAL_y  \
# 37177       2613.0    CAL          37.0  TDDDD  2020.0          77.0
# 37182       2613.0    CAL          23.0  TDDDD  2020.0          77.0
# 37125       2612.0    CAL          42.0  TDDDD  2020.0          77.0
# 37132       2612.0    CAL          34.0  TDDDD  2020.0          77.0
# 36966       2610.0    CAL          38.0  TDDDD  2020.0          80.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO  \
# 37177         0.0     TDDDD  2613.0
# 37182         0.0     TDDDD  2613.0
# 37125         0.0     TDDDD  2612.0
# 37132         0.0     TDDDD  2612.0
# 36966         1.0     TDDDD  2610.0
#
#                                          PROCEDENCIA  RAZA_ENCODED  \
# 37177  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA      0.429643
# 37182  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA      0.429643
# 37125  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA      0.429643
# 37132  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA      0.429643
# 36966  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA      0.429643
#
#        CENTRO_ENCODED  GENETICA_ENCODED  PROCEDENCIA_ENCODED
# 37177        0.419873          0.428892             0.280098
# 37182        0.419873          0.428892             0.280098
# 37125        0.419873          0.428892             0.280098
# 37132        0.419873          0.428892             0.280098
# 36966        0.419873          0.428892             0.280098

# %%
x_train = train.loc[:, ['RAZA_ENCODED', 'CENTRO_ENCODED', 'GENETICA_ENCODED', 'PROCEDENCIA_ENCODED', 'DOSIS_REAL_x']].values
y_train = train['PRODUCTIVO'].values

# %%
test.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x       RAZA     AÑO  DOSIS_REAL_y  \
# 31768       2520.0    CAL          34.0      TDDDD  2019.0          68.0
# 40202       2658.0  PEÑAS          16.0  PIETUPBNN  2020.0          70.0
# 65588       1882.0    CAL          13.0  PIETUPBJJ  2017.0          99.0
# 52990       2355.0    CAL           9.0      TEEEE  2018.0          64.0
# 28760       2376.0    CAL          11.0        PAC  2018.0          68.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO  \
# 31768         0.0     TDDDD  2520.0
# 40202         0.0   PIETUPB  2658.0
# 65588         1.0   PIETUPB  1882.0
# 52990         0.0     TEEEE  2355.0
# 28760         0.0       PAC  2376.0
#
#                                              PROCEDENCIA
# 31768  PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE...
# 40202       SCWARZ WOLFGANG BACHSTR 14 SALCHING ALEMANIA
# 65588                                        UPB GENETIC
# 52990                                          CAN JAUMO
# 28760              KUGEL GEORG MAUERNER STR 23A ALEMANIA

# %%
test.isnull().sum()
# Out:
# COD_VERRACO     0
# CENTRO          0
# DOSIS_REAL_x    0
# RAZA            0
# AÑO             0
# DOSIS_REAL_y    0
# PRODUCTIVO      0
# LINEA_GEN       0
# CODIGO          0
# PROCEDENCIA     0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# COD_VERRACO            0
# CENTRO                 0
# DOSIS_REAL_x           0
# RAZA                   0
# AÑO                    0
# DOSIS_REAL_y           0
# PRODUCTIVO             0
# LINEA_GEN              0
# CODIGO                 0
# PROCEDENCIA            0
# RAZA_ENCODED           0
# CENTRO_ENCODED         0
# GENETICA_ENCODED       0
# PROCEDENCIA_ENCODED    0
# dtype: int64

# %%
test = test.merge(razas_encoded, how='inner', left_on='RAZA', right_index=True)

test = test.merge(centros_encoded, how='inner', left_on='CENTRO', right_index=True)

test = test.merge(genetica_encoded, how='inner', left_on='LINEA_GEN', right_index=True)

test = test.merge(procedencia_encoded, how='inner', left_on='PROCEDENCIA', right_index=True)

# %%
test.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x   RAZA     AÑO  DOSIS_REAL_y  \
# 31768       2520.0    CAL          34.0  TDDDD  2019.0          68.0
# 33007       2390.0    CAL          35.0  TDDDD  2019.0          91.0
# 22590       2426.0    CAL          25.0  TDDDD  2019.0         101.0
# 33004       2390.0    CAL           4.0  TDDDD  2019.0          91.0
# 22618       2426.0    CAL          26.0  TDDDD  2019.0         101.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO  \
# 31768         0.0     TDDDD  2520.0
# 33007         1.0     TDDDD  2390.0
# 22590         1.0     TDDDD  2426.0
# 33004         1.0     TDDDD  2390.0
# 22618         1.0     TDDDD  2426.0
#
#                                              PROCEDENCIA  RAZA_ENCODED  \
# 31768  PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE...      0.429643
# 33007  PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE...      0.429643
# 22590  PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE...      0.429643
# 33004  PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE...      0.429643
# 22618  PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE...      0.429643
#
#        CENTRO_ENCODED  GENETICA_ENCODED  PROCEDENCIA_ENCODED
# 31768        0.419873          0.428892             0.497401
# 33007        0.419873          0.428892             0.497401
# 22590        0.419873          0.428892             0.497401
# 33004        0.419873          0.428892             0.497401
# 22618        0.419873          0.428892             0.497401

# %%
x_test = test.loc[:, ['RAZA_ENCODED', 'CENTRO_ENCODED', 'GENETICA_ENCODED', 'PROCEDENCIA_ENCODED', 'DOSIS_REAL_x']].values
y_test = test['PRODUCTIVO'].values

# %% [markdown]
# **Redondeo los decimales de los float a 3 puesto que a veces el clasificador me daba problemas por la longitud de estos mismos**

# %%
train = train.round(3)
test = test.round(3)

# %%
train.isnull().sum()
# Out:
# COD_VERRACO            0
# CENTRO                 0
# DOSIS_REAL_x           0
# RAZA                   0
# AÑO                    0
# DOSIS_REAL_y           0
# PRODUCTIVO             0
# LINEA_GEN              0
# CODIGO                 0
# PROCEDENCIA            0
# RAZA_ENCODED           0
# CENTRO_ENCODED         0
# GENETICA_ENCODED       0
# PROCEDENCIA_ENCODED    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# COD_VERRACO            0
# CENTRO                 0
# DOSIS_REAL_x           0
# RAZA                   0
# AÑO                    0
# DOSIS_REAL_y           0
# PRODUCTIVO             0
# LINEA_GEN              0
# CODIGO                 0
# PROCEDENCIA            0
# RAZA_ENCODED           0
# CENTRO_ENCODED         0
# GENETICA_ENCODED       0
# PROCEDENCIA_ENCODED    0
# dtype: int64

# %% [markdown]
# **Los valores de las variables categóricas estan en tanto por 1. He de escalar todos los valores puesto que los valores de DOSIS_REAL_x (dosis reales en cada extracción) son mayores**

# %%
from sklearn.preprocessing import StandardScaler


sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform (x_test)

# %%
print(x_train)
# Out:
# [[-0.41129964 -0.69943543 -0.43641858 -0.88964529  0.90060388]
#  [-0.41129964 -0.69943543 -0.43641858 -0.88964529 -0.06922157]
#  [-0.41129964 -0.69943543 -0.43641858 -0.88964529  1.24697011]
#  ...
#  [-0.69180611 -1.52169685 -0.72758122 -1.95517685 -0.48486105]
#  [-0.69180611 -1.52169685 -0.72758122 -1.95517685 -1.66250624]
#  [-0.69180611 -1.52169685 -0.72758122 -1.95517685 -1.66250624]]

# %%
x_train.shape
# Out:
# (68369, 5)

# %%
x_test.shape
# Out:
# (22790, 5)

# %% [markdown]
# # Modelo de Decision Tree Classifier

# %%
def clasificador_arbol(X_train, Y_train, X_test, Y_test):
    
    tree = DecisionTreeClassifier()

    tree.fit(X_train, Y_train)
    preds = tree.predict(X_test)
    probs = tree.predict_proba(X_test)
    fpr, tpr, thresholds = roc_curve(Y_test, probs[:, 1])
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], color='red', linestyle='--')
    return metricas(Y_test,preds)

# %%
def metricas(Y_test, preds):
    
    auc = roc_auc_score(Y_test, preds)  
    print('AUC: %.2f' % auc) 
    return accuracy_score(Y_test, preds), recall_score(Y_test, preds), precision_score(Y_test, preds), f1_score(Y_test, preds)

# %%
# %%time
clasificador_arbol(x_train, y_train, x_test, y_test)
# Out:
# AUC: 0.77
# CPU times: user 303 ms, sys: 27.7 ms, total: 330 ms
# Wall time: 388 ms
# (0.7694164107064502,
#  0.8084346569169288,
#  0.7600319744204637,
#  0.7834864653289935)

# %% [markdown]
# # Modelo de Logistic Regressor

# %%
def clasificador_LR(X_train, Y_train, X_test, Y_test):
    
    classifier = LogisticRegression()
    
    classifier.fit(X_train, y_train)
    preds = classifier.predict(X_test)
    probs = classifier.predict_proba(X_test)
    fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], color='red', linestyle='--')
    return metricas(Y_test,preds)

# %%
# %%time
clasificador_LR(x_train, y_train, x_test, y_test)
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# AUC: 0.73
# CPU times: user 369 ms, sys: 112 ms, total: 481 ms
# Wall time: 410 ms
# (0.7278192189556824,
#  0.7398180426834453,
#  0.7346335697399528,
#  0.7372166913789452)

# %% [markdown]
# # Modelo Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
 
def clasificador_RF(X_train, Y_train, X_test, Y_test):
    # Crear el modelo con 100 arboles #verbose=2 para ver más detalle del proceso
    model = RandomForestClassifier(n_estimators=100, 
                                   bootstrap = True,
                                   max_features = 'sqrt')
    # a entrenar!
    model.fit(X_train, Y_train)
    preds = model.predict(X_test)
    probs = model.predict_proba(X_test)
    fpr, tpr, thresholds = roc_curve(Y_test, probs[:, 1])
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], color='red', linestyle='--')
    return metricas(Y_test,preds)

# %%
# %%time
clasificador_RF(x_train, y_train, x_test, y_test)
# Out:
# AUC: 0.77
# CPU times: user 6.49 s, sys: 148 ms, total: 6.64 s
# Wall time: 6.7 s
# (0.7731899956121105,
#  0.8321571294957911,
#  0.7538900015405947,
#  0.7910924301822737)

# %% [markdown]
# # SVM Classifier

# %%
from sklearn import svm
 
def clasificador_SVM(X_train, Y_train, X_test, Y_test):

    # Initialize SVM classifier
    clf = svm.SVC(kernel='linear')

    # Fit data
    clf = clf.fit(X_train, y_train)
    preds = clf.predict(X_test)
    return metricas(Y_test,preds)

# %%
# %time
clasificador_SVM(x_train, y_train, x_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs
# AUC: 0.73
# (0.7296621325142606,
#  0.7695774168863192,
#  0.7239641657334827,
#  0.7460742694637926)

# %%
train.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x   RAZA     AÑO  DOSIS_REAL_y  \
# 37177       2613.0    CAL          37.0  TDDDD  2020.0          77.0
# 37182       2613.0    CAL          23.0  TDDDD  2020.0          77.0
# 37125       2612.0    CAL          42.0  TDDDD  2020.0          77.0
# 37132       2612.0    CAL          34.0  TDDDD  2020.0          77.0
# 36966       2610.0    CAL          38.0  TDDDD  2020.0          80.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO  \
# 37177         0.0     TDDDD  2613.0
# 37182         0.0     TDDDD  2613.0
# 37125         0.0     TDDDD  2612.0
# 37132         0.0     TDDDD  2612.0
# 36966         1.0     TDDDD  2610.0
#
#                                          PROCEDENCIA  RAZA_ENCODED  \
# 37177  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA          0.43
# 37182  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA          0.43
# 37125  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA          0.43
# 37132  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA          0.43
# 36966  TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA          0.43
#
#        CENTRO_ENCODED  GENETICA_ENCODED  PROCEDENCIA_ENCODED
# 37177            0.42             0.429                 0.28
# 37182            0.42             0.429                 0.28
# 37125            0.42             0.429                 0.28
# 37132            0.42             0.429                 0.28
# 36966            0.42             0.429                 0.28

# %% [markdown]
# **Este último estudio se ha realizado con el objetivo de ver el peso de cada variable sobre el resultado final, así como ver que relación tienen las diferentes variables entre sí**

# %%
small_train = train.loc[:, ['RAZA_ENCODED', 'CENTRO_ENCODED', 'GENETICA_ENCODED', 'PROCEDENCIA_ENCODED', 'DOSIS_REAL_y', 'PRODUCTIVO']]

# %%
c = small_train.corr()

# %%
sns.heatmap(c, annot = True);
