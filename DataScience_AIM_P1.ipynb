# %% [markdown]
# **1. Algunos puntos que me parece interesante que puedas llegar a establecer relaciones son:
# FECHA DE RECOGIDA, CENTRO, CONCENTRACIÓN, DOSIS, RAZA, GENÉTICA, FORMAS ANORMALES (todas y las totales),
# MOTILIDAD4, CALIDAD_MOVIMIENTO4, COLONIAS, COLONIAS4 (en cada punto), COD_TRATAMIENTO, COD_VACUNA, edad del
# verraco en la recogida de semen (FECHA_LLEGADA – FECHA EYACULADO en cada recogida), edad del verraco a la
# llegada (FECHA LLEGADA – FECHA_NACTO), supervivencia del verraco en el centro (FECHA_SALIDA – FECHA LLEGADA),
# PROCEDENCIA, CAUSA_BAJA, LINEA_GEN**

# %% [markdown]
# # **Modelo Predictivo - Machine Learning:**
#
# **Modelo predivtivo en busca de conocer si un verraco será productivo o no es función a su raza, procedencia, linea genética, centro y dosis reales en cada una de las extracciones realizadas en él**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

df = pd.read_excel('EYACULADOS.xlsx')
verracos = pd.read_excel('VERRACOS.xlsx')

# %% [markdown]
# ## Estudio inicial de los datos

# %% [markdown]
# **Las dos bases de datos a utilizar son la perteneicente al archivo denominado EYACULADOS.xlsx (almacenada en la cariable "df") y Verracos.xlsx (almacenada en la variable "verracos")**

# %%
df.head(5)
# Out:
#    CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 0  140901 2020-01-03         2095  620ND06    CAL          68          56
# 1  140902 2020-01-03         1872  520ND19    CAL          68          55
# 2  140903 2020-01-03         2094  620ND05    CAL          68          83
# 3  140904 2020-01-03         2086  620ND96    CAL          68          78
# 4  140905 2020-01-03         2470  807DP42    CAL          68          83
#
#    VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 0      317             76          9                   7               10
# 1      357             61          9                   7                9
# 2      511            156          9                   7               36
# 3      497            134          9                   8               30
# 4      572            116          9                   7               30
#
#    DOSIS_REAL  DOSIS_A_DILUIR  DILUYENTE  SEMEN_ANADIR  CONCENTRACION_REAL  \
# 0          10             0.0      513.0           317                2409
# 1           9             0.0      390.0           357                2420
# 2          36             0.0     2477.0           511                2214
# 3          30             0.0     1993.0           497                2220
# 4          30             0.0     1918.0           572                2212
#
#   VALIDO MOTIVO_DESECHO MOTIVO_DIFERENCIA HETEROSPERMIA CODIGO_HETEROSPERMIA  \
# 0   True             OK                OK          True          N07DDA10101
# 1   True             OK                OK          True          N07DDA10101
# 2   True             OK                OK          True          N07DDA10101
# 3   True             OK                OK          True          N07DDA10101
# 4   True             OK                OK          True          N07DPA10101
#
#    ENVASADAS  DILUIDO  BOLASER_BLANCO  BOLASER_MA  ID_DILUYENTE  ML_DILUYENTE  \
# 0    98.3125     True         30995.0         0.0        2730.0         513.0
# 1     0.0000     True         30995.0         0.0        2730.0         390.0
# 2     0.0000     True         30995.0         0.0        2730.0        2477.0
# 3     0.0000     True         30995.0         0.0        2730.0        1993.0
# 4    82.0000     True         30995.0         0.0        2730.0        1918.0
#
#       RAZA  DOSIS DILUIDAS  TEMP_DILUYENTE  CONDUCTIVIDAD
# 0  DANBRED              10       20.299999           10.6
# 1  DANBRED               9       20.299999           10.4
# 2  DANBRED              36       20.299999           10.5
# 3  DANBRED              30       20.299999           10.6
# 4    DUPIC              30       20.400000            9.6

# %%
df['AÑO'] = df['FECHA_REC'].dt.year
df['MES'] = df['FECHA_REC'].dt.month
df.head(5)
# Out:
#    CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 0  140901 2020-01-03         2095  620ND06    CAL          68          56
# 1  140902 2020-01-03         1872  520ND19    CAL          68          55
# 2  140903 2020-01-03         2094  620ND05    CAL          68          83
# 3  140904 2020-01-03         2086  620ND96    CAL          68          78
# 4  140905 2020-01-03         2470  807DP42    CAL          68          83
#
#    VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 0      317             76          9                   7               10
# 1      357             61          9                   7                9
# 2      511            156          9                   7               36
# 3      497            134          9                   8               30
# 4      572            116          9                   7               30
#
#    DOSIS_REAL  DOSIS_A_DILUIR  DILUYENTE  SEMEN_ANADIR  CONCENTRACION_REAL  \
# 0          10             0.0      513.0           317                2409
# 1           9             0.0      390.0           357                2420
# 2          36             0.0     2477.0           511                2214
# 3          30             0.0     1993.0           497                2220
# 4          30             0.0     1918.0           572                2212
#
#   VALIDO MOTIVO_DESECHO MOTIVO_DIFERENCIA HETEROSPERMIA CODIGO_HETEROSPERMIA  \
# 0   True             OK                OK          True          N07DDA10101
# 1   True             OK                OK          True          N07DDA10101
# 2   True             OK                OK          True          N07DDA10101
# 3   True             OK                OK          True          N07DDA10101
# 4   True             OK                OK          True          N07DPA10101
#
#    ENVASADAS  DILUIDO  BOLASER_BLANCO  BOLASER_MA  ID_DILUYENTE  ML_DILUYENTE  \
# 0    98.3125     True         30995.0         0.0        2730.0         513.0
# 1     0.0000     True         30995.0         0.0        2730.0         390.0
# 2     0.0000     True         30995.0         0.0        2730.0        2477.0
# 3     0.0000     True         30995.0         0.0        2730.0        1993.0
# 4    82.0000     True         30995.0         0.0        2730.0        1918.0
#
#       RAZA  DOSIS DILUIDAS  TEMP_DILUYENTE  CONDUCTIVIDAD   AÑO  MES
# 0  DANBRED              10       20.299999           10.6  2020    1
# 1  DANBRED               9       20.299999           10.4  2020    1
# 2  DANBRED              36       20.299999           10.5  2020    1
# 3  DANBRED              30       20.299999           10.6  2020    1
# 4    DUPIC              30       20.400000            9.6  2020    1

# %%
print(df['AÑO'].value_counts())
print(df['MES'].value_counts())
# Out:
# 2015    23414
# 2017    21919
# 2020    20761
# 2016    20234
# 2018    20094
# 2019    19847
# 2014    14042
# 2013    12638
# 2012      628
# 2021      122
# Name: AÑO, dtype: int64
# 9     13848
# 8     13764
# 10    13711
# 12    13637
# 7     13279
# 6     12834
# 3     12752
# 5     12555
# 4     12553
# 11    12288
# 1     11266
# 2     11212
# Name: MES, dtype: int64

# %%
df['CENTRO'].value_counts()
# Out:
# CAL      100158
# PEÑAS     48924
# TOL        4617
# Name: CENTRO, dtype: int64

# %%
df['RAZA'].value_counts()
# Out:
# 0             50148
# DANBRED       24808
# AND           10479
# PIETUPBJJ      7736
# PIETUPBNN      6542
# PAC            6518
# TDDDD          5352
# DUPIC          5178
# PIETUPB        3967
# AGSG           3900
# TEEEE          3597
# DNA            2050
# PIETAXIOM      1990
# DURGENES       1761
# ADN            1679
# TLLLL          1635
# TUUUUIBE       1247
# TVVVV          1183
# DCAXIOM        1085
# LDAX           1075
# TPPNP          1028
# TPPPPTOP        975
# BLUEACMC        846
# DCADN           699
# TDDPP           698
# LWAX            631
# LDADN           603
# TUUUU           506
# PIETUPBFR       492
# PI ALEM NP      467
# TIIII           456
# IBERICO         396
# TPPPPELI        276
# LWACMC          263
# TZZZZGGP        263
# LWADN           261
# MAXSEG          230
# TAAAAGGP        228
# DURGENMJJ       223
# DURGENG         222
# ADNREK          221
# DURGENM         205
# DURGENESM       165
# TUUUUEFI        158
# TUUUUCAL        149
# L65P+           142
# TZZZZ           128
# PACCAR          100
# PIETSERGAL       87
# TUUUUGGP         30
# TPPNN            22
# PIETGEN          10
# TDDDDTOP         10
# TAAAA             3
# DAN-INGA          1
# -                 1
# Name: RAZA, dtype: int64

# %%
verracos.head()
# Out:
#    CODIGO  CLASE VERRACO TATUAJE CENTRO FECHA_NACTO FECHA_LLEGADA  \
# 0     828  TUUUU     406   A4V7Z    CAL         NaT    2008-01-22
# 1     829  TUUUU     407   A2V7W    CAL  2007-03-04    2008-03-06
# 2     830  TUUUU     408   A8V2P    CAL  2007-12-21    2008-03-06
# 3     831  TUUUU     409   S7N8F    CAL  2007-03-06    2008-03-06
# 4     832  TUUUU     410   S8N7D    CAL  2007-05-11    2008-03-06
#
#   FECHA_SALIDA  ACTIVO STRESS PROCEDENCIA            DESTINO CAUSA_BAJA  \
# 0   2008-09-03   False    NaN         NaN                NaN         29
# 1   2008-09-03   False    NaN         NaN                NaN         29
# 2   2009-01-08   False    NaN         NaN  CARNICAS CIEZANAS         15
# 3   2008-09-03   False    NaN         NaN                NaN         29
# 4   2008-12-11   False    NaN         NaN                NaN         29
#
#   LINEA_GEN INICIO_AMORT  COSTE_AMORT  MESES_AMORT  COD_ANT  \
# 0       NaN   2008-01-22         2500           18      828
# 1       NaN   2008-03-06         2500           18      829
# 2       NaN   2008-03-06         2500           18      830
# 3       NaN   2008-03-06         2500           18      831
# 4       NaN   2008-03-06         2500           18      832
#
#    PROPIEDAD_CLIENTE COD_CLIENTE ULTIMA_AMORTIZACION  IMP_PTE_AMORTIZAR  \
# 0              False         NaN                 NaT                NaN
# 1              False         NaN                 NaT                NaN
# 2              False         NaN                 NaT                NaN
# 3              False         NaN                 NaT                NaN
# 4              False         NaN                 NaT                NaN
#
#   NUM_ACTIVO_FIJO  RECLAMADO CUARENTENA GENETICA RAZA2 FECHA_ENTRADA_PROD
# 0             NaN      False        NaN      NaN   NaN                NaT
# 1             NaN      False        NaN      NaN   NaN                NaT
# 2             NaN      False        NaN      NaN   NaN                NaT
# 3             NaN      False        NaN      NaN   NaN                NaT
# 4             NaN      False        NaN      NaN   NaN                NaT

# %%
verracos['LINEA_GEN'].value_counts()
# Out:
# PIETUPB      214
# DANBRED      197
# PAC          106
# TDDDD         70
# AND           65
# DURGEN        38
# DUPIC         35
# PTAXIOM       34
# TUUUU         34
# TEEEE         33
# TAAAA         33
# TVVVV         28
# TZZZZ         27
# TPPPP         27
# BLUEACMC      21
# TLLLL         20
# DNA           18
# LDAX          18
# AGSG          17
# TDDPP         16
# PTADN         13
# TIIII         12
# DURAXIOM      12
# LWAX          10
# LWACMC        10
# PTSER          9
# TNNNN          8
# TPPNP          8
# LDADN          8
# DURADN         7
# PTALE          7
# LWADN          5
# MAXSEG         5
# PIETRAIN       5
# L65            4
# TBBBB          4
# PIETUPBFR      4
# ADNREK         4
# TPPNN          3
# IBERICO        3
# PTAUSBAR       1
# PIETGEN        1
# Name: LINEA_GEN, dtype: int64

# %%
verracos['PROCEDENCIA'].value_counts()
# Out:
# PEÑAS DE SAN PEDRO                                    159
# MEJORADA                                              102
# ANTONIO LOPEZ                                          83
# BURUTAIN                                               53
# ESCORIAL                                               50
# PEÑAS                                                  48
# QUALITAT ESPERMATICA                                   44
# AIM LEON                                               42
# TAFALLA                                                37
# SINOVAS                                                34
# ACOMPOR                                                24
# GANADOS PERALTA S.L                                    24
# ALMENAR                                                23
# ZAHARA                                                 22
# GENESUS INC OAKVILLE MB ID NO 5326121                  18
# LA COMETA                                              17
# CAN JAUMO                                              17
# EXPLOTACIONES CUFA                                     17
# DESCONOCIDA                                            16
# HASTRUPGARD, HASTRUPGARDSVEJ 7000 FREDERICIA DENMA     16
# AIM SINOVAS                                            15
# SORIA                                                  14
# PEUT VAN DE V.O.F.                                     14
# PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE HOL     13
# ALBAGES                                                12
# LA MASIA                                               12
# BUJARALOZ                                              12
# UPB GENETIC                                            12
# LEON                                                   11
# MAS GALLAT                                             11
# REPUBLICA CHECA                                        11
# AIM SORIA                                              11
# GRUPO ALTOPASO A CORUÑA                                10
# JOSSE PASCAL LE POURCAUD AUGAN FRANCE                  10
# ROHWER TIMO LOOPER WEG 19 24589 SCHULP ALEMANIA        10
# HASTRUPGARD HASTRUPGARDSVEJ 8 7000 FREDERICIA D
# FINA MARKUS AM LAUBENBUCH WEIBENBURG GERMANY            1
# EARL FERME DE LA VALLEE HERBINGHEM FRANCE               1
# CUARENTENA UPB                                          1
# ECKARDT BERND HOHNWEG 14 SONNFELD GERMANY               1
# AGUILAFUENTE                                            1
# ARRI TURRI, SL                                          1
# ATEZ (NAVARRA)                                          1
# ES250020011665                                          1
# CASETA SANTASUSANA SAN MATEU DE BAGES                   1
# DECONOCIDO                                              1
# ALMOLDA                                                 1
# TRAINING MEJORADA                                       1
# UPB GENETICA                                            1
# KERBELAY (MARZAN)                                       1
# TOPIGS IBERICA SL                                       1
# QUALITAT ESPERMÁTICA                                    1
# ECKARDT BEECKARDT BERND SONNEFELD GERMANY               1
# CAN CARRERAS                                            1
# QIALITAT ESPERMATICA                                    1
# VITORIA                                                 1
# MAALING III SLEVADVEJ 3 6560 SOMMERSTED DENMARK         1
# SCEA PINIER-JOSSO KERBELAY MARZAN 56130 FRANCIA         1
# SANCHEZ ROMERO CARVAJAL JABUGO S.A.                     1
# EARL ARMANE LE BOIS CLAIR EVAILLE 72120 FRANCIA         1
# TRAINING TOPINS                                         1
# LL. TANKEDAL DENMARK 6580 VANDRUP                       1
# GAEC DES PORCS SAINS LA FOURBERIE GUIGNEN 35580         1
# VAN DE PEUT B.V                                         1
# BARCELONA                                               1
# INGA FOOD SA ALMENDRALEJO BADAJOZ                       1
# GANADERA MOBEGRO                                        1
# BURUATIN                                                1
# GRANJA ZAHARA TOLEDO SPAIN                              1
# TRANING TOPIGS                                          1
# CUARENTENA SOSA                                         1
# JULE TOR HENRIK - - - - 7710 SPARBU - - NORWAY          1
# INGLATERRA                                              1
# BERGSHOLM VIDAR N 3160 STOKKE NORUEGA                   1
# SAS ADN (MAIGRIS)                                       1
# QUALITA ESPERMATICA                                     1
# FINA MARKUS AM LAUBENBUCH 2 WEIBENBURG ALEMANIA         1
# TOJAPIGS SARL DOMBRAS - 1, RUE NAPOLEON - -FRANCE       1
# FRANCIA                                                 1
# Name: PROCEDENCIA, dtype: int64

# %% [markdown]
# **Para saber si un verraco es productivo o no es necesario establecer un mínimo de dosis reales producidas en un año**

# %%
# Agrupo por cada verraco y cuento sus dosis reales en sus años de producción. Reseteo los índices con el objetivo de poder hacer un merge con estos
group_1 = df.groupby(['COD_VERRACO', 'AÑO'])['DOSIS_REAL'].count()
group_1 = pd.DataFrame(group_1)
group_1 = group_1.reset_index()
group_1.head()
# Out:
#    COD_VERRACO   AÑO  DOSIS_REAL
# 0          770  2013           1
# 1         1048  2012           3
# 2         1048  2013          18
# 3         1049  2012           3
# 4         1049  2013          12

# %%
group_1.shape
# Out:
# (3146, 3)

# %%
merged = pd.merge(df, group_1, on=['COD_VERRACO', 'AÑO'])

# %%
merged.head(10)
# Out:
#    CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 0  140901 2020-01-03         2095  620ND06    CAL          68          56
# 1  141423 2020-01-13         2095  620ND06    CAL          68          55
# 2  141683 2020-01-17         2095  620ND06    CAL          68          78
# 3  141838 2020-01-20         2095  620ND06    CAL          68          55
# 4  142047 2020-01-24         2095  620ND06    CAL          68          83
# 5  142252 2020-01-27         2095  620ND06    CAL          68          83
# 6  142651 2020-02-03         2095  620ND06    CAL          68          55
# 7  142857 2020-02-07         2095  620ND06    CAL          68          55
# 8  143016 2020-02-10         2095  620ND06    CAL          68          83
# 9  142449 2020-01-29         2095  620ND06    CAL          68          78
#
#    VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 0      317             76          9                   7               10
# 1      562             87          8                   7               22
# 2      639            166          9                   7               48
# 3      272             96          9                   8               11
# 4      500             76          9                   8               17
# 5      433             92          9                   7               18
# 6      643            111          9                   8               32
# 7      354             66          9                   7               10
# 8      458             72          9                   7               14
# 9      380             56          8                   7                9
#
#    DOSIS_REAL_x  DOSIS_A_DILUIR  DILUYENTE  SEMEN_ANADIR  CONCENTRACION_REAL  \
# 0            10             0.0      513.0           317                2409
# 1            22             0.0     1264.0           562                2222
# 2            48             0.0     3345.0           639                2210
# 3            11             0.0      641.0           272                2374
# 4            17             0.0      911.0           500                2235
# 5            18             0.0     1061.0           433                2213
# 6            32             0.0     2013.0           643                2230
# 7            10             0.0      476.0           354                2336
# 8            14             0.0      704.0           458                2355
# 9             0             0.0        0.0            32                   0
#
#   VALIDO MOTIVO_DESECHO MOTIVO_DIFERENCIA HETEROSPERMIA CODIGO_HETEROSPERMIA  \
# 0   True             OK                OK          True          N07DDA10101
# 1   True             OK                OK          True          N07DDA10303
# 2   True             OK                OK          True          N07DDA10310
# 3   True             OK                OK          True          N07DDA10403
# 4   True             OK                OK          True          N07DDA10406
# 5   True             OK                OK          True          N07DDA10502
# 6   True             OK                OK          True          N07DDA10602
# 7   True             OK                OK          True          N07DDA10606
# 8   True             OK                OK          True          N07DDA10703
# 9  False              F                OK         False                  NaN
#
#    ENVASADAS  DILUIDO  BOLASER_BLANCO  BOLASER_MA  ID_DILUYENTE  ML_DILUYENTE  \
# 0    98.3125     True         30995.0         0.0        2730.0         513.0
# 1    68.6250     True         31483.0         0.0        2749.0        1264.0
# 2     0.0000     True         31475.0         0.0        2760.0        3345.0
# 3     0.0000     True         31343.0         0.0        2765.0         641.0
# 4     0.0000     True         30832.0         0.0        2774.0         911.0
# 5     0.0000     True         30999.0         0.0        2780.0        1061.0
# 6     0.0000     True         30976.0         0.0        2795.0        2013.0
# 7     0.0000     True         31049.0         0.0        2806.0         476.0
# 8     0.0000     True         31177.0         0.0        2812.0         704.0
# 9     0.0000    False         30983.0         0.0           0.0           0.0
#
#       RAZA  DOSIS DILUIDAS  TEMP_DILUYENTE  CONDUCTIVIDAD   AÑO  MES  \
# 0  DANBRED              10       20.299999           10.6  2020    1
# 1  DANBRED              22       20.500000           10.7  2020    1
# 2  DANBRED              48       20.299999           10.4  2020    1
# 3  DANBRED              11       20.500000           10.5  2020    1
# 4  DANBRED              17       20.200001           10.4  2020    1
# 5  DANBRED              18       20.799999           10.8  2020    1
# 6  DANBRED              32       20.900000           10.6  2020    2
# 7  DANBRED              10       21.100000           10.5  2020    2
# 8  DANBRED              14       20.799999           10.4  2020    2
# 9  DANBRED               0             NaN            NaN  2020    1
#
#    DOSIS_REAL_y
# 0            18
# 1            18
# 2            18
# 3            18
# 4            18
# 5            18
# 6            18
# 7            18
# 8            18
# 9            18

# %% [markdown]
# **DOSIS_REAL_y es el valor de la producción de dosis anual en el año de la fecha de recogida. En base a este dato y suponiendo que, para ser considerado productivo, un verraco ha de producir más de 50 dosis al año, creo la nueva columna 'PRODUCTIVO' con valores 1 si es productivo, 0 si no.**

# %%
merged['DOSIS_REAL_y'].unique()
# Out:
# array([ 18,  11,  45,  17,  81,   2,  73,  37,  62,  56,  36,  80,  84,
#         70,  86,  58,  65,  28, 120,  44,   9, 128, 101,  51,  64,  61,
#         48,  33,  53,  82, 130,  60,  46,  77,  92,  76,  47,  72,  31,
#         79,  71,  90,  95,  26,  19, 138,  94, 139, 141, 135, 134, 133,
#        126, 147, 131, 136,  30, 123,  24,  40,  21,  29,  27,  39,   4,
#         89,   1,  42,  14,  32,  59, 140,  10, 143, 116,  22, 145, 100,
#         63,  88,  15,  85,  54,  35,  74,  83,  20,  69,  52,  41,   7,
#        109,  99,  50,  55,  13,  23,  49, 121, 103,  87,  43,  75,  34,
#         68,  91, 125,  16, 127,  78,   5,  67,  66,  57,  12,  25,   3,
#          8,   6, 104,  97, 106,  96, 144, 107, 114, 115, 118, 108, 112,
#         98, 166, 119, 105, 132, 102, 113, 152, 165, 156, 111,  93,  38,
#        122, 117, 124, 110, 129, 137, 142, 148, 154, 151])

# %%
merged['PRODUCTIVO'] = 0

# %%
merged['PRODUCTIVO'] = np.where(merged['DOSIS_REAL_y'] >= 80, 1, 0)

# %%
merged.head()
# Out:
#    CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 0  140901 2020-01-03         2095  620ND06    CAL          68          56
# 1  141423 2020-01-13         2095  620ND06    CAL          68          55
# 2  141683 2020-01-17         2095  620ND06    CAL          68          78
# 3  141838 2020-01-20         2095  620ND06    CAL          68          55
# 4  142047 2020-01-24         2095  620ND06    CAL          68          83
#
#    VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 0      317             76          9                   7               10
# 1      562             87          8                   7               22
# 2      639            166          9                   7               48
# 3      272             96          9                   8               11
# 4      500             76          9                   8               17
#
#    DOSIS_REAL_x  DOSIS_A_DILUIR  DILUYENTE  SEMEN_ANADIR  CONCENTRACION_REAL  \
# 0            10             0.0      513.0           317                2409
# 1            22             0.0     1264.0           562                2222
# 2            48             0.0     3345.0           639                2210
# 3            11             0.0      641.0           272                2374
# 4            17             0.0      911.0           500                2235
#
#   VALIDO MOTIVO_DESECHO MOTIVO_DIFERENCIA HETEROSPERMIA CODIGO_HETEROSPERMIA  \
# 0   True             OK                OK          True          N07DDA10101
# 1   True             OK                OK          True          N07DDA10303
# 2   True             OK                OK          True          N07DDA10310
# 3   True             OK                OK          True          N07DDA10403
# 4   True             OK                OK          True          N07DDA10406
#
#    ENVASADAS  DILUIDO  BOLASER_BLANCO  BOLASER_MA  ID_DILUYENTE  ML_DILUYENTE  \
# 0    98.3125     True         30995.0         0.0        2730.0         513.0
# 1    68.6250     True         31483.0         0.0        2749.0        1264.0
# 2     0.0000     True         31475.0         0.0        2760.0        3345.0
# 3     0.0000     True         31343.0         0.0        2765.0         641.0
# 4     0.0000     True         30832.0         0.0        2774.0         911.0
#
#       RAZA  DOSIS DILUIDAS  TEMP_DILUYENTE  CONDUCTIVIDAD   AÑO  MES  \
# 0  DANBRED              10       20.299999           10.6  2020    1
# 1  DANBRED              22       20.500000           10.7  2020    1
# 2  DANBRED              48       20.299999           10.4  2020    1
# 3  DANBRED              11       20.500000           10.5  2020    1
# 4  DANBRED              17       20.200001           10.4  2020    1
#
#    DOSIS_REAL_y  PRODUCTIVO
# 0            18           0
# 1            18           0
# 2            18           0
# 3            18           0
# 4            18           0

# %%
merged['PRODUCTIVO'].value_counts()
# Out:
# 1    78700
# 0    74999
# Name: PRODUCTIVO, dtype: int64

# %% [markdown]
# **Del data frame de VERRACOS no nos interesa toda la información existente. Me creo un data frame que posteriormente uniremos a "datos_modelo"**

# %% [markdown]
# **Así mismo, del dataframe de EYACULADOS no nos interesa toda la información**

# %%
small_verracos = verracos.loc[:, ['LINEA_GEN', 'CODIGO', 'PROCEDENCIA']]
small_eyaculados = merged.loc[:, ['COD_VERRACO', 'CENTRO', 'DOSIS_REAL_x', 'RAZA', 'AÑO', 'DOSIS_REAL_y', 'PRODUCTIVO']]

# %%
small_verracos.head(5)
# Out:
#   LINEA_GEN  CODIGO PROCEDENCIA
# 0       NaN     828         NaN
# 1       NaN     829         NaN
# 2       NaN     830         NaN
# 3       NaN     831         NaN
# 4       NaN     832         NaN

# %%
small_eyaculados.head()
# Out:
#    COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA   AÑO  DOSIS_REAL_y  PRODUCTIVO
# 0         2095    CAL            10  DANBRED  2020            18           0
# 1         2095    CAL            22  DANBRED  2020            18           0
# 2         2095    CAL            48  DANBRED  2020            18           0
# 3         2095    CAL            11  DANBRED  2020            18           0
# 4         2095    CAL            17  DANBRED  2020            18           0

# %% [markdown]
# **Hay que ligar la tabla "datos_modelo" junto con "verracos" según el código del verraco para añadir en "datos_modelo" el valor de LIENA_GEN y PROCEDENCIA**

# %%
datos_modelo = pd.merge(small_eyaculados, small_verracos, left_on='COD_VERRACO', right_on='CODIGO', how='outer')

# %%
datos_modelo.head()
# Out:
#    COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 0       2095.0    CAL          10.0  DANBRED  2020.0          18.0
# 1       2095.0    CAL          22.0  DANBRED  2020.0          18.0
# 2       2095.0    CAL          48.0  DANBRED  2020.0          18.0
# 3       2095.0    CAL          11.0  DANBRED  2020.0          18.0
# 4       2095.0    CAL          17.0  DANBRED  2020.0          18.0
#
#    PRODUCTIVO LINEA_GEN  CODIGO                        PROCEDENCIA
# 0         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 1         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 2         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 3         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 4         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE

# %%
datos_modelo.shape
# Out:
# (154216, 10)

# %% [markdown]
# ## PREPROCESAMIENTO - ANÁLISI Y LIMPIEZA

# %% [markdown]
# **Una vez seleccionado y calculado los datos necesarios para el correcto funcionamiento del modelo, procedo a hacer la correspondiente limpieza de datos en busca de valores NaN, NaT o valores carentes de sentido**

# %%
datos_modelo.shape
# Out:
# (154216, 10)

# %%
print(datos_modelo.isnull().sum().sum())
# Out:
# 45218

# %% [markdown]
# **Existe un total de 45.218 valores NaN, voy a localizar dónde están exactamente:**

# %%
datos_modelo.isnull().sum()
# Out:
# COD_VERRACO       517
# CENTRO            517
# DOSIS_REAL_x      517
# RAZA             1091
# AÑO               517
# DOSIS_REAL_y      517
# PRODUCTIVO        517
# LINEA_GEN       20952
# CODIGO            214
# PROCEDENCIA     19859
# dtype: int64

# %% [markdown]
# **Como tanto en CODIGO como en COD_VERRACO existen valores nulos siendo estos verracos sin código asignado, los elimino directamente. Son verracos a los que no se les puede realizar un seguimiento**

# %%
datos_modelo = datos_modelo.dropna(subset=["COD_VERRACO"])
datos_modelo = datos_modelo.dropna(subset=["CODIGO"])

# %%
datos_modelo.isnull().sum()
# Out:
# COD_VERRACO         0
# CENTRO              0
# DOSIS_REAL_x        0
# RAZA              574
# AÑO                 0
# DOSIS_REAL_y        0
# PRODUCTIVO          0
# LINEA_GEN       20246
# CODIGO              0
# PROCEDENCIA     19391
# dtype: int64

# %% [markdown]
# **Al ser variables categóricas (y no poder asignar la media de los valores de los verracos semejantes, por ejemplo) he decidido eliminar los NaN restantes**

# %%
datos_modelo = datos_modelo.dropna(subset=["LINEA_GEN"])
datos_modelo = datos_modelo.dropna(subset=["PROCEDENCIA"])
datos_modelo = datos_modelo.dropna(subset=["RAZA"])

# %%
datos_modelo.isnull().sum()
# Out:
# COD_VERRACO     0
# CENTRO          0
# DOSIS_REAL_x    0
# RAZA            0
# AÑO             0
# DOSIS_REAL_y    0
# PRODUCTIVO      0
# LINEA_GEN       0
# CODIGO          0
# PROCEDENCIA     0
# dtype: int64

# %%
print(datos_modelo.shape)
print(datos_modelo.isnull().sum().sum())
# Out:
# (115101, 10)
# 0

# %%
datos_modelo.head()
# Out:
#    COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 0       2095.0    CAL          10.0  DANBRED  2020.0          18.0
# 1       2095.0    CAL          22.0  DANBRED  2020.0          18.0
# 2       2095.0    CAL          48.0  DANBRED  2020.0          18.0
# 3       2095.0    CAL          11.0  DANBRED  2020.0          18.0
# 4       2095.0    CAL          17.0  DANBRED  2020.0          18.0
#
#    PRODUCTIVO LINEA_GEN  CODIGO                        PROCEDENCIA
# 0         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 1         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 2         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 3         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 4         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE

# %% [markdown]
# **Una vez eliminados los NaN, se analizan particularidades**

# %%
datos_modelo['CENTRO'].value_counts()
# Out:
# CAL      75155
# PEÑAS    36165
# TOL       3781
# Name: CENTRO, dtype: int64

# %% [markdown]
# **Nada mal en CENTRO**

# %%
datos_modelo['RAZA'].value_counts()
# Out:
# 0             23941
# DANBRED       21051
# AND            8513
# PIETUPBNN      6542
# PIETUPBJJ      6423
# PAC            5417
# TDDDD          5349
# DUPIC          5152
# PIETUPB        3967
# TEEEE          3595
# DNA            2050
# PIETAXIOM      1989
# DURGENES       1759
# AGSG           1725
# TLLLL          1635
# ADN            1583
# TUUUUIBE       1247
# TVVVV          1173
# DCAXIOM         999
# LDAX            989
# TPPNP           875
# TPPPPTOP        871
# BLUEACMC        779
# TDDPP           698
# LWAX            631
# LDADN           548
# PIETUPBFR       492
# PI ALEM NP      464
# TIIII           451
# DCADN           428
# IBERICO         396
# TUUUU           294
# TPPPPELI        276
# LWADN           261
# TZZZZGGP        236
# MAXSEG          230
# DURGENMJJ       223
# DURGENG         222
# ADNREK          221
# DURGENM         205
# TAAAAGGP        199
# DURGENESM       165
# L65P+           142
# LWACMC          127
# TUUUUEFI        116
# TZZZZ           111
# PACCAR          100
# PIETSERGAL       87
# TUUUUCAL         87
# TUUUUGGP         30
# TPPNN            22
# TDDDDTOP         10
# TAAAA             3
# -                 1
# DAN-INGA          1
# Name: RAZA, dtype: int64

# %% [markdown]
# **Hay una raza denominada '-' y otra con nombre '0'. Elimino ambas**

# %%
datos_modelo[datos_modelo['RAZA'] == '-']
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x RAZA     AÑO  DOSIS_REAL_y  \
# 35099       2484.0    TOL          13.0    -  2019.0          88.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO    PROCEDENCIA
# 35099         1.0     TDDPP  2484.0  GRANJA ZAHARA

# %%
datos_modelo[datos_modelo['RAZA'] == 0].head()
# Out:
#      COD_VERRACO CENTRO  DOSIS_REAL_x RAZA     AÑO  DOSIS_REAL_y  PRODUCTIVO  \
# 906       1872.0  PEÑAS          18.0    0  2015.0          61.0         0.0
# 907       1872.0  PEÑAS          24.0    0  2015.0          61.0         0.0
# 908       1872.0  PEÑAS          38.0    0  2015.0          61.0         0.0
# 909       1872.0  PEÑAS          31.0    0  2015.0          61.0         0.0
# 910       1872.0  PEÑAS          10.0    0  2015.0          61.0         0.0
#
#     LINEA_GEN  CODIGO  PROCEDENCIA
# 906   DANBRED  1872.0  DESCONOCIDA
# 907   DANBRED  1872.0  DESCONOCIDA
# 908   DANBRED  1872.0  DESCONOCIDA
# 909   DANBRED  1872.0  DESCONOCIDA
# 910   DANBRED  1872.0  DESCONOCIDA

# %%
datos_modelo = datos_modelo.drop(datos_modelo[datos_modelo['RAZA'] == '-'].index, axis=0)
datos_modelo = datos_modelo.drop(datos_modelo[datos_modelo['RAZA'] == 0].index, axis=0)

# %%
datos_modelo['RAZA'].value_counts()
# Out:
# DANBRED       21051
# AND            8513
# PIETUPBNN      6542
# PIETUPBJJ      6423
# PAC            5417
# TDDDD          5349
# DUPIC          5152
# PIETUPB        3967
# TEEEE          3595
# DNA            2050
# PIETAXIOM      1989
# DURGENES       1759
# AGSG           1725
# TLLLL          1635
# ADN            1583
# TUUUUIBE       1247
# TVVVV          1173
# DCAXIOM         999
# LDAX            989
# TPPNP           875
# TPPPPTOP        871
# BLUEACMC        779
# TDDPP           698
# LWAX            631
# LDADN           548
# PIETUPBFR       492
# PI ALEM NP      464
# TIIII           451
# DCADN           428
# IBERICO         396
# TUUUU           294
# TPPPPELI        276
# LWADN           261
# TZZZZGGP        236
# MAXSEG          230
# DURGENMJJ       223
# DURGENG         222
# ADNREK          221
# DURGENM         205
# TAAAAGGP        199
# DURGENESM       165
# L65P+           142
# LWACMC          127
# TUUUUEFI        116
# TZZZZ           111
# PACCAR          100
# PIETSERGAL       87
# TUUUUCAL         87
# TUUUUGGP         30
# TPPNN            22
# TDDDDTOP         10
# TAAAA             3
# DAN-INGA          1
# Name: RAZA, dtype: int64

# %%
datos_modelo.shape
# Out:
# (91159, 10)

# %% [markdown]
# **Eliminados los valores extraños en RAZA**

# %%
print(datos_modelo['DOSIS_REAL_x'].min())
print(datos_modelo['DOSIS_REAL_x'].max())
# Out:
# 0.0
# 122.0

# %%
datos_modelo['DOSIS_REAL_x'].unique()
# Out:
# array([ 10.,  22.,  48.,  11.,  17.,  18.,  32.,  14.,   0.,  25.,  23.,
#         21.,  33.,  58.,  15.,  43.,  12.,  13.,  70.,  24.,  28.,  36.,
#         41.,  57.,  38.,  26.,  16.,  51.,  37.,   6.,  39.,  20.,   8.,
#          9.,  19.,   5.,  34.,  47.,  31.,  27.,  29.,  42.,  52.,  30.,
#         44.,  40.,  66.,  50.,  71.,  55.,  45.,  68.,  35.,   4.,  74.,
#         59.,  53.,   3.,  67.,  80.,  61.,  64.,  54.,  63.,  90.,  62.,
#         60.,  65.,  88.,  49.,  46.,   7.,   2.,  56.,  69.,  76.,  75.,
#         84.,  85.,  82.,  72.,  73.,  89.,  87.,  86.,  96.,  79.,  98.,
#         77.,  83.,  78.,  91.,  95.,  92.,  94., 111., 101.,  93.,  81.,
#        100., 106., 103.,  97., 110., 107., 102., 109.,  99., 122., 114.,
#          1.])

# %%
print(datos_modelo['DOSIS_REAL_y'].min())
print(datos_modelo['DOSIS_REAL_y'].max())
# Out:
# 1.0
# 166.0

# %%
datos_modelo['DOSIS_REAL_x'].unique()
# Out:
# array([ 10.,  22.,  48.,  11.,  17.,  18.,  32.,  14.,   0.,  25.,  23.,
#         21.,  33.,  58.,  15.,  43.,  12.,  13.,  70.,  24.,  28.,  36.,
#         41.,  57.,  38.,  26.,  16.,  51.,  37.,   6.,  39.,  20.,   8.,
#          9.,  19.,   5.,  34.,  47.,  31.,  27.,  29.,  42.,  52.,  30.,
#         44.,  40.,  66.,  50.,  71.,  55.,  45.,  68.,  35.,   4.,  74.,
#         59.,  53.,   3.,  67.,  80.,  61.,  64.,  54.,  63.,  90.,  62.,
#         60.,  65.,  88.,  49.,  46.,   7.,   2.,  56.,  69.,  76.,  75.,
#         84.,  85.,  82.,  72.,  73.,  89.,  87.,  86.,  96.,  79.,  98.,
#         77.,  83.,  78.,  91.,  95.,  92.,  94., 111., 101.,  93.,  81.,
#        100., 106., 103.,  97., 110., 107., 102., 109.,  99., 122., 114.,
#          1.])

# %% [markdown]
# **Todo bien en DOSIS_REAL_x y DOSIS_REAL_y**

# %%
print(datos_modelo['AÑO'].min())
print(datos_modelo['AÑO'].max())
# Out:
# 2016.0
# 2021.0

# %%
datos_modelo['AÑO'].unique()
# Out:
# array([2020., 2019., 2018., 2017., 2016., 2021.])

# %%
datos_modelo['PRODUCTIVO'].value_counts()
# Out:
# 1.0    46900
# 0.0    44259
# Name: PRODUCTIVO, dtype: int64

# %%
datos_modelo['PRODUCTIVO'].unique()
# Out:
# array([0., 1.])

# %% [markdown]
# **Todo OK en AÑO y PRODUCTIVO**

# %%
datos_modelo['LINEA_GEN'].value_counts()
# Out:
# DANBRED      27043
# PIETUPB      17069
# PAC           5517
# TDDDD         5359
# DUPIC         5152
# TEEEE         3595
# AND           3498
# PTAXIOM       2576
# DURGEN        2574
# DNA           2224
# TPPPP         2044
# TUUUU         1774
# TLLLL         1635
# LDAX          1299
# TVVVV         1173
# DURAXIOM      1045
# PTADN          994
# BLUEACMC       779
# TIIII          738
# TDDPP          698
# LWAX           650
# AGSG           574
# PTALE          464
# DURADN         382
# PIETUPBFR      355
# TZZZZ          347
# LWADN          242
# LDADN          238
# MAXSEG         230
# ADNREK         221
# TAAAA          202
# L65            142
# LWACMC         127
# IBERICO        109
# PTSER           87
# PIETRAIN         3
# Name: LINEA_GEN, dtype: int64

# %% [markdown]
# **Todo OK en cuanto a genética**

# %%
datos_modelo['PROCEDENCIA'].value_counts()
# Out:
# QUALITAT ESPERMATICA                                  6601
# BURUTAIN                                              4834
# DESCONOCIDA                                           3549
# TAFALLA                                               3264
# EXPLOTACIONES CUFA                                    2796
# PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE HOL    2558
# GENESUS INC OAKVILLE MB ID NO 5326121                 2338
# GRUPO ALTOPASO A CORUÑA                               2112
# CAN JAUMO                                             1883
# ESCORIAL                                              1838
# LA COMETA                                             1747
# AIM LEON                                              1688
# DESCONOCIDO                                           1683
# ZAHARA                                                1669
# FUGLSANG DENMARK 4160 HERLUFMAGLE                     1660
# NAVARRA                                               1525
# MAS GALLAT                                            1519
# USA                                                   1513
# FINA MARKUS AM LAUBENBUCH 2 ALEMANIA                  1416
# LA MASIA                                              1403
# NEHER STEPHAN DORFSTR 16 ALEMANIA                     1268
# HASTRUPGARD HASTRUPGARDSVEJ 8 7000 FREDERICIA DK      1262
# LIPPERT NORBERT AURAER STR 1 ALEMANIA                 1188
# PEÑAS DE SAN PEDRO                                    1180
# UPB GENETIC                                           1148
# QUALITAT                                              1026
# SCHWARZ WOLFGANG BACHT STR 14 ALEMANIA                1024
# GRUPO ALTOPASO A CORUÑA ES150800089301                 971
# EL ESCORIAL                                            951
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ  DENMARK         939
# BUJARALOZ                                              931
# COMETA                                                 879
# MAALING AVL OG OPFORMERING SKELDEMARG 10 DENMARK       879
# KERNEIS KERINOU LE CONQUET 29217 FRANCIA               818
# ELTZABURU                                              779
# ACOMPOR                                                748
# KUGEL GEORG MAUERNER STR 23A ALEMANIA                  740
# GRANJA ZAHARA                                          734
# MUNKBRO II MUNKBROVEJ 7 7500 HOLSTEBRO DENMARK         716
# ECKARDT BERND GBR HOHNWEG 14 ALEMANIA                  702
# HASTRUPGARD, HASTRUPGARDSVEJ 7000 FREDERICIA DENMA     691
# TOJAPIGS SARL DROMBAS DROMBAS FRANCE                   683
# AVLSCENTRET HOLMEGARD A/S, FALDSLEDVEJ FABORG DK       677
# AIM ANDALUCIA                                          673
# ROHWER TIMO LOOPER WEG 19 24589 SCHULP ALEMANIA        653
# AIM PEÑAS                                              605
# NAVALAGAMELLA                                          600
# VAN DE PEUT B.V.                                       592
# LYKKENSGAARD AVLSCENTER ELLEDEVEJ 95 DENMARK           571
# ROHWER JURGEN BOKELER STR 5 24793 BRAMMER ALEMANIA     540
# GRANJA ZAHARA TOLEDO ESPAÑA                            540
# SCWARZ WOLFGANG BACHSTR 14 SALCHING ALEMANIA           539
# TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA          537
# TOM RATHJE COLUMBUS NEBRASKA USA                       501
# ELEVAGE DE BIZY OUZOUER LE MARCHE 41240 FRANCIA        500
# SINOVAS                                                492
# ALBAGES                                                475
# AIM ANDALUCÍA                                          470
# EXPLOTACIONES CUFA SL                                  420
# LEON                                                   418
# GRANJA ALTOPASO SOBRADO DE LOS MONJES A CORUÑA         384
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ DENMARK          377
# LA ALMOLDA                                             364
# GUMPP HERMANN KIRCHPLATZ 1, 89420 DEISENFOFEN ALEM     362
# UPB GENETIC WORLD                                      355
# LL. TANKEDAL DENMARK 6580 VANDRUP                      353
# ODARPI GENETICA VILLADIEGO                             342
# BEUNZA                                                 336
# JOSSE PASCAL LE POURCAUD AUGAN FRANCE                  334
# AIM SINOVAS                                            321
# GANADOS PERALTA S.L                                    313
# HORIZON CERAN LE FROMENTEAU CERANS FOULLETOURTE FR     309
# ALMUDEVAR                                              288
# ERTL JOHANNES GROSSHUNDLBACH 12 ALEMANIA               286
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN ALEMANIA               285
# AIM CENTRO                                             281
# GRANJA ALTOPASO  A CORUÑA SPAIN                        277
# UPB GENETICA                                           276
# ATEZ                                                   253
# EXPLTACIONES CUFA                                      250
# PETERSEN HANS DETLEF SUEDER  VOLSEMENHUSEN ALEMANI     233
# VAN DE PEUT B.V                                        208
# INTEGRACIONES PERALTA                                  208
# AGER                                                   207
# DECONOCIDO                                             204
# VOLSGAARDI DAMSTRUPVEJ ORNHOJ DENMARK                  203
# KERDANET                                               202
# QIALITAT ESPERMATICA                                   196
# LE BARON CHRISTIAN PEN LAN KERDAVID LE MOUSTOIR FR     191
# BERGSHOLM VIDAR N-3160 STOKKE NORUEGA                  189
# LA GARENNE 37310 AZAY-SUR-INDRE FRANCIA                174
# GRANJA ZAHARA (TOLEDO) ESPAÑA                          171
# FINA MARKUS AM LAUBNBUCH 2                             166
# GRANJA ZAHARA CERVERA TOLEDO ESPAÑA                    164
# ARANDA DE DUERO                                        164
# AIM SORIA                                              163
# FINA MARKUS AM LAUBENBUCH WEIBENBURG ALEMANIA          160
# EARL FERME DE LA VALLE 650 RUE DU PIRE ALLER FRANC     159
# ELEVAGE DE BIZY OUZOUERLE MARCHE FRANCE                154
# SANTENIS - C. CARRASCONES 12-2A - 45610 NAVALCAN T     151
# MAS EL CROS                                            147
# SCHAAF-SCHELD GBR ARNSHAINER WEG 5 WAHLEN ALEMANIA     142
# GAEC DES PORCS SAINS LA FOURBERIE GUIGNEN 35580        142
# PEUT BV, VAN DE - BAARLOSEWEG 18 -  MARKNESS NETHE     134
# MAALING III SLEVADVEJ 3 6560 SOMMERSTED DENMARK        134
# FINA MARKUS WEIBENBURG GERMANY                         131
# ODARPI VILLUSTO ESPAÑA                                 120
# ZAHARA CERVERA TOLEDO ESPAÑA                           107
# ATEZ (NAVARRA)                                         101
# SCEA PINIER-JOSSO KERBELAY MARZAN 56130 FRANCIA         98
# GANADERA MONEGRO                                        97
# EARL ARMANE LE BOIS CLAIR EVAILLE 72120 FRANCIA         95
# ESKEGAARD A/S MOLLEGYDE HADERSLEV DENMARK               95
# QUALITA ESPERMATICA                                     92
# CHANTELOUP                                              91
# ES5010370130002-00864                                   89
# VAN DE PEUT B.B.                                        87
# CASETA SANTASUSANA SAN MATEU DE BAGES                   85
# ELEVAGE DE BIZY OUZOUER LE MARCHE FRANCE                84
# CAN CARRERAS                                            84
# LIPPERT NORBERT EUERDORF GERMANY                        79
# PEÑAS DE SAN PÈDRO                                      78
# JULE TOR HENRIK - - - - 7710 SPARBU - - NORWAY          78
# QUALITAT ESPERMÁTICA                                    75
# KERBELAY (MARZAN)                                       75
# FINA MARKUS AM LAUBENBUCH 2 WEIBENBURG ALEMANIA         72
# SANTIBAÑEZ                                              70
# BIURRUN                                                 70
# KERNEIS KERINOU LE CONQUET FRANCE                       69
# KÜGEL GEORG MAUERNER STR PFÖRRING ALEMANIA              68
# TOJAPIGS SARL DOMBRAS - 1, RUE NAPOLEON - -FRANCE       63
# GRANJA ZAHARA TOLEDO SPAIN                              61
# TOPIGS NORSVIN ESPAÑA                                   61
# BERGSHOLM VIDAR N 3160 STOKKE NORUEGA                   46
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN GERMANY                 39
# EARL FERME DE LA VALLEE HERBINGHEM FRANCE               37
# SCHWARZ WOLFGANG SALCHING GERMANY                       35
# KUGEL GEORG PFORRING GERMANY                            34
# ALMOLDA                                                 31
# ERTL JOHANNES FRAUNBERG GERMANY                         28
# ECKARDT BEECKARDT BERND SONNEFELD GERMANY               21
# SCHWARZ WOLFGANG BACHSTR SALCHING GERMANY               19
# GUMPP HERMANN DEISENHOFEN GERMANY                       19
# EARL DARTOIS BEAUCHENE GUITE FRANCE                     17
# INGA FOOD SA ALMENDRALEJO BADAJOZ                       16
# SAS ADN (MAIGRIS)                                       14
# SCHAAF-SCHELD ARNSHAINER KIRTORF-WAHLEN GERMANY         12
# SANTENIS NAVALCAN TOLEDO SPAIN                          11
# GUMPP HERMANN KIRCHPLATZ 1 DEISENHOFEN GERMANY          10
# BARCELONA                                                9
# ECKARDT BERND HOHNWEG 14 SONNFELD GERMANY                8
# FINA MARKUS AM LAUBENBUCH WEIBENBURG GERMANY             6
# ECKARDT BERND SONNEFELD GERMANY                          4
# Name: PROCEDENCIA, dtype: int64

# %% [markdown]
# **Se puede apreciar tres procedencias iguales con distinto nombre: DESCONOCIDO, DESCONOCIDA, DECONOCIDA**

# %%
datos_modelo[datos_modelo['PROCEDENCIA'] == 'DESCONOCIDO'].head()
# Out:
#       COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 4202       2326.0    CAL          26.0  DANBRED  2020.0          58.0
# 4203       2326.0    CAL          16.0  DANBRED  2020.0          58.0
# 4204       2326.0    CAL          20.0  DANBRED  2020.0          58.0
# 4205       2326.0    CAL          27.0  DANBRED  2020.0          58.0
# 4206       2326.0    CAL          28.0  DANBRED  2020.0          58.0
#
#       PRODUCTIVO LINEA_GEN  CODIGO  PROCEDENCIA
# 4202         0.0   DANBRED  2326.0  DESCONOCIDO
# 4203         0.0   DANBRED  2326.0  DESCONOCIDO
# 4204         0.0   DANBRED  2326.0  DESCONOCIDO
# 4205         0.0   DANBRED  2326.0  DESCONOCIDO
# 4206         0.0   DANBRED  2326.0  DESCONOCIDO

# %%
datos_modelo[datos_modelo['PROCEDENCIA'] == 'DESCONOCIDA'].head()
# Out:
#      COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 433       1872.0    CAL           9.0  DANBRED  2020.0          11.0
# 434       1872.0    CAL          31.0  DANBRED  2020.0          11.0
# 435       1872.0    CAL           4.0  DANBRED  2020.0          11.0
# 436       1872.0    CAL          26.0  DANBRED  2020.0          11.0
# 437       1872.0    CAL          19.0  DANBRED  2020.0          11.0
#
#      PRODUCTIVO LINEA_GEN  CODIGO  PROCEDENCIA
# 433         0.0   DANBRED  1872.0  DESCONOCIDA
# 434         0.0   DANBRED  1872.0  DESCONOCIDA
# 435         0.0   DANBRED  1872.0  DESCONOCIDA
# 436         0.0   DANBRED  1872.0  DESCONOCIDA
# 437         0.0   DANBRED  1872.0  DESCONOCIDA

# %%
datos_modelo[datos_modelo['PROCEDENCIA'] == 'DECONOCIDO'].head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 12927       2421.0  PEÑAS          21.0  DANBRED  2020.0          30.0
# 12928       2421.0  PEÑAS          30.0  DANBRED  2020.0          30.0
# 12929       2421.0  PEÑAS          16.0  DANBRED  2020.0          30.0
# 12930       2421.0  PEÑAS          21.0  DANBRED  2020.0          30.0
# 12931       2421.0  PEÑAS          25.0  DANBRED  2020.0          30.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO PROCEDENCIA
# 12927         0.0   DANBRED  2421.0  DECONOCIDO
# 12928         0.0   DANBRED  2421.0  DECONOCIDO
# 12929         0.0   DANBRED  2421.0  DECONOCIDO
# 12930         0.0   DANBRED  2421.0  DECONOCIDO
# 12931         0.0   DANBRED  2421.0  DECONOCIDO

# %%
datos_modelo['PROCEDENCIA'] = np.where(datos_modelo['PROCEDENCIA'] == 'DESCONOCIDO', datos_modelo['PROCEDENCIA'] == 'DESCONOCIDA', datos_modelo['PROCEDENCIA'])
datos_modelo['PROCEDENCIA'] = np.where(datos_modelo['PROCEDENCIA'] == 'DECONOCIDO', datos_modelo['PROCEDENCIA'] == 'DESCONOCIDA', datos_modelo['PROCEDENCIA'])

# %%
datos_modelo['PROCEDENCIA'].value_counts()
# Out:
# QUALITAT ESPERMATICA                                  6601
# BURUTAIN                                              4834
# DESCONOCIDA                                           3549
# TAFALLA                                               3264
# EXPLOTACIONES CUFA                                    2796
# PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE HOL    2558
# GENESUS INC OAKVILLE MB ID NO 5326121                 2338
# GRUPO ALTOPASO A CORUÑA                               2112
# False                                                 1887
# CAN JAUMO                                             1883
# ESCORIAL                                              1838
# LA COMETA                                             1747
# AIM LEON                                              1688
# ZAHARA                                                1669
# FUGLSANG DENMARK 4160 HERLUFMAGLE                     1660
# NAVARRA                                               1525
# MAS GALLAT                                            1519
# USA                                                   1513
# FINA MARKUS AM LAUBENBUCH 2 ALEMANIA                  1416
# LA MASIA                                              1403
# NEHER STEPHAN DORFSTR 16 ALEMANIA                     1268
# HASTRUPGARD HASTRUPGARDSVEJ 8 7000 FREDERICIA DK      1262
# LIPPERT NORBERT AURAER STR 1 ALEMANIA                 1188
# PEÑAS DE SAN PEDRO                                    1180
# UPB GENETIC                                           1148
# QUALITAT                                              1026
# SCHWARZ WOLFGANG BACHT STR 14 ALEMANIA                1024
# GRUPO ALTOPASO A CORUÑA ES150800089301                 971
# EL ESCORIAL                                            951
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ  DENMARK         939
# BUJARALOZ                                              931
# MAALING AVL OG OPFORMERING SKELDEMARG 10 DENMARK       879
# COMETA                                                 879
# KERNEIS KERINOU LE CONQUET 29217 FRANCI
# GUMPP HERMANN KIRCHPLATZ 1 DEISENHOFEN GERMANY          10
# BARCELONA                                                9
# ECKARDT BERND HOHNWEG 14 SONNFELD GERMANY                8
# FINA MARKUS AM LAUBENBUCH WEIBENBURG GERMANY             6
# ECKARDT BERND SONNEFELD GERMANY                          4
# Name: PROCEDENCIA, dtype: int64

# %% [markdown]
# # FEATURE ENGINEERING

# %%
datos_modelo.head()
# Out:
#    COD_VERRACO CENTRO  DOSIS_REAL_x     RAZA     AÑO  DOSIS_REAL_y  \
# 0       2095.0    CAL          10.0  DANBRED  2020.0          18.0
# 1       2095.0    CAL          22.0  DANBRED  2020.0          18.0
# 2       2095.0    CAL          48.0  DANBRED  2020.0          18.0
# 3       2095.0    CAL          11.0  DANBRED  2020.0          18.0
# 4       2095.0    CAL          17.0  DANBRED  2020.0          18.0
#
#    PRODUCTIVO LINEA_GEN  CODIGO                        PROCEDENCIA
# 0         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 1         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 2         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 3         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE
# 4         0.0   DANBRED  2095.0  FUGLSANG DENMARK 4160 HERLUFMAGLE

# %%
datos_modelo.shape
# Out:
# (91159, 10)

# %% [markdown]
# **CENTRO, RAZA, LINEA_GEN y PROCEDENCIA son variables categóricas las cuales han de ser codificadas para poder introducirlas como parámetros al modelo. Para ello, utilizaré la técninca de Target Encoding**

# %% [markdown]
# **¡Importante!: Target Encoding se realiza solo sobre el conjunto de train. El algoritmo tiene que ser capaz de, cuando se le pase una lista de razas, identificarlas, asignarle probabilidades y calcular su influencia en la productividad. Al algoritmo no se le va a introducir las razas ya codificadas, sino una lista con las diferentes razas nuevas existentes.**

# %%
train, test = train_test_split(datos_modelo)

# %%
train.shape, test.shape
# Out:
# ((68369, 10), (22790, 10))

# %%
datos_modelo['RAZA'].value_counts()
# Out:
# DANBRED       21051
# AND            8513
# PIETUPBNN      6542
# PIETUPBJJ      6423
# PAC            5417
# TDDDD          5349
# DUPIC          5152
# PIETUPB        3967
# TEEEE          3595
# DNA            2050
# PIETAXIOM      1989
# DURGENES       1759
# AGSG           1725
# TLLLL          1635
# ADN            1583
# TUUUUIBE       1247
# TVVVV          1173
# DCAXIOM         999
# LDAX            989
# TPPNP           875
# TPPPPTOP        871
# BLUEACMC        779
# TDDPP           698
# LWAX            631
# LDADN           548
# PIETUPBFR       492
# PI ALEM NP      464
# TIIII           451
# DCADN           428
# IBERICO         396
# TUUUU           294
# TPPPPELI        276
# LWADN           261
# TZZZZGGP        236
# MAXSEG          230
# DURGENMJJ       223
# DURGENG         222
# ADNREK          221
# DURGENM         205
# TAAAAGGP        199
# DURGENESM       165
# L65P+           142
# LWACMC          127
# TUUUUEFI        116
# TZZZZ           111
# PACCAR          100
# PIETSERGAL       87
# TUUUUCAL         87
# TUUUUGGP         30
# TPPNN            22
# TDDDDTOP         10
# TAAAA             3
# DAN-INGA          1
# Name: RAZA, dtype: int64

# %% [markdown]
# **Como se puede apreciar en la lista arriba mostrada, de las razas TAAAA y DAN-INGA solo existen 3 y 1 verracos respectivamente. Las conclusiones que se obtengan en base a la probabilidad de ser productivo en base a esas determinadas razas no van a ser muy fiables**

# %%
razas_encoded = train.groupby('RAZA')['PRODUCTIVO'].agg(['mean', 'count']).sort_values(by='count', ascending=False)
razas_encoded
# Out:
#                 mean  count
# RAZA
# DANBRED     0.709835  15922
# AND         0.716131   6348
# PIETUPBNN   0.338205   4858
# PIETUPBJJ   0.596458   4800
# PAC         0.243500   4000
# TDDDD       0.431402   3987
# DUPIC       0.566978   3852
# PIETUPB     0.527316   2947
# TEEEE       0.383812   2681
# DNA         0.858247   1552
# PIETAXIOM   0.341153   1492
# DURGENES    0.246792   1325
# AGSG        0.580420   1287
# TLLLL       0.668265   1251
# ADN         0.390638   1175
# TUUUUIBE    0.312306    967
# TVVVV       0.316327    882
# DCAXIOM     0.649418    773
# LDAX        0.168263    731
# TPPNP       0.336377    657
# TPPPPTOP    0.352308    650
# BLUEACMC    0.106164    584
# TDDPP       0.367308    520
# LWAX        0.459290    479
# LDADN       0.427500    400
# PIETUPBFR   0.000000    373
# PI ALEM NP  0.000000    343
# TIIII       0.000000    336
# DCADN       0.645260    327
# IBERICO     0.327759    299
# TUUUU       0.647577    227
# TPPPPELI    0.330144    209
# LWADN       0.331731    208
# MAXSEG      0.774725    182
# DURGENMJJ   0.140449    178
# ADNREK      0.000000    174
# TZZZZGGP    0.000000    174
# DURGENG     0.000000    165
# DURGENM     0.293333    150
# TAAAAGGP    0.000000    143
# DURGENESM   0.000000    129
# L65P+       0.000000    115
# LWACMC      0.000000     93
# TUUUUEFI    0.000000     86
# TZZZZ       0.000000     83
# PACCAR      0.000000     78
# TUUUUCAL    0.882353     68
# PIETSERGAL  0.000000     67
# TUUUUGGP    0.000000     18
# TPPNN       0.000000     15
# TDDDDTOP    0.000000      5
# TAAAA       0.000000      3
# DAN-INGA    1.000000      1

# %% [markdown]
# **COMENTARIO RAZAS**

# %%
razas_encoded = train.groupby('RAZA')['PRODUCTIVO'].mean()
razas_encoded = pd.DataFrame(razas_encoded)
razas_encoded.columns = ['RAZA_ENCODED']
razas_encoded.head()
# Out:
#           RAZA_ENCODED
# RAZA
# ADN           0.390638
# ADNREK        0.000000
# AGSG          0.580420
# AND           0.716131
# BLUEACMC      0.106164

# %%
centros_encoded = train.groupby(['CENTRO'])['PRODUCTIVO'].agg(['mean', 'count']).sort_values(by='count', ascending=False)
centros_encoded
# Out:
#             mean  count
# CENTRO
# CAL     0.420932  41009
# PEÑAS   0.688410  24927
# TOL     0.315660   2433

# %%
centros_encoded = train.groupby(['CENTRO'])['PRODUCTIVO'].mean()
centros_encoded = pd.DataFrame(centros_encoded)
centros_encoded = centros_encoded.rename(columns = {'PRODUCTIVO':'CENTRO_ENCODED'})
centros_encoded
# Out:
#         CENTRO_ENCODED
# CENTRO
# CAL           0.420932
# PEÑAS         0.688410
# TOL           0.315660

# %%
genetica_encoded = train.groupby(['LINEA_GEN'])['PRODUCTIVO'].agg(['mean', 'count']).sort_values(by='count', ascending=False)
genetica_encoded
# Out:
#                mean  count
# LINEA_GEN
# DANBRED    0.716609  20357
# PIETUPB    0.476902  12707
# PAC        0.238843   4078
# TDDDD      0.430862   3992
# DUPIC      0.566978   3852
# TEEEE      0.383812   2681
# AND        0.614710   2624
# DURGEN     0.203390   1947
# PTAXIOM    0.413382   1928
# DNA        0.856043   1688
# TPPPP      0.338994   1531
# TUUUU      0.372621   1366
# TLLLL      0.668265   1251
# LDAX       0.307210    957
# TVVVV      0.316327    882
# DURAXIOM   0.639851    808
# PTADN      0.232022    737
# BLUEACMC   0.106164    584
# TIIII      0.176577    555
# TDDPP      0.367308    520
# LWAX       0.443548    496
# AGSG       0.640909    440
# PTALE      0.000000    343
# DURADN     0.671233    292
# PIETUPBFR  0.000000    271
# TZZZZ      0.000000    257
# LWADN      0.361257    191
# MAXSEG     0.774725    182
# LDADN      0.000000    174
# ADNREK     0.000000    174
# TAAAA      0.000000    146
# L65        0.000000    115
# LWACMC     0.000000     93
# IBERICO    0.000000     80
# PTSER      0.000000     67
# PIETRAIN   0.000000      3

# %%
genetica_encoded = train.groupby(['LINEA_GEN'])['PRODUCTIVO'].mean()
genetica_encoded = pd.DataFrame(genetica_encoded)
genetica_encoded = genetica_encoded.rename(columns = {'PRODUCTIVO':'GENETICA_ENCODED'})
genetica_encoded
# Out:
#            GENETICA_ENCODED
# LINEA_GEN
# ADNREK             0.000000
# AGSG               0.640909
# AND                0.614710
# BLUEACMC           0.106164
# DANBRED            0.716609
# DNA                0.856043
# DUPIC              0.566978
# DURADN             0.671233
# DURAXIOM           0.639851
# DURGEN             0.203390
# IBERICO            0.000000
# L65                0.000000
# LDADN              0.000000
# LDAX               0.307210
# LWACMC             0.000000
# LWADN              0.361257
# LWAX               0.443548
# MAXSEG             0.774725
# PAC                0.238843
# PIETRAIN           0.000000
# PIETUPB            0.476902
# PIETUPBFR          0.000000
# PTADN              0.232022
# PTALE              0.000000
# PTAXIOM            0.413382
# PTSER              0.000000
# TAAAA              0.000000
# TDDDD              0.430862
# TDDPP              0.367308
# TEEEE              0.383812
# TIIII              0.176577
# TLLLL              0.668265
# TPPPP              0.338994
# TUUUU              0.372621
# TVVVV              0.316327
# TZZZZ              0.000000

# %%
procedencia_encoded = train.groupby(['PROCEDENCIA'])['PRODUCTIVO'].agg(['mean', 'count']).sort_values(by='count', ascending=False)
procedencia_encoded
# Out:
#                                                         mean  count
# PROCEDENCIA
# QUALITAT ESPERMATICA                                0.768479   4911
# BURUTAIN                                            0.385710   3653
# DESCONOCIDA                                         0.659661   2712
# TAFALLA                                             0.641640   2464
# EXPLOTACIONES CUFA                                  0.728256   2127
# PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE HOL  0.503165   1896
# GENESUS INC OAKVILLE MB ID NO 5326121               0.223729   1770
# GRUPO ALTOPASO A CORUÑA                             0.728727   1563
# False                                               0.742275   1424
# CAN JAUMO                                           0.567376   1410
# ESCORIAL                                            0.468906   1399
# LA COMETA                                           0.417317   1282
# FUGLSANG DENMARK 4160 HERLUFMAGLE                   0.840190   1264
# ZAHARA                                              0.254183   1255
# AIM LEON                                            0.229455   1229
# USA                                                 0.868467   1148
# MAS GALLAT                                          0.514537   1135
# NAVARRA                                             0.819073   1122
# LA MASIA                                            0.755725   1048
# FINA MARKUS AM LAUBENBUCH 2 ALEMANIA                0.408602   1023
# HASTRUPGARD HASTRUPGARDSVEJ 8 7000 FREDERICIA DK    0.626911    981
# NEHER STEPHAN DORFSTR 16 ALEMANIA                   0.618221    922
# LIPPERT NORBERT AURAER STR 1 ALEMANIA               0.757812    896
# PEÑAS DE SAN PEDRO                                  0.391206    887
# UPB GENETIC                                         0.460819    855
# SCHWARZ WOLFGANG BACHT STR 14 ALEMANIA              0.457847    771
# QUALITAT                                            0.506579    760
# GRUPO ALTOPASO A CORUÑA ES150800089301              0.597297    740
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ  DENMAR
# ELEVAGE DE BIZY OUZOUER LE MARCHE FRANCE            0.000000     66
# LIPPERT NORBERT EUERDORF GERMANY                    0.000000     63
# CAN CARRERAS                                        0.000000     62
# PEÑAS DE SAN PÈDRO                                  0.000000     62
# CHANTELOUP                                          0.000000     62
# JULE TOR HENRIK - - - - 7710 SPARBU - - NORWAY      0.000000     60
# QUALITAT ESPERMÁTICA                                0.000000     59
# VAN DE PEUT B.B.                                    0.000000     56
# SANTIBAÑEZ                                          0.000000     55
# KERBELAY (MARZAN)                                   0.000000     53
# KÜGEL GEORG MAUERNER STR PFÖRRING ALEMANIA          0.000000     53
# BIURRUN                                             0.000000     51
# GRANJA ZAHARA TOLEDO SPAIN                          0.000000     51
# FINA MARKUS AM LAUBENBUCH 2 WEIBENBURG ALEMANIA     0.000000     50
# KERNEIS KERINOU LE CONQUET FRANCE                   0.000000     47
# TOJAPIGS SARL DOMBRAS - 1, RUE NAPOLEON - -FRANCE   0.000000     46
# TOPIGS NORSVIN ESPAÑA                               0.000000     45
# BERGSHOLM VIDAR N 3160 STOKKE NORUEGA               0.000000     38
# EARL FERME DE LA VALLEE HERBINGHEM FRANCE           0.000000     30
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN GERMANY             0.000000     30
# SCHWARZ WOLFGANG SALCHING GERMANY                   0.000000     28
# KUGEL GEORG PFORRING GERMANY                        0.000000     27
# ALMOLDA                                             0.000000     21
# ERTL JOHANNES FRAUNBERG GERMANY                     0.000000     20
# ECKARDT BEECKARDT BERND SONNEFELD GERMANY           0.000000     18
# GUMPP HERMANN DEISENHOFEN GERMANY                   0.000000     18
# EARL DARTOIS BEAUCHENE GUITE FRANCE                 0.000000     16
# SCHWARZ WOLFGANG BACHSTR SALCHING GERMANY           0.000000     13
# INGA FOOD SA ALMENDRALEJO BADAJOZ                   0.000000     10
# SAS ADN (MAIGRIS)                                   0.000000      9
# SCHAAF-SCHELD ARNSHAINER KIRTORF-WAHLEN GERMANY     0.000000      9
# SANTENIS NAVALCAN TOLEDO SPAIN                      0.000000      8
# GUMPP HERMANN KIRCHPLATZ 1 DEISENHOFEN GERMANY      0.000000      8
# BARCELONA                                           0.000000      7
# ECKARDT BERND HOHNWEG 14 SONNFELD GERMANY           0.000000      6
# FINA MARKUS AM LAUBENBUCH WEIBENBURG GERMANY        0.000000      4
# ECKARDT BERND SONNEFELD GERMANY                     0.000000      3

# %%
procedencia_encoded = train.groupby(['PROCEDENCIA'])['PRODUCTIVO'].mean()
procedencia_encoded = pd.DataFrame(procedencia_encoded)
procedencia_encoded = procedencia_encoded.rename(columns = {'PRODUCTIVO':'PROCEDENCIA_ENCODED'})
procedencia_encoded
# Out:
#                                                     PROCEDENCIA_ENCODED
# PROCEDENCIA
# False                                                          0.742275
# ACOMPOR                                                        0.363316
# AGER                                                           0.454545
# AIM ANDALUCIA                                                  0.400398
# AIM ANDALUCÍA                                                  0.577031
# AIM CENTRO                                                     0.000000
# AIM LEON                                                       0.229455
# AIM PEÑAS                                                      0.656587
# AIM SINOVAS                                                    0.000000
# AIM SORIA                                                      0.000000
# ALBAGES                                                        0.425770
# ALMOLDA                                                        0.000000
# ALMUDEVAR                                                      0.000000
# ARANDA DE DUERO                                                0.596774
# ATEZ                                                           0.000000
# ATEZ (NAVARRA)                                                 0.000000
# AVLSCENTRET HOLMEGARD A/S, FALDSLEDVEJ FABORG DK               0.998012
# BARCELONA                                                      0.000000
# BERGSHOLM VIDAR N 3160 STOKKE NORUEGA                          0.000000
# BERGSHOLM VIDAR N-3160 STOKKE NORUEGA                          0.532847
# BEUNZA                                                         0.387352
# BIURRUN                                                        0.000000
# BUJARALOZ                                                      0.530191
# BURUTAIN                                                       0.385710
# CAN CARRERAS                                                   0.000000
# CAN JAUMO                                                      0.567376
# CASETA SANTASUSANA SAN MATEU DE BAGES                          0.000000
# CHANTELOUP                                                     0.000000
# COMETA                                                         0.449624
# DESCONOCIDA                                                    0.659661
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN ALEMANIA                       0.000000
# SCHAAF-SCHELD GBR KIRTOF-WAHLEN GERMANY                        0.000000
# SCHWARZ WOLFGANG BACHSTR SALCHING GERMANY                      0.000000
# SCHWARZ WOLFGANG BACHT STR 14 ALEMANIA                         0.457847
# SCHWARZ WOLFGANG SALCHING GERMANY                              0.000000
# SCWARZ WOLFGANG BACHSTR 14 SALCHING ALEMANIA                   0.000000
# SINOVAS                                                        0.549865
# TAFALLA                                                        0.641640
# TOJAPIGS SARL DOMBRAS - 1, RUE NAPOLEON - -FRANCE              0.000000
# TOJAPIGS SARL DOMBRAS-1, RUE NAPOLEON FRANCIA                  0.325123
# TOJAPIGS SARL DROMBAS DROMBAS FRANCE                           0.607004
# TOM RATHJE COLUMBUS NEBRASKA USA                               0.960733
# TOPIGS NORSVIN ESPAÑA                                          0.000000
# UPB GENETIC                                                    0.460819
# UPB GENETIC WORLD                                              0.000000
# UPB GENETICA                                                   0.774510
# USA                                                            0.868467
# VAN DE PEUT B.B.                                               0.000000
# VAN DE PEUT B.V                                                0.443709
# VAN DE PEUT B.V.                                               0.490153
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ  DENMARK                 0.995792
# VOLSGAARD I DAMSTRUPVEJ 2 6973 OHRNOJ DENMARK                  0.847584
# VOLSGAARDI DAMSTRUPVEJ ORNHOJ DENMARK                          0.000000
# ZAHARA                                                         0.254183
# ZAHARA CERVERA TOLEDO ESPAÑA                                   0.000000

# %%
train = train.merge(razas_encoded, how='outer', left_on='RAZA', right_index=True)

# %%
train = train.merge(centros_encoded, how='outer', left_on='CENTRO', right_index=True)

# %%
train = train.merge(genetica_encoded, how='outer', left_on='LINEA_GEN', right_index=True)

# %%
#train = train.merge(procedencia_encoded, how='outer', left_on='PROCEDENCIA', right_index=True)

# %%
train.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x RAZA     AÑO  DOSIS_REAL_y  \
# 32106       2469.0    CAL          49.0  PAC  2019.0          85.0
# 32585       2463.0    CAL          20.0  PAC  2018.0          12.0
# 32084       2469.0    CAL          58.0  PAC  2019.0          85.0
# 61634       2521.0    CAL           0.0  PAC  2019.0          29.0
# 58610       2050.0    CAL          53.0  PAC  2017.0          81.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO                            PROCEDENCIA  \
# 32106         1.0       PAC  2469.0   FINA MARKUS AM LAUBENBUCH 2 ALEMANIA
# 32585         0.0       PAC  2463.0  KUGEL GEORG MAUERNER STR 23A ALEMANIA
# 32084         1.0       PAC  2469.0   FINA MARKUS AM LAUBENBUCH 2 ALEMANIA
# 61634         0.0       PAC  2521.0                  INTEGRACIONES PERALTA
# 58610         1.0       PAC  2050.0                             MAS GALLAT
#
#        RAZA_ENCODED  CENTRO_ENCODED  GENETICA_ENCODED
# 32106        0.2435        0.420932          0.238843
# 32585        0.2435        0.420932          0.238843
# 32084        0.2435        0.420932          0.238843
# 61634        0.2435        0.420932          0.238843
# 58610        0.2435        0.420932          0.238843

# %% [markdown]
# **Ya tengo las variables categóricas codificadas con valores numéricos**

# %% [markdown]
# **Los valores de las variables categóricas estan en tanto por 1. He de escalar el valor de DOSIS_REAL_x (dosis reales en cada extracción) para poder compararlas**

# %%
train.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x RAZA     AÑO  DOSIS_REAL_y  \
# 32106       2469.0    CAL          49.0  PAC  2019.0          85.0
# 32585       2463.0    CAL          20.0  PAC  2018.0          12.0
# 32084       2469.0    CAL          58.0  PAC  2019.0          85.0
# 61634       2521.0    CAL           0.0  PAC  2019.0          29.0
# 58610       2050.0    CAL          53.0  PAC  2017.0          81.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO                            PROCEDENCIA  \
# 32106         1.0       PAC  2469.0   FINA MARKUS AM LAUBENBUCH 2 ALEMANIA
# 32585         0.0       PAC  2463.0  KUGEL GEORG MAUERNER STR 23A ALEMANIA
# 32084         1.0       PAC  2469.0   FINA MARKUS AM LAUBENBUCH 2 ALEMANIA
# 61634         0.0       PAC  2521.0                  INTEGRACIONES PERALTA
# 58610         1.0       PAC  2050.0                             MAS GALLAT
#
#        RAZA_ENCODED  CENTRO_ENCODED  GENETICA_ENCODED
# 32106        0.2435        0.420932          0.238843
# 32585        0.2435        0.420932          0.238843
# 32084        0.2435        0.420932          0.238843
# 61634        0.2435        0.420932          0.238843
# 58610        0.2435        0.420932          0.238843

# %% [markdown]
# **Ya tengo las cuatro variables codificadas en tanto por 1, listas para ser modeladas**

# %% [markdown]
# # CREACIÓN DEL MODELO

# %%
train.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x RAZA     AÑO  DOSIS_REAL_y  \
# 32106       2469.0    CAL          49.0  PAC  2019.0          85.0
# 32585       2463.0    CAL          20.0  PAC  2018.0          12.0
# 32084       2469.0    CAL          58.0  PAC  2019.0          85.0
# 61634       2521.0    CAL           0.0  PAC  2019.0          29.0
# 58610       2050.0    CAL          53.0  PAC  2017.0          81.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO                            PROCEDENCIA  \
# 32106         1.0       PAC  2469.0   FINA MARKUS AM LAUBENBUCH 2 ALEMANIA
# 32585         0.0       PAC  2463.0  KUGEL GEORG MAUERNER STR 23A ALEMANIA
# 32084         1.0       PAC  2469.0   FINA MARKUS AM LAUBENBUCH 2 ALEMANIA
# 61634         0.0       PAC  2521.0                  INTEGRACIONES PERALTA
# 58610         1.0       PAC  2050.0                             MAS GALLAT
#
#        RAZA_ENCODED  CENTRO_ENCODED  GENETICA_ENCODED
# 32106        0.2435        0.420932          0.238843
# 32585        0.2435        0.420932          0.238843
# 32084        0.2435        0.420932          0.238843
# 61634        0.2435        0.420932          0.238843
# 58610        0.2435        0.420932          0.238843

# %%
x_train = train.loc[:, ['RAZA_ENCODED', 'CENTRO_ENCODED', 'GENETICA_ENCODED', 'DOSIS_REAL_x']]
y_train = train['PRODUCTIVO']

# %%
test.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x       RAZA     AÑO  DOSIS_REAL_y  \
# 21819       2393.0    CAL          40.0      TEEEE  2018.0          41.0
# 22078       2370.0    CAL          31.0  PIETUPBNN  2020.0          79.0
# 9002        2461.0    CAL          11.0    PIETUPB  2019.0          87.0
# 14595       2502.0    CAL          11.0   TUUUUIBE  2019.0          91.0
# 52919       2384.0    CAL          54.0      TEEEE  2018.0          54.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO  \
# 21819         0.0     TEEEE  2393.0
# 22078         0.0   PIETUPB  2370.0
# 9002          1.0   PIETUPB  2461.0
# 14595         1.0     TUUUU  2502.0
# 52919         0.0     TEEEE  2384.0
#
#                                              PROCEDENCIA
# 21819  PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE...
# 22078                  NEHER STEPHAN DORFSTR 16 ALEMANIA
# 9002               ECKARDT BERND GBR HOHNWEG 14 ALEMANIA
# 14595                         ODARPI GENETICA VILLADIEGO
# 52919                                           AIM LEON

# %%
test = test.merge(razas_encoded, how='outer', left_on='RAZA', right_index=True)

test = test.merge(centros_encoded, how='outer', left_on='CENTRO', right_index=True)

test = test.merge(genetica_encoded, how='outer', left_on='LINEA_GEN', right_index=True)

#test = test.merge(procedencia_encoded, how='outer', left_on='PROCEDENCIA', right_index=True)

# %%
test.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x   RAZA     AÑO  DOSIS_REAL_y  \
# 21819       2393.0    CAL          40.0  TEEEE  2018.0          41.0
# 52919       2384.0    CAL          54.0  TEEEE  2018.0          54.0
# 6976        2297.0    CAL          26.0  TEEEE  2019.0         120.0
# 54736       2353.0    CAL          27.0  TEEEE  2019.0         103.0
# 73050       2064.0    CAL          30.0  TEEEE  2018.0          20.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO  \
# 21819         0.0     TEEEE  2393.0
# 52919         0.0     TEEEE  2384.0
# 6976          1.0     TEEEE  2297.0
# 54736         1.0     TEEEE  2353.0
# 73050         0.0     TEEEE  2064.0
#
#                                              PROCEDENCIA  RAZA_ENCODED  \
# 21819  PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE...      0.383812
# 52919                                           AIM LEON      0.383812
# 6976                TOJAPIGS SARL DROMBAS DROMBAS FRANCE      0.383812
# 54736                                          CAN JAUMO      0.383812
# 73050                                        EL ESCORIAL      0.383812
#
#        CENTRO_ENCODED  GENETICA_ENCODED
# 21819        0.420932          0.383812
# 52919        0.420932          0.383812
# 6976         0.420932          0.383812
# 54736        0.420932          0.383812
# 73050        0.420932          0.383812

# %%
x_test = test.loc[:, ['RAZA_ENCODED', 'CENTRO_ENCODED', 'GENETICA_ENCODED', 'DOSIS_REAL_x']]
y_test = test['PRODUCTIVO']

# %% [markdown]
# **Redondeo los decimales de los float a 3 puesto que a veces el clasificador me daba problemas por la longitud de estos mismos**

# %%
train = train.round(2)
test = test.round(2)

# %%
train.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x RAZA     AÑO  DOSIS_REAL_y  \
# 32106       2469.0    CAL          49.0  PAC  2019.0          85.0
# 32585       2463.0    CAL          20.0  PAC  2018.0          12.0
# 32084       2469.0    CAL          58.0  PAC  2019.0          85.0
# 61634       2521.0    CAL           0.0  PAC  2019.0          29.0
# 58610       2050.0    CAL          53.0  PAC  2017.0          81.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO                            PROCEDENCIA  \
# 32106         1.0       PAC  2469.0   FINA MARKUS AM LAUBENBUCH 2 ALEMANIA
# 32585         0.0       PAC  2463.0  KUGEL GEORG MAUERNER STR 23A ALEMANIA
# 32084         1.0       PAC  2469.0   FINA MARKUS AM LAUBENBUCH 2 ALEMANIA
# 61634         0.0       PAC  2521.0                  INTEGRACIONES PERALTA
# 58610         1.0       PAC  2050.0                             MAS GALLAT
#
#        RAZA_ENCODED  CENTRO_ENCODED  GENETICA_ENCODED
# 32106          0.24            0.42              0.24
# 32585          0.24            0.42              0.24
# 32084          0.24            0.42              0.24
# 61634          0.24            0.42              0.24
# 58610          0.24            0.42              0.24

# %%
test.head()
# Out:
#        COD_VERRACO CENTRO  DOSIS_REAL_x   RAZA     AÑO  DOSIS_REAL_y  \
# 21819       2393.0    CAL          40.0  TEEEE  2018.0          41.0
# 52919       2384.0    CAL          54.0  TEEEE  2018.0          54.0
# 6976        2297.0    CAL          26.0  TEEEE  2019.0         120.0
# 54736       2353.0    CAL          27.0  TEEEE  2019.0         103.0
# 73050       2064.0    CAL          30.0  TEEEE  2018.0          20.0
#
#        PRODUCTIVO LINEA_GEN  CODIGO  \
# 21819         0.0     TEEEE  2393.0
# 52919         0.0     TEEEE  2384.0
# 6976          1.0     TEEEE  2297.0
# 54736         1.0     TEEEE  2353.0
# 73050         0.0     TEEEE  2064.0
#
#                                              PROCEDENCIA  RAZA_ENCODED  \
# 21819  PEUT BV VAN DE BAARLOSEWEG 18 8316 SG MARKENSE...          0.38
# 52919                                           AIM LEON          0.38
# 6976                TOJAPIGS SARL DROMBAS DROMBAS FRANCE          0.38
# 54736                                          CAN JAUMO          0.38
# 73050                                        EL ESCORIAL          0.38
#
#        CENTRO_ENCODED  GENETICA_ENCODED
# 21819            0.42              0.38
# 52919            0.42              0.38
# 6976             0.42              0.38
# 54736            0.42              0.38
# 73050            0.42              0.38

# %%
def clasificador_arbol(X_train, Y_train, X_test, Y_test):
    
    tree = DecisionTreeClassifier()

    tree.fit(X_train, Y_train)
    preds = tree.predict(X_test)
    probs = tree.predict_proba(X_test)
    fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], color='red', linestyle='--')
    return metricas(Y_test,preds)

# %%
def metricas(Y_test, preds):
    
    auc = roc_auc_score(Y_test, preds)  
    print('AUC: %.2f' % auc) 
    return accuracy_score(Y_test, preds), recall_score(Y_test, preds), precision_score(Y_test, preds), f1_score(Y_test, preds)

# %%
clasificador_arbol(x_train, y_train, x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-3aae0944e196> in <module>
# ----> 1 clasificador_arbol(x_train, y_train, x_test, y_test)
#
# <ipython-input-87-0a0c8cedccdb> in clasificador_arbol(X_train, Y_train, X_test, Y_test)
#       4
#       5     tree.fit(X_train, Y_train)
# ----> 6     preds = tree.predict(X_test)
#       7     probs = tree.predict_proba(X_test)
#       8     fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/tree/tree.py in predict(self, X, check_input)
#     414         """
#     415         check_is_fitted(self, 'tree_')
# --> 416         X = self._validate_X_predict(X, check_input)
#     417         proba = self.tree_.predict(X)
#     418         n_samples = X.shape[0]
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     375         """Validate X whenever one tries to predict, apply, predict_proba"""
#     376         if check_input:
# --> 377             X = check_array(X, dtype=DTYPE, accept_sparse="csr")
#     378             if issparse(X) and (X.indices.dtype != np.intc or
#     379                                 X.indptr.dtype != np.intc):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %% [markdown]
# **Accuracy_score: Es el porcentaje total de elementos clasificados correctamente: 68.96%**
#
# **Recall_score: Pocentaje de cerdos productivos que somos capaces de detectar: 78.013%**
#
# **Precision_score: Es el número de elementos identificados correctamente como positivo de un total de elementos identificados como positivos; qué fiabilidad tiene cuando predecimos un positivo: 68.814%.**

# %% [markdown]
# # Modelo de Logistic Regressor

# %%
def clasificador_LR(X_train, Y_train, X_test, Y_test):
    
    classifier = LogisticRegression()
    
    classifier.fit(X_train, y_train)
    preds = classifier.predict(X_test)
    probs = classifier.predict_proba(X_test)
    fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], color='red', linestyle='--')
    return metricas(Y_test,preds)

# %%
clasificador_LR(x_train, y_train, x_test, y_test)

# %%
train.columns

# %%
df_small = train.loc[:,['PRODUCTIVO','RAZA_ENCODED', 'CENTRO_ENCODED', 'GENETICA_ENCODED', 'DOSIS_REAL_x_NORMALIZADO']]

# %%
correlation_mat = df_small.corr()

# %%
sns.heatmap(correlation_mat, annot = True);

# %% [markdown]
# **Con el heatmap se puede ver de antemano algunas relaciones entre diferentes variables con ser productivo o no**

# %% [markdown]
# **Haciendo uno con muchas variables se podria llegar a ver de antemano cuales serán las variables que mas relacion den y por ende las que mejor funcionen en un modelo predictivo**
