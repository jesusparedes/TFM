# %% [markdown]
# **2. Especialmente será interesante cómo se comportan los verracos que llevan regularmente un pinchazo de ENZAPROST
# o DINO (que son prostaglandinas que les estimulan puntualmente la libido pero puede que les baje la productividad
# inmediata o a corto plazo), así como el resto de medicaciones. Ten en cuenta que cuando un verraco recibe una
# medicación es porque está enfermo, así que lo normal será que su productividad esté disminuida. Supongo que será
# un reto encontrar relaciones sólidas entre tratamientos y calidad seminal o supervivencia del verraco en el centro.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

df = pd.read_excel('EYACULADOS.xlsx')
df.head(5)
# Out:
#    CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 0  140901 2020-01-03         2095  620ND06    CAL          68          56
# 1  140902 2020-01-03         1872  520ND19    CAL          68          55
# 2  140903 2020-01-03         2094  620ND05    CAL          68          83
# 3  140904 2020-01-03         2086  620ND96    CAL          68          78
# 4  140905 2020-01-03         2470  807DP42    CAL          68          83
#
#    VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 0      317             76          9                   7               10
# 1      357             61          9                   7                9
# 2      511            156          9                   7               36
# 3      497            134          9                   8               30
# 4      572            116          9                   7               30
#
# ...

# %%
df['COD_VERRACO'].value_counts().head()
# Out:
# 1872    534
# 2094    446
# 1941    435
# 2095    433
# 2086    417
# Name: COD_VERRACO, dtype: int64

# %% [markdown]
# **INTENTO GRAFICAR TODO PARA VER LA DISMINUCIÓN DE LA PRODUCTIVIDAD**

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

df_tratamientos = pd.read_excel('TRATAMIENTOS_VERRACOS.xlsx')
df_tratamientos.head(15)
# Out:
#     CODIGO  COD_VERRACO      FECHA   DURACION COD_TRATAMIENTO NOTAS CENTRO
# 0    29344       2221.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS
# 1    29345       2407.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS
# 2    29346       2409.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS
# 3    29347       2416.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS
# 4    29348       2419.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS
# 5    29349       2422.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS
# 6    29350       2201.0 2019-05-27 2019-05-29            PARA   NaN    CAL
# 7    29351       2390.0 2019-05-27 2019-05-29            PARA   NaN    CAL
# 8    29352       2391.0 2019-05-27 2019-05-29            PARA   NaN    CAL
# 9    29353       2392.0 2019-05-27 2019-05-29            PARA   NaN    CAL
# 10   29354       2393.0 2019-05-27 2019-05-29            PARA   NaN    CAL
# ...

# %%
df_tratamientos['POI'] = 20
df_tratamientos.head()
# Out:
#    CODIGO  COD_VERRACO      FECHA   DURACION COD_TRATAMIENTO NOTAS CENTRO  POI
# 0   29344       2221.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS   20
# 1   29345       2407.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS   20
# 2   29346       2409.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS   20
# 3   29347       2416.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS   20
# 4   29348       2419.0 2019-05-30 2019-05-30       ENZAPROST   NaN  PEÑAS   20

# %%
verraco_2221_tratamiento = df_tratamientos[df_tratamientos['COD_VERRACO'] == 2221]
verraco_2221_tratamiento.head()
# Out:
#      CODIGO  COD_VERRACO      FECHA   DURACION COD_TRATAMIENTO     NOTAS  \
# 0     29344       2221.0 2019-05-30 2019-05-30       ENZAPROST       NaN
# 43    24506       2221.0 2018-05-20 2018-05-20       ENZAPROST  NO SALTA
# 64    24527       2221.0 2018-05-24 2018-05-24       ENZAPROST  NO SALTA
# 108   24501       2221.0 2018-05-17 2018-05-17       ENZAPROST  NO SALTA
# 114   24542       2221.0 2018-05-27 2018-05-27       ENZAPROST  NO SALTA
#
#     CENTRO  POI
# 0    PEÑAS   20
# 43   PEÑAS   20
# 64   PEÑAS   20
# 108  PEÑAS   20
# 114  PEÑAS   20

# %%
verraco_2221_tratamiento_ENZAPROST = verraco_2221_tratamiento[verraco_2221_tratamiento['COD_TRATAMIENTO'] == 'ENZAPROST']
verraco_2221_tratamiento_ENZAPROST.head()
# Out:
#      CODIGO  COD_VERRACO      FECHA   DURACION COD_TRATAMIENTO     NOTAS  \
# 0     29344       2221.0 2019-05-30 2019-05-30       ENZAPROST       NaN
# 43    24506       2221.0 2018-05-20 2018-05-20       ENZAPROST  NO SALTA
# 64    24527       2221.0 2018-05-24 2018-05-24       ENZAPROST  NO SALTA
# 108   24501       2221.0 2018-05-17 2018-05-17       ENZAPROST  NO SALTA
# 114   24542       2221.0 2018-05-27 2018-05-27       ENZAPROST  NO SALTA
#
#     CENTRO  POI
# 0    PEÑAS   20
# 43   PEÑAS   20
# 64   PEÑAS   20
# 108  PEÑAS   20
# 114  PEÑAS   20

# %%
x = verraco_2221_tratamiento_ENZAPROST['FECHA']
y = verraco_2221_tratamiento_ENZAPROST['POI']

plt.stem(x, y)
plt.plot_date(x, y, '*', color='red');

# %%
verraco_2221_datos = df[df['COD_VERRACO'] == 2221]
verraco_2221_datos = verraco_2221_datos.sort_values(by='FECHA_REC')
verraco_2221_datos.head()
# Out:
#        CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 69203   87118 2017-05-30         2221  720ND17  PEÑAS          68          58
# 69416   87302 2017-06-02         2221  720ND17  PEÑAS          68          58
# 69501   87557 2017-06-07         2221  720ND17  PEÑAS          68          69
# 69894   87816 2017-06-12         2221  720ND17  PEÑAS          47          58
# 70259   88256 2017-06-19         2221  720ND17  PEÑAS          47          69
#
#        VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 69203      416            179          9                   8               33
# 69416      426            116          9                   9               22
# 69501      518             97          9                   9               22
# 69894      399             84          8                   8               15
# 70259      470            145          8                   7               30
#
# ...

# %%
x = verraco_2221_datos['FECHA_REC']
y = verraco_2221_datos['DOSIS_REAL']

# %%
plt.plot(x, y, '-', linewidth=1)

# %%
fig, ax = plt.subplots()

x = verraco_2221_tratamiento_ENZAPROST['FECHA']
y = verraco_2221_tratamiento_ENZAPROST['POI']

x1 = verraco_2221_datos['FECHA_REC']
y1 = verraco_2221_datos['DOSIS_REAL']

fig1 = plt.figure(1)
ax.plot_date(x, y, '*', color='red');
ax.plot(x1, y1, '-', linewidth=1)
plt.title('Producción DOSIS_REAL verraco 2221')
fig1.set_size_inches(12, 6)
plt.savefig("grafica_inyecciones.jpg")

# %% [markdown]
# **Miro el primer valor de fecha de los tratameintos y ploteo la produccion de dosis desde ahí**

# %%
fechas_tratamientos = verraco_2221_tratamiento_ENZAPROST['FECHA']
fechas_tratamientos = pd.DataFrame(fechas_tratamientos)
fechas_tratamientos = fechas_tratamientos.sort_values(by='FECHA')
fechas_tratamientos = fechas_tratamientos.reset_index()
fecha_inicial = fechas_tratamientos['FECHA'][0]
fecha_inicial
# Out:
# Timestamp('2018-05-17 00:00:00')

# %%
borrar = verraco_2221_datos[verraco_2221_datos['FECHA_REC'] >= fecha_inicial]
borrar = borrar.sort_values(by='FECHA_REC')
borrar.head()
# Out:
#        CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 50145  109107 2018-05-18         2221  720ND17  PEÑAS          47          58
# 49828  109210 2018-05-21         2221  720ND17  PEÑAS          68          58
# 50430  109500 2018-05-25         2221  720ND17  PEÑAS          68          58
# 50212  109598 2018-05-28         2221  720ND17  PEÑAS          68          58
# 50339  109741 2018-05-30         2221  720ND17  PEÑAS          68          58
#
#        VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 50145      470             93          8                   7               19
# 49828      432             97          9                   7               19
# 50430      470            132          9                   7               28
# 50212      485            122          9                   7               26
# 50339      498            138          9                   7               31
#
# ...

# %%
fig, ax = plt.subplots()

x = verraco_2221_tratamiento_ENZAPROST['FECHA']
y = verraco_2221_tratamiento_ENZAPROST['POI']

x1 = borrar['FECHA_REC']
y1= borrar['DOSIS_REAL']

fig1 = plt.figure(1)
ax.plot_date(x, y, '*', color='red');
ax.plot(x1, y1, '-', linewidth=1)
plt.title('Producción DOSIS_REAL verraco 2221')
fig1.set_size_inches(20, 6)

# %% [markdown]
# **En el gráfico anterior se puede apreciar la producción de DOSIS_REAL del verraco 2221 partiendo desde el momento en el que se le suminsitró la primera dosis de ENZAPROST**

# %% [markdown]
# **Procedo a estudiar la influencia sobre el tratameinto ENZAPROST sobre otros verracos**

# %%
lista = df_tratamientos['COD_VERRACO'].value_counts()
lista.head()
# Out:
# 1872.0    233
# 2422.0    195
# 1946.0    194
# 2229.0    190
# 2044.0    174
# Name: COD_VERRACO, dtype: int64

# %%
lista.index[0]
# Out:
# 1872.0

# %% [markdown]
# **EL verraco con COD_VERRACO 1872 posee 233 inyecciones. Analizo la influencia de ENZAPROST sobre la producción de DOSIS_REAL**

# %%
verraco_1872_datos = df[df['COD_VERRACO'] == 1872]
verraco_1872_datos.shape
# Out:
# (534, 32)

# %%
verraco_1872_datos.head()
# Out:
#       CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 1     140902 2020-01-03         1872  520ND19    CAL          68          55
# 657   141708 2020-01-17         1872  520ND19    CAL          68          78
# 939   141840 2020-01-20         1872  520ND19    CAL          68          78
# 1342  142049 2020-01-24         1872  520ND19    CAL          68          78
# 1388  143285 2020-02-14         1872  520ND19    CAL          68          55
#
#       VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 1         357             61          9                   7                9
# 657       475            146          9                   7               31
# 939       142             64          8                   7                4
# 1342      453            130          8                   7               26
# 1388      485             89          8                   7               19
#
# ...

# %%
media = verraco_1872_datos['DOSIS_REAL'].mean()
media
# Out:
# 21.724719101123597

# %%
verraco_1872_datos = verraco_1872_datos.sort_values(by='FECHA_REC')
verraco_1872_datos.head()
# Out:
#         CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  \
# 113097   34744 2015-04-24         1872  520ND19  PEÑAS          32
# 111638   34827 2015-04-27         1872  520ND19  PEÑAS          32
# 113213   35020 2015-04-29         1872  520ND19  PEÑAS          47
# 111790   35280 2015-05-04         1872  520ND19  PEÑAS          47
# 111835   35666 2015-05-11         1872  520ND19  PEÑAS          32
#
#         RECOLECTOR  VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  \
# 113097          69      331            184          9                   8
# 111638          69      312            104          8                   8
# 113213          69      315            100          8                   8
# 111790          69      348            137          8                   7
# 111835          69      358            177          9                   8
#
#         DOSIS_POTENCIAL  DOSIS_REAL  DOSIS_A_DILUIR  DILUYENTE  SEMEN_ANADIR  \
# ...

# %%
verraco_1872_tratamiento = df_tratamientos[df_tratamientos['COD_VERRACO'] == 1872]
verraco_1872_tratamiento.shape
# Out:
# (233, 8)

# %%
verraco_1872_tratamiento_ENZAPROST =  verraco_1872_tratamiento[verraco_1872_tratamiento['COD_TRATAMIENTO'] == 'ENZAPROST']
verraco_1872_tratamiento_ENZAPROST.shape
# Out:
# (118, 8)

# %%
verraco_1872_tratamiento_ENZAPROST.head()
# Out:
#        CODIGO  COD_VERRACO      FECHA   DURACION COD_TRATAMIENTO     NOTAS  \
# 19023   21155       1872.0 2017-10-21 2017-10-21       ENZAPROST  NO SALTA
# 19028   21160       1872.0 2017-10-24 2017-10-24       ENZAPROST  NO SALTA
# 19037   21169       1872.0 2017-10-26 2017-10-26       ENZAPROST  NO SALTA
# 20639   25649       1872.0 2018-08-09 2018-08-09       ENZAPROST  NO SALTA
# 21905   21175       1872.0 2017-10-28 2017-10-28       ENZAPROST  NO SALTA
#
#       CENTRO  POI
# 19023    CAL   20
# 19028    CAL   20
# 19037    CAL   20
# 20639    CAL   20
# 21905    CAL   20

# %%
fig, ax = plt.subplots()

x = verraco_1872_tratamiento_ENZAPROST['FECHA']
y = verraco_1872_tratamiento_ENZAPROST['POI']

x1 = verraco_1872_datos['FECHA_REC']
y1= verraco_1872_datos['DOSIS_REAL']

fig1 = plt.figure(1)
ax.plot_date(x, y, '*', color='red');
ax.plot(x1, y1, '-', linewidth=1)
plt.title('Producción DOSIS_REAL verraco 1872')
fig1.set_size_inches(20, 8)

# %% [markdown]
# **Acorto el muestreo de la producción haciendo que empiece por el primer día de inyectado de tratamiento**

# %%
fechas_tratamientos = verraco_1872_tratamiento_ENZAPROST['FECHA']
fechas_tratamientos = pd.DataFrame(fechas_tratamientos)
fechas_tratamientos = fechas_tratamientos.sort_values(by='FECHA')
fechas_tratamientos = fechas_tratamientos.reset_index()
fecha_inicial = fechas_tratamientos['FECHA'][0]
fecha_inicial
# Out:
# Timestamp('2017-10-21 00:00:00')

# %%
fechas_tratamientos = fechas_tratamientos.sort_values(by='FECHA', ascending=False).reset_index()

# %%
fecha_final = fechas_tratamientos['FECHA'][0]

# %%
type(fecha_final)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
a = verraco_1872_datos[verraco_1872_datos['FECHA_REC'] >= fecha_inicial]

# %%
a.shape
# Out:
# (240, 32)

# %%
b = a[a['FECHA_REC'] <= fecha_final]

# %%
b.shape
# Out:
# (239, 32)

# %%
aux = verraco_1872_datos[verraco_1872_datos['FECHA_REC'] >= fecha_inicial]
aux = aux.sort_values(by='FECHA_REC')
aux.shape
# Out:
# (240, 32)

# %%
aux.head()
# Out:
#        CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 78474   96644 2017-10-23         1872  520ND19  PEÑAS          47          58
# 78750   96847 2017-10-25         1872  520ND19  PEÑAS          68          58
# 78916   97000 2017-10-27         1872  520ND19  PEÑAS          68          58
# 79087   97096 2017-10-30         1872  520ND19  PEÑAS          68          58
# 79212   97300 2017-11-01         1872  520ND19  PEÑAS          47          58
#
#        VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 78474      503             93          8                   7               21
# 78750      441            170          9                   7               34
# 78916      512            106          8                   7               24
# 79087      462            136          9                   7               28
# 79212      479             96          8                   8               20
#
# ...

# %%
fig, ax = plt.subplots()

x = verraco_1872_tratamiento_ENZAPROST['FECHA']
y = verraco_1872_tratamiento_ENZAPROST['POI']

x1 = aux['FECHA_REC']
y1= aux['DOSIS_REAL']

fig1 = plt.figure(1)
ax.plot_date(x, y, '*', color='red');
ax.plot(x1, y1, '-', linewidth=1)
plt.title('Producción DOSIS_REAL verraco 1872')
fig1.set_size_inches(20, 6)

# %% [markdown]
# **EL verraco con COD_VERRACO 2422 posee 195 inyecciones. Analizo la influencia de ENZAPROST sobre la producción de DOSIS_REAL**

# %%
lista = df_tratamientos['COD_VERRACO'].value_counts()
lista.head(10)
# Out:
# 1872.0    233
# 2422.0    195
# 1946.0    194
# 2229.0    190
# 2044.0    174
# 1832.0    163
# 1863.0    162
# 2374.0    158
# 2421.0    156
# 1932.0    155
# Name: COD_VERRACO, dtype: int64

# %%
lista.index[0]
max_verracos = 6

# %%
def graficar_verracos_mas_inyectados(lista, max_verracos):
    
    
    fig, ax = plt.subplots(max_verracos, 1)
    
    for i in range(max_verracos):
        
        datos = df[df['COD_VERRACO'] == lista.index[i]]
        media = datos['DOSIS_REAL'].mean()

        tratamientos = df_tratamientos[df_tratamientos['COD_VERRACO'] == lista.index[i]]

        tratamiento_ENZAPROST =  tratamientos[tratamientos['COD_TRATAMIENTO'] == 'ENZAPROST']

        fechas_tratamientos = tratamiento_ENZAPROST['FECHA']
        fechas_tratamientos = pd.DataFrame(fechas_tratamientos)
        fechas_tratamientos = fechas_tratamientos.sort_values(by='FECHA')
        fechas_tratamientos = fechas_tratamientos.reset_index()
        fecha_inicial = fechas_tratamientos['FECHA'].iloc[0]

        #aux = datos[datos['FECHA_REC'] >= fecha_inicial]
        #aux = aux.sort_values(by='FECHA_REC')
        aux = datos.sort_values(by='FECHA_REC')


        tratamiento_ENZAPROST['POI'] = media
        
        
        x = tratamiento_ENZAPROST['FECHA']
        y = tratamiento_ENZAPROST['POI']

        x1 = aux['FECHA_REC']
        y1= aux['DOSIS_REAL']

        fig1 = plt.figure(1)
        ax[i].plot_date(x, y, '*', color='red');
        ax[i].plot(x1, y1, '-', linewidth=1)
        plt.title('Producción DOSIS_REAL verraco')
        fig1.set_size_inches(15, 25)

# %%
graficar_verracos_mas_inyectados(lista, max_verracos)
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# **El objetivo es analizar la calidad seminal de las muestras antes y durante el periodo de inyección del medicamento**

# %% [markdown]
# **El verraco ideal a analizar es aquel que posee la misma cantidad de dosis SIN inyección que CON inyección.**
#
# **Para ello, cojo la fecha de la primera inyección y miro el número de extracciones antes de esa fecha y después de esa fecha.**
#
# NOTA: primera prueba realizada para el VERRACO 1872

# %%
verraco_1872_datos.head()
# Out:
#         CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  \
# 113097   34744 2015-04-24         1872  520ND19  PEÑAS          32
# 111638   34827 2015-04-27         1872  520ND19  PEÑAS          32
# 113213   35020 2015-04-29         1872  520ND19  PEÑAS          47
# 111790   35280 2015-05-04         1872  520ND19  PEÑAS          47
# 111835   35666 2015-05-11         1872  520ND19  PEÑAS          32
#
#         RECOLECTOR  VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  \
# 113097          69      331            184          9                   8
# 111638          69      312            104          8                   8
# 113213          69      315            100          8                   8
# 111790          69      348            137          8                   7
# 111835          69      358            177          9                   8
#
#         DOSIS_POTENCIAL  DOSIS_REAL  DOSIS_A_DILUIR  DILUYENTE  SEMEN_ANADIR  \
# ...

# %%
verraco_1872_tratamiento.head()
# Out:
#        CODIGO  COD_VERRACO      FECHA   DURACION COD_TRATAMIENTO NOTAS CENTRO  \
# 32      29376       1872.0 2019-05-27 2019-05-29            PARA   NaN    CAL
# 395     16304       1872.0 2016-11-11 2016-11-11         SARNACU   NaN  PEÑAS
# 10749   10504       1872.0 2015-04-23 2015-06-01            FLUB   NaN  PEÑAS
# 11586   11653       1872.0 2015-09-16 2015-09-16           AMOXI   NaN  PEÑAS
# 11950   11991       1872.0 2015-11-11 2015-12-10         SARNACU   NaN  PEÑAS
#
#        POI
# 32      20
# 395     20
# 10749   20
# 11586   20
# 11950   20

# %%
verraco_1872_tratamiento_ENZAPROST.head()
# Out:
#        CODIGO  COD_VERRACO      FECHA   DURACION COD_TRATAMIENTO     NOTAS  \
# 19023   21155       1872.0 2017-10-21 2017-10-21       ENZAPROST  NO SALTA
# 19028   21160       1872.0 2017-10-24 2017-10-24       ENZAPROST  NO SALTA
# 19037   21169       1872.0 2017-10-26 2017-10-26       ENZAPROST  NO SALTA
# 20639   25649       1872.0 2018-08-09 2018-08-09       ENZAPROST  NO SALTA
# 21905   21175       1872.0 2017-10-28 2017-10-28       ENZAPROST  NO SALTA
#
#       CENTRO  POI
# 19023    CAL   20
# 19028    CAL   20
# 19037    CAL   20
# 20639    CAL   20
# 21905    CAL   20

# %%
verraco_1872_tratamiento_ENZAPROST.sort_values(by='FECHA').head()
# Out:
#        CODIGO  COD_VERRACO      FECHA   DURACION COD_TRATAMIENTO     NOTAS  \
# 19023   21155       1872.0 2017-10-21 2017-10-21       ENZAPROST  NO SALTA
# 19028   21160       1872.0 2017-10-24 2017-10-24       ENZAPROST  NO SALTA
# 19037   21169       1872.0 2017-10-26 2017-10-26       ENZAPROST  NO SALTA
# 21905   21175       1872.0 2017-10-28 2017-10-28       ENZAPROST  NO SALTA
# 21914   21184       1872.0 2017-10-31 2017-10-31       ENZAPROST  NO SALTA
#
#       CENTRO  POI
# 19023    CAL   20
# 19028    CAL   20
# 19037    CAL   20
# 21905    CAL   20
# 21914    CAL   20

# %%
verraco_1872_tratamiento_ENZAPROST.sort_values(by='FECHA')['FECHA'].iloc[0]
# Out:
# Timestamp('2017-10-21 00:00:00')

# %%
verraco_1872_datos[verraco_1872_datos['FECHA_REC'] <= verraco_1872_tratamiento_ENZAPROST.sort_values(by='FECHA')['FECHA'].iloc[0]].shape
# Out:
# (294, 32)

# %%
pre_enzaprost = verraco_1872_datos[verraco_1872_datos['FECHA_REC'] <= verraco_1872_tratamiento_ENZAPROST.sort_values(by='FECHA')['FECHA'].iloc[0]]
post_enzaprost = verraco_1872_datos[verraco_1872_datos['FECHA_REC'] >= verraco_1872_tratamiento_ENZAPROST.sort_values(by='FECHA')['FECHA'].iloc[0]]

# %%
post_enzaprost.shape
# Out:
# (240, 32)

# %% [markdown]
# **El 21 del 10 de 2017 es el momento de la primera inyección de ENZAPROST al verraco 1872.**
#
# **Tenemos 294 registros antes de la primera dosis y 118 registros posteriores.**
#
# **Ahora realizo un estudio de las dosis reales en el grupo de "pre_enzaprost" y en verraco_1872_tratamiento_ENZAPROST**

# %%
pre_enzaprost['DOSIS_REAL'].describe()
# Out:
# count    294.000000
# mean      17.010204
# std        9.405715
# min        0.000000
# 25%       13.000000
# 50%       17.000000
# 75%       22.000000
# max       46.000000
# Name: DOSIS_REAL, dtype: float64

# %%
post_enzaprost['DOSIS_REAL'].describe()
# Out:
# count    240.000000
# mean      27.500000
# std       18.119778
# min        0.000000
# 25%       14.000000
# 50%       26.000000
# 75%       37.000000
# max       90.000000
# Name: DOSIS_REAL, dtype: float64

# %%
plt.hist(pre_enzaprost['DOSIS_REAL'], bins = 17)
plt.xlabel("DOSIS_REAL");

# %%
plt.hist(post_enzaprost['DOSIS_REAL'], bins = 17)
# Out:
# (array([24., 16., 30., 34., 18., 34., 25., 13.,  9., 10., 10.,  9.,  4.,
#          1.,  0.,  1.,  2.]),
#  array([ 0.        ,  5.29411765, 10.58823529, 15.88235294, 21.17647059,
#         26.47058824, 31.76470588, 37.05882353, 42.35294118, 47.64705882,
#         52.94117647, 58.23529412, 63.52941176, 68.82352941, 74.11764706,
#         79.41176471, 84.70588235, 90.        ]),
#  <a list of 17 Patch objects>)

# %%
plt.boxplot([pre_enzaprost['DOSIS_REAL'], post_enzaprost['DOSIS_REAL']])
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f702f421e48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f702eeee5c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f702f421a20>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f702eeeec50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f702eeeef98>,
# ...
#  'means': []}

# %%
pre_enzaprost['MOTILIDAD'].describe()
# Out:
# count    294.000000
# mean       7.843537
# std        0.932542
# min        0.000000
# 25%        8.000000
# 50%        8.000000
# 75%        8.000000
# max        9.000000
# Name: MOTILIDAD, dtype: float64

# %%
plt.hist(pre_enzaprost['MOTILIDAD'], bins=7);

# %%
post_enzaprost['MOTILIDAD'].describe()
# Out:
# count    240.000000
# mean       8.379167
# std        1.619050
# min        0.000000
# 25%        8.000000
# 50%        9.000000
# 75%        9.000000
# max        9.000000
# Name: MOTILIDAD, dtype: float64

# %%
plt.hist(post_enzaprost['MOTILIDAD'], bins=7);
