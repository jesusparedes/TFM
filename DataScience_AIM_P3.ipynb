# %% [markdown]
# **3. También es muy interesante la repetibilidad o confianza de las técnicas de motilidad y formas anormales, y su
# capacidad predictiva del comportamiento del verraco a lo largo de su vida productiva, seguramente por raza genética
# o línea genética.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

eyaculados = pd.read_excel('EYACULADOS.xlsx')
eyaculados.head(5)
# Out:
#    CODIGO  FECHA_REC  COD_VERRACO  VERRACO CENTRO  ANALIZADOR  RECOLECTOR  \
# 0  140901 2020-01-03         2095  620ND06    CAL          68          56
# 1  140902 2020-01-03         1872  520ND19    CAL          68          55
# 2  140903 2020-01-03         2094  620ND05    CAL          68          83
# 3  140904 2020-01-03         2086  620ND96    CAL          68          78
# 4  140905 2020-01-03         2470  807DP42    CAL          68          83
#
#    VOLUMEN  CONCENTRACION  MOTILIDAD  CALIDAD_MOVIMIENTO  DOSIS_POTENCIAL  \
# 0      317             76          9                   7               10
# 1      357             61          9                   7                9
# 2      511            156          9                   7               36
# 3      497            134          9                   8               30
# 4      572            116          9                   7               30
#
# ...

# %%
eyaculados['ANALIZADOR'].unique()
# Out:
# array([68, 32, 47, 81, 69, 61, 58, 71, 78, 79, 38, 51, 43, 72, 73, 60, 31,
#        57, 59, 56, 55, 62])

# %%
eyaculados['RECOLECTOR'].unique()
# Out:
# array([56, 55, 83, 78, 58, 82, 67,  7,  8,  5, 86, 68, 84, 61, 32, 47, 69,
#        80, 71, 81, 51, 76, 70, 66, 64, 65, 43, 72, 75, 74, 77, 62, 60, 57,
#        63, 59, 31, 53, 54])

# %%
temp = eyaculados.groupby(['ANALIZADOR', 'MOTILIDAD', 'CALIDAD_MOVIMIENTO'])['DOSIS_REAL'].count()
temp = pd.DataFrame(temp)
temp
# Out:
#                                          DOSIS_REAL
# ANALIZADOR MOTILIDAD CALIDAD_MOVIMIENTO
# 31         5         5                            2
#                      7                            2
#            6         3                            1
#                      4                            1
#                      5                            5
#                      6                            1
#                      7                            5
#                      8                            2
#                      9                            1
#            7         5                            2
#                      6                            7
#                      7                           34
#                      8                           16
#                      9                            6
#            8         5                            2
#                      6                           10
# ...

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

conservacion = pd.read_excel('TOMAS_CONSERVACION.xlsx')
conservacion.head(5)
# Out:
#    NUM_TOMA  NUM_ANALISIS FECHA_ANALISIS FECHA_EYACULADO  COD_VERRACO  \
# 0    185458        150111     2020-06-15      2020-06-12         2571
# 1    185459        150112     2020-06-15      2020-06-12         2673
# 2    185460        150113     2020-06-15      2020-06-12         2514
# 3    185461        150114     2020-06-15      2020-06-12         2506
# 4    185462        150115     2020-06-15      2020-06-12         2508
#
#    VERRACO  MOTILIDAD  CALIDAD_MOVIMIENTO  CONTAMINACION  MOTILIDAD4  \
# 0  920ND62          9                   7             -1           9
# 1  020ND28          9                   7             -1           8
# 2  920ND21          9                   7             -1           7
# 3  920ND28          9                   7             -1           9
# 4  920ND26          9                   7             -1           9
#
#    CALIDAD_MOVIMIENTO4  CONTAMINACION4 CENTRO
# 0                    6              -1  PEÑAS
# ...

# %% [markdown]
# **clasificar por mala calidad de semen y predecir en base a calidad de movimiento motilidad y formas anormales si expulsarlo o no**
